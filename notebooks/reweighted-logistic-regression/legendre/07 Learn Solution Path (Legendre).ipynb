# %% [markdown]
# # 01 Import libraries

# %%
import numpy as np
import torch

device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
import pandas as pd

# %%
import importlib

# %% [markdown]
# ## Import our own modules

# %%
# !rm -r Learning-the-Optimal-Solution-Path
# !git clone https://github.com/Cumberkid/Learning-the-Optimal-Solution-Path.git
# Out:
# rm: cannot remove 'Learning-the-Optimal-Solution-Path': No such file or directory
# Cloning into 'Learning-the-Optimal-Solution-Path'...
# remote: Enumerating objects: 1679, done.
# remote: Counting objects: 100% (649/649), done.
# remote: Compressing objects: 100% (290/290), done.
# remote: Total 1679 (delta 492), reused 479 (delta 359), pack-reused 1030
# Receiving objects: 100% (1679/1679), 13.24 MiB | 9.95 MiB/s, done.
# Resolving deltas: 100% (1129/1129), done.

# %% [markdown]
# (Using Colab)

# %%
import sys

# %%
# Add the parent directory to sys.path
sys.path.append('/content/Learning-the-Optimal-Solution-Path')

# %%
import lib
importlib.reload(lib)
# Out:
# <module 'lib' from '/content/Learning-the-Optimal-Solution-Path/lib/__init__.py'>

# %%
from lib.lsp.basis_generator import scaled_shifted_legendre
from lib.lsp.basis_tf_module import Basis_TF_SGD
from lib.lsp.learn_solution_path import learn_solution_path
from lib.lsp.loss_fn_lsp import reg_unif_weighted_logit
from lib.fast_tensor_data_loader import FastTensorDataLoader

# %% [markdown]
# # 02 Instantiate dataset

# %%
# file path for Colab. May need to change this
X_df = pd.read_csv('/content/Learning-the-Optimal-Solution-Path/experiments/fair-regression/data/X_processed.csv')
y_df = pd.read_csv('/content/Learning-the-Optimal-Solution-Path/experiments/fair-regression/data/y_processed.csv')

# %%
X = np.array(X_df)
y = np.array(y_df).squeeze()

# %%
train_X = torch.tensor(X, dtype=torch.float32)
train_y = torch.tensor(y, dtype=torch.float32)

# %%
# full gradient descent uses all data points
GD_data_loader = FastTensorDataLoader(train_X, train_y, batch_size=1000, shuffle=True, )
# stochastic gradient descent uses mini-batch
SGD_data_loader = FastTensorDataLoader(train_X, train_y, batch_size=20, shuffle=True, )
# test data
test_data_loader = FastTensorDataLoader(train_X, train_y, batch_size=1000, shuffle=False, )

# %%
lam_max = 1
lam_min = 0
input_dim = X.shape[1]
loss_fn = reg_unif_weighted_logit

# %%
# Read the CSV file into a DataFrame
# truth = pd.read_csv('/content/Learning-the-Optimal-Solution-Path/experiments/fair-regression/results/exact_soln_list.csv')
truth = pd.read_csv('exact_soln_list.csv')

# Display the DataFrame
truth
# Out:
#         losses   theta_0   theta_1   theta_2   theta_3   theta_4   theta_5  \
# 0     0.190793 -0.373029  0.186622  0.227443 -0.023583  0.164822  0.142992
# 1     0.192130 -0.371212  0.186634  0.227586 -0.023679  0.164875  0.142262
# 2     0.193463 -0.369401  0.186645  0.227729 -0.023775  0.164927  0.141535
# 3     0.194792 -0.367595  0.186656  0.227870 -0.023870  0.164977  0.140811
# 4     0.196117 -0.365794  0.186665  0.228009 -0.023964  0.165027  0.140089
# ...        ...       ...       ...       ...       ...       ...       ...
# 1019  0.327684  0.692472 -0.029101 -0.033382 -0.017462 -0.005831 -0.225541
# 1020  0.325866  0.693930 -0.029932 -0.034521 -0.017548 -0.006565 -0.226194
# 1021  0.324032  0.695399 -0.030769 -0.035668 -0.017634 -0.007304 -0.226853
# 1022  0.322184  0.696878 -0.031613 -0.036822 -0.017720 -0.008050 -0.227517
# 1023  0.320320  0.698369 -0.032464 -0.037983 -0.017807 -0.008802 -0.228186
#
#        theta_6   theta_7   theta_8  ...  theta_36  theta_37  theta_38  \
# 0     0.168018  0.026305  0.142661  ... -0.018010  0.054908 -0.005629
# 1     0.167428  0.025960  0.142993  ... -0.017600  0.054199 -0.005657
# 2     0.166842  0.025615  0.143323  ... -0.017191  0.053493 -0.005685
# 3     0.166258  0.025271  0.143653  ... -0.016784  0.052790 -0.005713
# 4     0.165677  0.024927  0.143982  ... -0.016378  0.052089 -0.005741
# ...        ...       ...       ...  ...       ...       ...       ...
# 1019 -0.146453 -0.051680  0.070009  ...  0.105324 -0.201982  0.000913
# 1020 -0.148351 -0.051246  0.068693  ...  0.105340 -0.202186  0.000990
# 1021 -0.150274 -0.050809  0.067366  ...  0.105357 -0.202393  0.001066
# 1022 -0.152223 -0.050369  0.066028  ...  0.105374 -0.202601  0.001143
# 1023 -0.154196 -0.049927  0.064680  ...  0.105391 -0.202811  0.001220
#
#       theta_39  theta_40  theta_41  theta_42  theta_43  theta_44  theta_45
# 0     0.000000  0.000000 -0.031270 -0.018010 -0.139608 -0.116840 -0.061673
# 1     0.000069  0.000098 -0.031115 -0.017600 -0.139385 -0.116402 -0.061226
# 2     0.000137  0.000195 -0.030961 -0.017191 -0.139162 -0.115965 -0.060781
# 3     0.000205  0.000293 -0.030808 -0.016784 -0.138939 -0.115529 -0.060337
# 4     0.000273  0.000390 -0.030655 -0.016378 -0.138717 -0.115094 -0.059894
# ...        ...       ...       ...       ...       ...       ...       ...
# 1019  0.013100  0.018598  0.063129  0.105324  0.157442  0.161747  0.171301
# 1020  0.013040  0.018537  0.063366  0.105340  0.158131  0.162149  0.171464
# 1021  0.012980  0.018475  0.063604  0.105357  0.158825  0.162554  0.171627
# 1022  0.012919  0.018415  0.063843  0.105374  0.159523  0.162962  0.171792
# 1023  0.012859  0.018354  0.064084  0.105391  0.160226  0.163374  0.171958
#
# [1024 rows x 47 columns]

# %%
selected_columns = ['theta_0', 'theta_1', 'theta_2', 'theta_3', 'theta_4',
                    'theta_5', 'theta_6', 'theta_7', 'theta_8', 'theta_9',
                    'theta_10', 'theta_11', 'theta_12', 'theta_13', 'theta_14',
                    'theta_15', 'theta_16', 'theta_17', 'theta_18', 'theta_19',
                    'theta_20', 'theta_21', 'theta_22', 'theta_23', 'theta_24',
                    'theta_25', 'theta_26', 'theta_27', 'theta_28', 'theta_29',
                    'theta_30', 'theta_31', 'theta_32', 'theta_33', 'theta_34',
                    'theta_35', 'theta_36', 'theta_37', 'theta_38', 'theta_39',
                    'theta_40', 'theta_41', 'theta_42', 'theta_43', 'theta_44',
                    'theta_45']
true_thetas = truth[selected_columns].to_numpy()
true_losses = truth['losses'].to_numpy()

# %% [markdown]
# # 03 Exact Gradient with Diminishing LR by Distance Diagnostic

# %% [markdown]
# Recall that our method runs SGD over random $\tilde λ$'s with a linear basis $\Phi(\tilde \lambda)$ of our choice. We want to approximate $\theta$ with $\Phi(\lambda)\beta$, so the objective function is $\min_\beta h(\Phi(\tilde\lambda)\beta, \tilde\lambda) = (1-\tilde\lambda) BCE(X_\text{pass}\Phi(\tilde\lambda)\beta,\ y_\text{pass}) + \tilde\lambda BCE(X_\text{fail}\Phi(\tilde\lambda)\beta,\ y_\text{fail})$. For each batch of training data set, we randomize $\tilde\lambda$. If batch size = 1, then this is equivalent to a standard SGD.

# %% [markdown]
# We use diminishing learning rate for better demonstrate convergence. If we use a constant learning rate, the solution path error will eventually do a random walk after descending to a certain threshold value.
#
# Set weighted_avg to 'False' see this random walk.

# %%
max_epochs = 2000

# %%
phi_lam = scaled_shifted_legendre

# %%
def thresh_basis(basis_dim):
    return 1e-9

# %% [markdown]
# ## num basis func = 5

# %%
basis_dim = 5
init_lr = 0.125

# %%
np.random.seed(8675309)
torch.manual_seed(8675309)

num_itr_history, sup_err_history, weight, lr = learn_solution_path(input_dim, basis_dim, phi_lam, max_epochs,
                                                               GD_data_loader, test_data_loader, loss_fn,
                                                               lam_min, lam_max, true_losses, init_lr=init_lr,
                                                               diminish=True, thresh_basis=thresh_basis,
                                                               record_frequency=10, distribution='uniform',
                                                               device=device, trace_frequency=10)
sup_err_history = np.array(sup_err_history)
# Out:
# diminish at iteration #8, new lr = 0.12125
# diminish at iteration #10, new lr = 0.1176125
# --------approximate solution path for # itr = 10 complete--------
# # itr: 10	 sup error: 3.808290511369705
# diminish at iteration #13, new lr = 0.114084125
# diminish at iteration #17, new lr = 0.11066160124999999
# --------approximate solution path for # itr = 20 complete--------
# # itr: 20	 sup error: 0.4882354736328125
# diminish at iteration #23, new lr = 0.10734175321249999
# diminish at iteration #30, new lr = 0.10412150061612499
# --------approximate solution path for # itr = 30 complete--------
# # itr: 30	 sup error: 0.31499093770980835
# diminish at iteration #39, new lr = 0.10099785559764124
# --------approximate solution path for # itr = 40 complete--------
# # itr: 40	 sup error: 0.061185866594314575
# --------approximate solution path for # itr = 50 complete--------
# # itr: 50	 sup error: 0.040966540575027466
# diminish at iteration #51, new lr = 0.097967919929712
# --------approximate solution path for # itr = 60 complete--------
# # itr: 60	 sup error: 0.023592114448547363
# diminish at iteration #66, new lr = 0.09502888233182064
# --------approximate solution path for # itr = 70 complete--------
# # itr: 70	 sup error: 0.014293372631072998
# --------approximate solution path for # itr = 80 complete--------
# # itr: 80	 sup error: 0.009062230587005615
# diminish at iteration #86, new lr = 0.09217801586186601
# --------approximate solution path for # itr = 90 complete--------
# # itr: 90	 sup error: 0.005998894572257996
# --------approximate solution path for # itr = 100 complete--------
# # itr: 100	 sup error: 0.004095256328582764
# --------approximate solution path for # itr = 110 complete--------
# # itr: 110	 sup error: 0.0028149038553237915
# diminish at iteration #112, new lr = 0.08941267538601003
# --------approximate solution path for # itr = 120 complete--------
# # itr: 120	 sup error: 0.0019732415676116943
# --------approximate solution path for # itr = 130 complete--------
# # itr: 130	 sup error: 0.0013890564441680908
# --------approximate solution path for # itr = 140 complete--------
# # itr: 140	 sup error: 0.0009844601154327393
# diminish at iteration #146, new lr = 0.08673029512442973
# --------approximate solution path for # itr = 150 complete--------
# # itr: 150	 sup error: 0.000721275806427002
# --------approximate solution path for # itr = 160 complete--------
# # itr: 160	 sup error: 0.0005931258201599121
# --------approximate solution path for # itr = 170 complete--------
# # itr: 170	 sup error: 0.000543594360351618
# --------approximate solution path for # itr = 180 complete--------
# # itr: 180	 sup error: 0.000529319047927912
# diminish at iteration #190, new lr = 0.08412838627069684
# --------approximate solution path for # itr = 190 complete--------
# # itr: 190	 sup error: 0.000524520874023493
# --------approximate solution path for # itr = 200 complete--------
# # itr: 200	 sup error: 0.0004869699478149969
# --------approximate solution path for # itr = 210 complete--------
# # itr: 210	 sup error: 0.00046241283416748047
# --------approximate solution path for # itr = 220 complete--------
# # itr: 220	 sup error: 0.000515669584274292
# --------approximate solution path for # itr = 230 complete--------
# # itr: 230	 sup error: 0.0005297064781188965
# --------approximate solution path for # itr = 240 complete--------
# # itr: 240	 sup error: 0.0004743337631225586
# diminish at iteration #247, new lr = 0.08160453468257593
# --------approximate solution path for # itr = 250 complete--------
# # itr: 250	 sup error: 0.00047272443771362305
# --------approximate solution path for # itr = 260 complete--------
# # itr: 260	 sup error: 0.000490725040435791
# --------approximate solution path for # itr = 270 complete--------
# # itr: 270	 sup error: 0.0005446672439575195
# --------approximate solution path for # itr = 280 complete--------
# # itr: 280	 sup error: 0.0006149411201477051
# --------approximate solution path for # itr = 290 complete--------
# # itr: 290	 sup error: 0.000664442777633667
# --------approximate solution path for # itr = 300 complete--------
# # itr: 300	 sup error: 0.0006803572177886963
# --------approximate solution path for # itr = 310 complete--------
# # itr: 310	 sup error: 0.0006954371929168701
# --------approximate solution path for # itr = 320 complete--------
# # itr: 320	 sup error: 0.0007096529006958008
# diminish at iteration #321, new lr = 0.07915639864209865
# --------approximate solution path for # itr = 330 complete--------
# # itr: 330	 sup error: 0.0007195472717285156
# --------approximate solution path for # itr = 340 complete--------
# # itr: 340	 sup error: 0.0006952881813049316
# --------approximate solution path for # itr = 350 complete--------
# # itr: 350	 sup error: 0.0007210373878479004
# --------approximate solution path for # itr = 360 complete--------
# # itr: 360	 sup error: 0.0007612109184265137
# --------approximate solution path for # itr = 370 complete--------
# # itr: 370	 sup error: 0.0008118152618408203
# --------approximate solution path for # itr = 380 complete--------
# # itr: 380	 sup error: 0.0008694231510162354
# --------approximate solution path for # itr = 390 complete--------
# # itr: 390	 sup error: 0.0008623301982879639
# --------approximate solution path for # itr = 400 complete--------
# # itr: 400	 sup error: 0.0008353590965270996
# --------approximate solution path for # itr = 410 complete--------
# # itr: 410	 sup error: 0.0008404552936553955
# diminish at iteration #417, new lr = 0.0767817066828357
# --------approximate solution path for # itr = 420 complete--------
# # itr: 420	 sup error: 0.0008479952812194824
# --------approximate solution path for # itr = 430 complete--------
# # itr: 430	 sup error: 0.000813603401184082
# --------approximate solution path for # itr = 440 complete--------
# # itr: 440	 sup error: 0.0008102655410766602
# --------approximate solution path for # itr = 450 complete--------
# # itr: 450	 sup error: 0.0008144378662109375
# --------approximate solution path for # itr = 460 complete--------
# # itr: 460	 sup error: 0.0008350610733032227
# --------approximate solution path for # itr = 470 complete--------
# # itr: 470	 sup error: 0.0008682012557983398
# --------approximate solution path for # itr = 480 complete--------
# # itr: 480	 sup error: 0.0009209513664245605
# --------approximate solution path for # itr = 490 complete--------
# # itr: 490	 sup error: 0.0009812116622924805
# --------approximate solution path for # itr = 500 complete--------
# # itr: 500	 sup error: 0.0010216832160949707
# --------approximate solution path for # itr = 510 complete--------
# # itr: 510	 sup error: 0.0010332763195037842
# --------approximate solution path for # itr = 520 complete--------
# # itr: 520	 sup error: 0.0010596513748168945
# --------approximate solution path for # itr = 530 complete--------
# # itr: 530	 sup error: 0.001052558422088623
# --------approximate solution path for # itr = 540 complete--------
# # itr: 540	 sup error: 0.001043558120727539
# diminish at iteration #542, new lr = 0.07447825548235062
# --------approximate solution path for # itr = 550 complete--------
# # itr: 550	 sup error: 0.0010048747062683105
# --------approximate solution path for # itr = 560 complete--------
# # itr: 560	 sup error: 0.0009902417659759521
# --------approximate solution path for # itr = 570 complete--------
# # itr: 570	 sup error: 0.00100630521774292
# --------approximate solution path for # itr = 580 complete--------
# # itr: 580	 sup error: 0.001036226749420166
# --------approximate solution path for # itr = 590 complete--------
# # itr: 590	 sup error: 0.0010724961757659912
# --------approximate solution path for # itr = 600 complete--------
# # itr: 600	 sup error: 0.0011123418807983398
# --------approximate solution path for # itr = 610 complete--------
# # itr: 610	 sup error: 0.0011583268642425537
# --------approximate solution path for # itr = 620 complete--------
# # itr: 620	 sup error: 0.0012105107307434082
# --------approximate solution path for # itr = 630 complete--------
# # itr: 630	 sup error: 0.001265406608581543
# --------approximate solution path for # itr = 640 complete--------
# # itr: 640	 sup error: 0.0013059377670288086
# --------approximate solution path for # itr = 650 complete--------
# # itr: 650	 sup error: 0.001312553882598877
# --------approximate solution path for # itr = 660 complete--------
# # itr: 660	 sup error: 0.0013284683227539062
# --------approximate solution path for # itr = 670 complete--------
# # itr: 670	 sup error: 0.0013034939765930176
# --------approximate solution path for # itr = 680 complete--------
# # itr: 680	 sup error: 0.001280367374420166
# --------approximate solution path for # itr = 690 complete--------
# # itr: 690	 sup error: 0.0012587010860443115
# --------approximate solution path for # itr = 700 complete--------
# # itr: 700	 sup error: 0.0012387633323669434
# diminish at iteration #705, new lr = 0.07224390781788011
# --------approximate solution path for # itr = 710 complete--------
# # itr: 710	 sup error: 0.0012336969375610352
# --------approximate solution path for # itr = 720 complete--------
# # itr: 720	 sup error: 0.0011923611164093018
# --------approximate solution path for # itr = 730 complete--------
# # itr: 730	 sup error: 0.0011654198169708252
# --------approximate solution path for # itr = 740 complete--------
# # itr: 740	 sup error: 0.0011507868766784668
# --------approximate solution path for # itr = 750 complete--------
# # itr: 750	 sup error: 0.0011337697505950928
# --------approximate solution path for # itr = 760 complete--------
# # itr: 760	 sup error: 0.001125723123550415
# --------approximate solution path for # itr = 770 complete--------
# # itr: 770	 sup error: 0.0011307001113891602
# --------approximate solution path for # itr = 780 complete--------
# # itr: 780	 sup error: 0.0011374056339263916
# --------approximate solution path for # itr = 790 complete--------
# # itr: 790	 sup error: 0.0011293590068817139
# --------approximate solution path for # itr = 800 complete--------
# # itr: 800	 sup error: 0.0011261701583862305
# --------approximate solution path for # itr = 810 complete--------
# # itr: 810	 sup error: 0.0011240243911743164
# --------approximate solution path for # itr = 820 complete--------
# # itr: 820	 sup error: 0.0010930299758911133
# --------approximate solution path for # itr = 830 complete--------
# # itr: 830	 sup error: 0.0010724663734436035
# --------approximate solution path for # itr = 840 complete--------
# # itr: 840	 sup error: 0.0010625123977661133
# --------approximate solution path for # itr = 850 complete--------
# # itr: 850	 sup error: 0.0010370314121246338
# --------approximate solution path for # itr = 860 complete--------
# # itr: 860	 sup error: 0.001009225845336914
# --------approximate solution path for # itr = 870 complete--------
# # itr: 870	 sup error: 0.000993102788925171
# --------approximate solution path for # itr = 880 complete--------
# # itr: 880	 sup error: 0.0009909570217132568
# --------approximate solution path for # itr = 890 complete--------
# # itr: 890	 sup error: 0.0009970366954803467
# --------approximate solution path for # itr = 900 complete--------
# # itr: 900	 sup error: 0.0010062158107757568
# --------approximate solution path for # itr = 910 complete--------
# # itr: 910	 sup error: 0.0010139048099517822
# diminish at iteration #917, new lr = 0.0700765905833437
# --------approximate solution path for # itr = 920 complete--------
# # itr: 920	 sup error: 0.0010269880294799805
# --------approximate solution path for # itr = 930 complete--------
# # itr: 930	 sup error: 0.0010411441326141357
# --------approximate solution path for # itr = 940 complete--------
# # itr: 940	 sup error: 0.0010326504707336426
# --------approximate solution path for # itr = 950 complete--------
# # itr: 950	 sup error: 0.0010342001914978027
# --------approximate solution path for # itr = 960 complete--------
# # itr: 960	 sup error: 0.0010425150394439697
# --------approximate solution path for # itr = 970 complete--------
# # itr: 970	 sup error: 0.001027911901473999
# --------approximate solution path for # itr = 980 complete--------
# # itr: 980	 sup error: 0.0010068416595458984
# --------approximate solution path for # itr = 990 complete--------
# # itr: 990	 sup error: 0.0009958744049072266
# --------approximate solution path for # itr = 1000 complete--------
# # itr: 1000	 sup error: 0.0009889602661132812
# --------approximate solution path for # itr = 1010 complete--------
# # itr: 1010	 sup error: 0.0009677112102508545
# --------approximate solution path for # itr = 1020 complete--------
# # itr: 1020	 sup error: 0.0009518265724182129
# --------approximate solution path for # itr = 1030 complete--------
# # itr: 1030	 sup error: 0.0009321868419647217
# --------approximate solution path for # itr = 1040 complete--------
# # itr: 1040	 sup error: 0.0009215474128723145
# --------approximate solution path for # itr = 1050 complete--------
# # itr: 1050	 sup error: 0.0009250044822692871
# --------approximate solution path for # itr = 1060 complete--------
# # itr: 1060	 sup error: 0.0009261369705200195
# --------approximate solution path for # itr = 1070 complete--------
# # itr: 1070	 sup error: 0.0008978843688964844
# --------approximate solution path for # itr = 1080 complete--------
# # itr: 1080	 sup error: 0.0008791685104370117
# --------approximate solution path for # itr = 1090 complete--------
# # itr: 1090	 sup error: 0.0008629262447357178
# --------approximate solution path for # itr = 1100 complete--------
# # itr: 1100	 sup error: 0.0008407235145568848
# --------approximate solution path for # itr = 1110 complete--------
# # itr: 1110	 sup error: 0.0008276998996734619
# --------approximate solution path for # itr = 1120 complete--------
# # itr: 1120	 sup error: 0.0008199512958526611
# --------approximate solution path for # itr = 1130 complete--------
# # itr: 1130	 sup error: 0.0008013248443603516
# --------approximate solution path for # itr = 1140 complete--------
# # itr: 1140	 sup error: 0.0007912516593933105
# --------approximate solution path for # itr = 1150 complete--------
# # itr: 1150	 sup error: 0.0007942616939544678
# --------approximate solution path for # itr = 1160 complete--------
# # itr: 1160	 sup error: 0.0008052289485931396
# --------approximate solution path for # itr = 1170 complete--------
# # itr: 1170	 sup error: 0.0008197426795959473
# --------approximate solution path for # itr = 1180 complete--------
# # itr: 1180	 sup error: 0.0008248984813690186
# --------approximate solution path for # itr = 1190 complete--------
# # itr: 1190	 sup error: 0.0008327066898345947
# diminish at iteration #1192, new lr = 0.06797429286584339
# --------approximate solution path for # itr = 1200 complete--------
# # itr: 1200	 sup error: 0.0008389949798583984
# --------approximate solution path for # itr = 1210 complete--------
# # itr: 1210	 sup error: 0.0008490979671478271
# --------approximate solution path for # itr = 1220 complete--------
# # itr: 1220	 sup error: 0.0008497834205627441
# --------approximate solution path for # itr = 1230 complete--------
# # itr: 1230	 sup error: 0.0008511841297149658
# --------approximate solution path for # itr = 1240 complete--------
# # itr: 1240	 sup error: 0.0008578598499298096
# --------approximate solution path for # itr = 1250 complete--------
# # itr: 1250	 sup error: 0.0008719563484191895
# --------approximate solution path for # itr = 1260 complete--------
# # itr: 1260	 sup error: 0.0008790791034698486
# --------approximate solution path for # itr = 1270 complete--------
# # itr: 1270	 sup error: 0.0008905231952667236
# --------approximate solution path for # itr = 1280 complete--------
# # itr: 1280	 sup error: 0.0009033381938934326
# --------approximate solution path for # itr = 1290 complete--------
# # itr: 1290	 sup error: 0.0009192824363708496
# --------approximate solution path for # itr = 1300 complete--------
# # itr: 1300	 sup error: 0.0009321272373199463
# --------approximate solution path for # itr = 1310 complete--------
# # itr: 1310	 sup error: 0.000946342945098877
# --------approximate solution path for # itr = 1320 complete--------
# # itr: 1320	 sup error: 0.0009615123271942139
# --------approximate solution path for # itr = 1330 complete--------
# # itr: 1330	 sup error: 0.0009742975234985352
# --------approximate solution path for # itr = 1340 complete--------
# # itr: 1340	 sup error: 0.0009882152080535889
# --------approximate solution path for # itr = 1350 complete--------
# # itr: 1350	 sup error: 0.0010022521018981934
# --------approximate solution path for # itr = 1360 complete--------
# # itr: 1360	 sup error: 0.0010049045085906982
# --------approximate solution path for # itr = 1370 complete--------
# # itr: 1370	 sup error: 0.0010004937648773193
# --------approximate solution path for # itr = 1380 complete--------
# # itr: 1380	 sup error: 0.001003354787826538
# --------approximate solution path for # itr = 1390 complete--------
# # itr: 1390	 sup error: 0.001010805368423462
# --------approximate solution path for # itr = 1400 complete--------
# # itr: 1400	 sup error: 0.001011967658996582
# --------approximate solution path for # itr = 1410 complete--------
# # itr: 1410	 sup error: 0.0010066628456115723
# --------approximate solution path for # itr = 1420 complete--------
# # itr: 1420	 sup error: 0.0010039806365966797
# --------approximate solution path for # itr = 1430 complete--------
# # itr: 1430	 sup error: 0.0010043084621429443
# --------approximate solution path for # itr = 1440 complete--------
# # itr: 1440	 sup error: 0.001000821590423584
# --------approximate solution path for # itr = 1450 complete--------
# # itr: 1450	 sup error: 0.0010033845901489258
# --------approximate solution path for # itr = 1460 complete--------
# # itr: 1460	 sup error: 0.0009990334510803223
# --------approximate solution path for # itr = 1470 complete--------
# # itr: 1470	 sup error: 0.0009927153587341309
# --------approximate solution path for # itr = 1480 complete--------
# # itr: 1480	 sup error: 0.0009866952896118164
# --------approximate solution path for # itr = 1490 complete--------
# # itr: 1490	 sup error: 0.0009744465351104736
# --------approximate solution path for # itr = 1500 complete--------
# # itr: 1500	 sup error: 0.0009577274322509766
# --------approximate solution path for # itr = 1510 complete--------
# # itr: 1510	 sup error: 0.0009470283985137939
# --------approximate solution path for # itr = 1520 complete--------
# # itr: 1520	 sup error: 0.000941932201385498
# --------approximate solution path for # itr = 1530 complete--------
# # itr: 1530	 sup error: 0.0009385943412780762
# --------approximate solution path for # itr = 1540 complete--------
# # itr: 1540	 sup error: 0.0009406507015228271
# diminish at iteration #1550, new lr = 0.06593506407986809
# --------approximate solution path for # itr = 1550 complete--------
# # itr: 1550	 sup error: 0.0009470582008361816
# --------approximate solution path for # itr = 1560 complete--------
# # itr: 1560	 sup error: 0.0009558200836181641
# --------approximate solution path for # itr = 1570 complete--------
# # itr: 1570	 sup error: 0.0009560585021972656
# --------approximate solution path for # itr = 1580 complete--------
# # itr: 1580	 sup error: 0.0009535551071166992
# --------approximate solution path for # itr = 1590 complete--------
# # itr: 1590	 sup error: 0.0009503364562988281
# --------approximate solution path for # itr = 1600 complete--------
# # itr: 1600	 sup error: 0.0009433627128601074
# --------approximate solution path for # itr = 1610 complete--------
# # itr: 1610	 sup error: 0.0009421110153198242
# --------approximate solution path for # itr = 1620 complete--------
# # itr: 1620	 sup error: 0.0009360909461975098
# --------approximate solution path for # itr = 1630 complete--------
# # itr: 1630	 sup error: 0.0009309351444244385
# --------approximate solution path for # itr = 1640 complete--------
# # itr: 1640	 sup error: 0.0009226202964782715
# --------approximate solution path for # itr = 1650 complete--------
# # itr: 1650	 sup error: 0.0009177923202514648
# --------approximate solution path for # itr = 1660 complete--------
# # itr: 1660	 sup error: 0.0009160041809082031
# --------approximate solution path for # itr = 1670 complete--------
# # itr: 1670	 sup error: 0.0009163320064544678
# --------approximate solution path for # itr = 1680 complete--------
# # itr: 1680	 sup error: 0.000918954610824585
# --------approximate solution path for # itr = 1690 complete--------
# # itr: 1690	 sup error: 0.0009144842624664307
# --------approximate solution path for # itr = 1700 complete--------
# # itr: 1700	 sup error: 0.0009102225303649902
# --------approximate solution path for # itr = 1710 complete--------
# # itr: 1710	 sup error: 0.0009116530418395996
# --------approximate solution path for # itr = 1720 complete--------
# # itr: 1720	 sup error: 0.0009170770645141602
# --------approximate solution path for # itr = 1730 complete--------
# # itr: 1730	 sup error: 0.0009237825870513916
# --------approximate solution path for # itr = 1740 complete--------
# # itr: 1740	 sup error: 0.0009317994117736816
# --------approximate solution path for # itr = 1750 complete--------
# # itr: 1750	 sup error: 0.0009230971336364746
# --------approximate solution path for # itr = 1760 complete--------
# # itr: 1760	 sup error: 0.0009174942970275879
# --------approximate solution path for # itr = 1770 complete--------
# # itr: 1770	 sup error: 0.0009121298789978027
# --------approximate solution path for # itr = 1780 complete--------
# # itr: 1780	 sup error: 0.0009080767631530762
# --------approximate solution path for # itr = 1790 complete--------
# # itr: 1790	 sup error: 0.0009026527404785156
# --------approximate solution path for # itr = 1800 complete--------
# # itr: 1800	 sup error: 0.0009031891822814941
# --------approximate solution path for # itr = 1810 complete--------
# # itr: 1810	 sup error: 0.0009014010429382324
# --------approximate solution path for # itr = 1820 complete--------
# # itr: 1820	 sup error: 0.0008935928344726562
# --------approximate solution path for # itr = 1830 complete--------
# # itr: 1830	 sup error: 0.0008912384510040283
# --------approximate solution path for # itr = 1840 complete--------
# # itr: 1840	 sup error: 0.0008916258811950684
# --------approximate solution path for # itr = 1850 complete--------
# # itr: 1850	 sup error: 0.000896155834197998
# --------approximate solution path for # itr = 1860 complete--------
# # itr: 1860	 sup error: 0.0009024739265441895
# --------approximate solution path for # itr = 1870 complete--------
# # itr: 1870	 sup error: 0.0009116530418395996
# --------approximate solution path for # itr = 1880 complete--------
# # itr: 1880	 sup error: 0.0009116232395172119
# --------approximate solution path for # itr = 1890 complete--------
# # itr: 1890	 sup error: 0.0009078681468963623
# --------approximate solution path for # itr = 1900 complete--------
# # itr: 1900	 sup error: 0.00090828537940979
# --------approximate solution path for # itr = 1910 complete--------
# # itr: 1910	 sup error: 0.0009126365184783936
# --------approximate solution path for # itr = 1920 complete--------
# # itr: 1920	 sup error: 0.0009199976921081543
# --------approximate solution path for # itr = 1930 complete--------
# # itr: 1930	 sup error: 0.0009300410747528076
# --------approximate solution path for # itr = 1940 complete--------
# # itr: 1940	 sup error: 0.0009416341781616211
# --------approximate solution path for # itr = 1950 complete--------
# # itr: 1950	 sup error: 0.0009514093399047852
# --------approximate solution path for # itr = 1960 complete--------
# # itr: 1960	 sup error: 0.0009570419788360596
# --------approximate solution path for # itr = 1970 complete--------
# # itr: 1970	 sup error: 0.0009548068046569824
# --------approximate solution path for # itr = 1980 complete--------
# # itr: 1980	 sup error: 0.0009447634220123291
# --------approximate solution path for # itr = 1990 complete--------
# # itr: 1990	 sup error: 0.0009413361549377441
# --------approximate solution path for # itr = 2000 complete--------
# # itr: 2000	 sup error: 0.0009431838989257812

# %%
file_path = 'LSP_results_exact_fixed_basis.csv'

LSP_results_exact_fixed_basis = pd.DataFrame(np.column_stack((num_itr_history, sup_err_history)), columns=['num_itr', 'sup_err_5'])

# Save the DataFrame to a CSV file
LSP_results_exact_fixed_basis.to_csv(file_path, index=False)

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Display the DataFrame
df
# Out:
#      num_itr  sup_err_5
# 0       10.0   3.808291
# 1       20.0   0.488235
# 2       30.0   0.314991
# 3       40.0   0.061186
# 4       50.0   0.040967
# ..       ...        ...
# 195   1960.0   0.000957
# 196   1970.0   0.000955
# 197   1980.0   0.000945
# 198   1990.0   0.000941
# 199   2000.0   0.000943
#
# [200 rows x 2 columns]

# %% [markdown]
# ## num basis func = 7

# %%
basis_dim = 7
init_lr = 0.0625

# %%
np.random.seed(8675309)
torch.manual_seed(8675309)

num_itr_history, sup_err_history, weight, lr = learn_solution_path(input_dim, basis_dim, phi_lam, max_epochs,
                                                               GD_data_loader, test_data_loader, loss_fn,
                                                               lam_min, lam_max, true_losses, init_lr=init_lr,
                                                               diminish=True, thresh_basis=thresh_basis,
                                                               record_frequency=10, distribution='uniform',
                                                               device=device, trace_frequency=10)
sup_err_history = np.array(sup_err_history)
# Out:
# --------approximate solution path for # itr = 10 complete--------
# # itr: 10	 sup error: 0.20327037572860718
# diminish at iteration #13, new lr = 0.060625
# --------approximate solution path for # itr = 20 complete--------
# # itr: 20	 sup error: 0.13757383823394775
# diminish at iteration #30, new lr = 0.05880625
# --------approximate solution path for # itr = 30 complete--------
# # itr: 30	 sup error: 0.04141576588153839
# diminish at iteration #39, new lr = 0.0570420625
# --------approximate solution path for # itr = 40 complete--------
# # itr: 40	 sup error: 0.017672955989837646
# --------approximate solution path for # itr = 50 complete--------
# # itr: 50	 sup error: 0.008210957050323542
# diminish at iteration #51, new lr = 0.055330800624999996
# --------approximate solution path for # itr = 60 complete--------
# # itr: 60	 sup error: 0.007690101861953735
# diminish at iteration #66, new lr = 0.053670876606249994
# --------approximate solution path for # itr = 70 complete--------
# # itr: 70	 sup error: 0.007095009088516235
# --------approximate solution path for # itr = 80 complete--------
# # itr: 80	 sup error: 0.005397319793701227
# diminish at iteration #86, new lr = 0.052060750308062495
# --------approximate solution path for # itr = 90 complete--------
# # itr: 90	 sup error: 0.004542946815490723
# --------approximate solution path for # itr = 100 complete--------
# # itr: 100	 sup error: 0.0038673579692840576
# --------approximate solution path for # itr = 110 complete--------
# # itr: 110	 sup error: 0.003275156021118164
# diminish at iteration #112, new lr = 0.05049892779882062
# --------approximate solution path for # itr = 120 complete--------
# # itr: 120	 sup error: 0.002775639295578003
# --------approximate solution path for # itr = 130 complete--------
# # itr: 130	 sup error: 0.002339780330657959
# --------approximate solution path for # itr = 140 complete--------
# # itr: 140	 sup error: 0.0019999444484710693
# diminish at iteration #146, new lr = 0.048983959964856
# --------approximate solution path for # itr = 150 complete--------
# # itr: 150	 sup error: 0.001687467098236084
# --------approximate solution path for # itr = 160 complete--------
# # itr: 160	 sup error: 0.0014202892780303955
# --------approximate solution path for # itr = 170 complete--------
# # itr: 170	 sup error: 0.0012066364288330078
# --------approximate solution path for # itr = 180 complete--------
# # itr: 180	 sup error: 0.0010319054126740057
# diminish at iteration #190, new lr = 0.04751444116591032
# --------approximate solution path for # itr = 190 complete--------
# # itr: 190	 sup error: 0.0008825957775116522
# --------approximate solution path for # itr = 200 complete--------
# # itr: 200	 sup error: 0.0007551312446594793
# --------approximate solution path for # itr = 210 complete--------
# # itr: 210	 sup error: 0.0006509125232697088
# --------approximate solution path for # itr = 220 complete--------
# # itr: 220	 sup error: 0.0005637109279633123
# --------approximate solution path for # itr = 230 complete--------
# # itr: 230	 sup error: 0.0004911124706268311
# --------approximate solution path for # itr = 240 complete--------
# # itr: 240	 sup error: 0.0004298686981201727
# diminish at iteration #247, new lr = 0.046089007930933006
# --------approximate solution path for # itr = 250 complete--------
# # itr: 250	 sup error: 0.0003777146339417059
# --------approximate solution path for # itr = 260 complete--------
# # itr: 260	 sup error: 0.00033351778984069824
# --------approximate solution path for # itr = 270 complete--------
# # itr: 270	 sup error: 0.0002943873405457098
# --------approximate solution path for # itr = 280 complete--------
# # itr: 280	 sup error: 0.0002600848674774725
# --------approximate solution path for # itr = 290 complete--------
# # itr: 290	 sup error: 0.00023096799850469418
# --------approximate solution path for # itr = 300 complete--------
# # itr: 300	 sup error: 0.0002053678035736084
# --------approximate solution path for # itr = 310 complete--------
# # itr: 310	 sup error: 0.00018280744552617856
# --------approximate solution path for # itr = 320 complete--------
# # itr: 320	 sup error: 0.00016313791275029965
# diminish at iteration #321, new lr = 0.04470633769300501
# --------approximate solution path for # itr = 330 complete--------
# # itr: 330	 sup error: 0.00014603137969976254
# --------approximate solution path for # itr = 340 complete--------
# # itr: 340	 sup error: 0.0001310408115387518
# --------approximate solution path for # itr = 350 complete--------
# # itr: 350	 sup error: 0.00011804699897771664
# --------approximate solution path for # itr = 360 complete--------
# # itr: 360	 sup error: 0.00010666251182561703
# --------approximate solution path for # itr = 370 complete--------
# # itr: 370	 sup error: 9.66787338256836e-05
# --------approximate solution path for # itr = 380 complete--------
# # itr: 380	 sup error: 9.101629257202148e-05
# --------approximate solution path for # itr = 390 complete--------
# # itr: 390	 sup error: 8.797645568847656e-05
# --------approximate solution path for # itr = 400 complete--------
# # itr: 400	 sup error: 8.565187454223633e-05
# --------approximate solution path for # itr = 410 complete--------
# # itr: 410	 sup error: 8.26716423034668e-05
# diminish at iteration #417, new lr = 0.043365147562214865
# --------approximate solution path for # itr = 420 complete--------
# # itr: 420	 sup error: 8.082389831542969e-05
# --------approximate solution path for # itr = 430 complete--------
# # itr: 430	 sup error: 7.987022399902344e-05
# --------approximate solution path for # itr = 440 complete--------
# # itr: 440	 sup error: 7.912516593933105e-05
# --------approximate solution path for # itr = 450 complete--------
# # itr: 450	 sup error: 7.727742195129395e-05
# --------approximate solution path for # itr = 460 complete--------
# # itr: 460	 sup error: 7.471442222595215e-05
# --------approximate solution path for # itr = 470 complete--------
# # itr: 470	 sup error: 6.902217864990234e-05
# --------approximate solution path for # itr = 480 complete--------
# # itr: 480	 sup error: 6.443262100219727e-05
# --------approximate solution path for # itr = 490 complete--------
# # itr: 490	 sup error: 6.0886144638061523e-05
# --------approximate solution path for # itr = 500 complete--------
# # itr: 500	 sup error: 5.841255187988281e-05
# --------approximate solution path for # itr = 510 complete--------
# # itr: 510	 sup error: 5.6803226470947266e-05
# --------approximate solution path for # itr = 520 complete--------
# # itr: 520	 sup error: 5.5789947509765625e-05
# --------approximate solution path for # itr = 530 complete--------
# # itr: 530	 sup error: 5.334615707397461e-05
# --------approximate solution path for # itr = 540 complete--------
# # itr: 540	 sup error: 5.131959915161133e-05
# diminish at iteration #542, new lr = 0.04206419313534842
# --------approximate solution path for # itr = 550 complete--------
# # itr: 550	 sup error: 4.971027374267578e-05
# --------approximate solution path for # itr = 560 complete--------
# # itr: 560	 sup error: 4.869699478149414e-05
# --------approximate solution path for # itr = 570 complete--------
# # itr: 570	 sup error: 4.8100948333740234e-05
# --------approximate solution path for # itr = 580 complete--------
# # itr: 580	 sup error: 4.696846008300781e-05
# --------approximate solution path for # itr = 590 complete--------
# # itr: 590	 sup error: 4.506111145019531e-05
# --------approximate solution path for # itr = 600 complete--------
# # itr: 600	 sup error: 4.369020462036133e-05
# --------approximate solution path for # itr = 610 complete--------
# # itr: 610	 sup error: 4.190206527709961e-05
# --------approximate solution path for # itr = 620 complete--------
# # itr: 620	 sup error: 4.0978193283081055e-05
# --------approximate solution path for # itr = 630 complete--------
# # itr: 630	 sup error: 4.0650367736816406e-05
# --------approximate solution path for # itr = 640 complete--------
# # itr: 640	 sup error: 4.0471553802490234e-05
# --------approximate solution path for # itr = 650 complete--------
# # itr: 650	 sup error: 4.0471553802490234e-05
# --------approximate solution path for # itr = 660 complete--------
# # itr: 660	 sup error: 4.0471553802490234e-05
# --------approximate solution path for # itr = 670 complete--------
# # itr: 670	 sup error: 4.06801700592041e-05
# --------approximate solution path for # itr = 680 complete--------
# # itr: 680	 sup error: 3.975629806518555e-05
# --------approximate solution path for # itr = 690 complete--------
# # itr: 690	 sup error: 3.930926322937012e-05
# --------approximate solution path for # itr = 700 complete--------
# # itr: 700	 sup error: 3.916025161743164e-05
# diminish at iteration #705, new lr = 0.040802267341287966
# --------approximate solution path for # itr = 710 complete--------
# # itr: 710	 sup error: 3.921985626220703e-05
# --------approximate solution path for # itr = 720 complete--------
# # itr: 720	 sup error: 3.975629806518555e-05
# --------approximate solution path for # itr = 730 complete--------
# # itr: 730	 sup error: 4.0590763092041016e-05
# --------approximate solution path for # itr = 740 complete--------
# # itr: 740	 sup error: 4.166364669799805e-05
# --------approximate solution path for # itr = 750 complete--------
# # itr: 750	 sup error: 4.285573959350586e-05
# --------approximate solution path for # itr = 760 complete--------
# # itr: 760	 sup error: 4.315376281738281e-05
# --------approximate solution path for # itr = 770 complete--------
# # itr: 770	 sup error: 4.252791404724121e-05
# --------approximate solution path for # itr = 780 complete--------
# # itr: 780	 sup error: 4.1544437408447266e-05
# --------approximate solution path for # itr = 790 complete--------
# # itr: 790	 sup error: 4.062056541442871e-05
# --------approximate solution path for # itr = 800 complete--------
# # itr: 800	 sup error: 3.999471664428711e-05
# --------approximate solution path for # itr = 810 complete--------
# # itr: 810	 sup error: 3.9637088775634766e-05
# --------approximate solution path for # itr = 820 complete--------
# # itr: 820	 sup error: 3.975629806518555e-05
# --------approximate solution path for # itr = 830 complete--------
# # itr: 830	 sup error: 4.0203332901000977e-05
# --------approximate solution path for # itr = 840 complete--------
# # itr: 840	 sup error: 4.088878631591797e-05
# --------approximate solution path for # itr = 850 complete--------
# # itr: 850	 sup error: 4.190206527709961e-05
# --------approximate solution path for # itr = 860 complete--------
# # itr: 860	 sup error: 4.3064355850219727e-05
# --------approximate solution path for # itr = 870 complete--------
# # itr: 870	 sup error: 4.4286251068115234e-05
# --------approximate solution path for # itr = 880 complete--------
# # itr: 880	 sup error: 4.488229751586914e-05
# --------approximate solution path for # itr = 890 complete--------
# # itr: 890	 sup error: 4.419684410095215e-05
# --------approximate solution path for # itr = 900 complete--------
# # itr: 900	 sup error: 4.3898820877075195e-05
# --------approximate solution path for # itr = 910 complete--------
# # itr: 910	 sup error: 4.309415817260742e-05
# diminish at iteration #917, new lr = 0.03957819932104933
# --------approximate solution path for # itr = 920 complete--------
# # itr: 920	 sup error: 4.246830940246582e-05
# --------approximate solution path for # itr = 930 complete--------
# # itr: 930	 sup error: 4.217028617858887e-05
# --------approximate solution path for # itr = 940 complete--------
# # itr: 940	 sup error: 4.1991472244262695e-05
# --------approximate solution path for # itr = 950 complete--------
# # itr: 950	 sup error: 4.2051076889038086e-05
# --------approximate solution path for # itr = 960 complete--------
# # itr: 960	 sup error: 4.225969314575195e-05
# --------approximate solution path for # itr = 970 complete--------
# # itr: 970	 sup error: 4.079937934875488e-05
# --------approximate solution path for # itr = 980 complete--------
# # itr: 980	 sup error: 3.936886787414551e-05
# --------approximate solution path for # itr = 990 complete--------
# # itr: 990	 sup error: 3.808736801147461e-05
# --------approximate solution path for # itr = 1000 complete--------
# # itr: 1000	 sup error: 3.743171691894531e-05
# --------approximate solution path for # itr = 1010 complete--------
# # itr: 1010	 sup error: 3.6656856536865234e-05
# --------approximate solution path for # itr = 1020 complete--------
# # itr: 1020	 sup error: 3.618001937866211e-05
# --------approximate solution path for # itr = 1030 complete--------
# # itr: 1030	 sup error: 3.5703182220458984e-05
# --------approximate solution path for # itr = 1040 complete--------
# # itr: 1040	 sup error: 3.460049629211426e-05
# --------approximate solution path for # itr = 1050 complete--------
# # itr: 1050	 sup error: 3.406405448913574e-05
# --------approximate solution path for # itr = 1060 complete--------
# # itr: 1060	 sup error: 3.3736228942871094e-05
# --------approximate solution path for # itr = 1070 complete--------
# # itr: 1070	 sup error: 3.358721733093262e-05
# --------approximate solution path for # itr = 1080 complete--------
# # itr: 1080	 sup error: 3.3527612686157227e-05
# --------approximate solution path for # itr = 1090 complete--------
# # itr: 1090	 sup error: 3.3795833587646484e-05
# --------approximate solution path for # itr = 1100 complete--------
# # itr: 1100	 sup error: 3.427267074584961e-05
# --------approximate solution path for # itr = 1110 complete--------
# # itr: 1110	 sup error: 3.4749507904052734e-05
# --------approximate solution path for # itr = 1120 complete--------
# # itr: 1120	 sup error: 3.540515899658203e-05
# --------approximate solution path for # itr = 1130 complete--------
# # itr: 1130	 sup error: 3.618001937866211e-05
# --------approximate solution path for # itr = 1140 complete--------
# # itr: 1140	 sup error: 3.7044286727905273e-05
# --------approximate solution path for # itr = 1150 complete--------
# # itr: 1150	 sup error: 3.784894943237305e-05
# --------approximate solution path for # itr = 1160 complete--------
# # itr: 1160	 sup error: 3.737211227416992e-05
# --------approximate solution path for # itr = 1170 complete--------
# # itr: 1170	 sup error: 3.62396240234375e-05
# --------approximate solution path for # itr = 1180 complete--------
# # itr: 1180	 sup error: 3.528594970703125e-05
# --------approximate solution path for # itr = 1190 complete--------
# # itr: 1190	 sup error: 3.471970558166504e-05
# diminish at iteration #1192, new lr = 0.03839085334141785
# --------approximate solution path for # itr = 1200 complete--------
# # itr: 1200	 sup error: 3.4332275390625e-05
# --------approximate solution path for # itr = 1210 complete--------
# # itr: 1210	 sup error: 3.400444984436035e-05
# --------approximate solution path for # itr = 1220 complete--------
# # itr: 1220	 sup error: 3.400444984436035e-05
# --------approximate solution path for # itr = 1230 complete--------
# # itr: 1230	 sup error: 3.349781036376953e-05
# --------approximate solution path for # itr = 1240 complete--------
# # itr: 1240	 sup error: 3.293156623840332e-05
# --------approximate solution path for # itr = 1250 complete--------
# # itr: 1250	 sup error: 3.272294998168945e-05
# --------approximate solution path for # itr = 1260 complete--------
# # itr: 1260	 sup error: 3.2782554626464844e-05
# --------approximate solution path for # itr = 1270 complete--------
# # itr: 1270	 sup error: 3.2961368560791016e-05
# --------approximate solution path for # itr = 1280 complete--------
# # itr: 1280	 sup error: 3.3229589462280273e-05
# --------approximate solution path for # itr = 1290 complete--------
# # itr: 1290	 sup error: 3.311038017272949e-05
# --------approximate solution path for # itr = 1300 complete--------
# # itr: 1300	 sup error: 3.2395124435424805e-05
# --------approximate solution path for # itr = 1310 complete--------
# # itr: 1310	 sup error: 3.209710121154785e-05
# --------approximate solution path for # itr = 1320 complete--------
# # itr: 1320	 sup error: 3.209710121154785e-05
# --------approximate solution path for # itr = 1330 complete--------
# # itr: 1330	 sup error: 3.224611282348633e-05
# --------approximate solution path for # itr = 1340 complete--------
# # itr: 1340	 sup error: 3.24249267578125e-05
# --------approximate solution path for # itr = 1350 complete--------
# # itr: 1350	 sup error: 3.2454729080200195e-05
# --------approximate solution path for # itr = 1360 complete--------
# # itr: 1360	 sup error: 3.2335519790649414e-05
# --------approximate solution path for # itr = 1370 complete--------
# # itr: 1370	 sup error: 3.2454729080200195e-05
# --------approximate solution path for # itr = 1380 complete--------
# # itr: 1380	 sup error: 3.260374069213867e-05
# --------approximate solution path for # itr = 1390 complete--------
# # itr: 1390	 sup error: 3.2901763916015625e-05
# --------approximate solution path for # itr = 1400 complete--------
# # itr: 1400	 sup error: 3.3348798751831055e-05
# --------approximate solution path for # itr = 1410 complete--------
# # itr: 1410	 sup error: 3.3855438232421875e-05
# --------approximate solution path for # itr = 1420 complete--------
# # itr: 1420	 sup error: 3.427267074584961e-05
# --------approximate solution path for # itr = 1430 complete--------
# # itr: 1430	 sup error: 3.415346145629883e-05
# --------approximate solution path for # itr = 1440 complete--------
# # itr: 1440	 sup error: 3.412365913391113e-05
# --------approximate solution path for # itr = 1450 complete--------
# # itr: 1450	 sup error: 3.406405448913574e-05
# --------approximate solution path for # itr = 1460 complete--------
# # itr: 1460	 sup error: 3.364682197570801e-05
# --------approximate solution path for # itr = 1470 complete--------
# # itr: 1470	 sup error: 3.3348798751831055e-05
# --------approximate solution path for # itr = 1480 complete--------
# # itr: 1480	 sup error: 3.30507755279541e-05
# --------approximate solution path for # itr = 1490 complete--------
# # itr: 1490	 sup error: 3.287196159362793e-05
# --------approximate solution path for # itr = 1500 complete--------
# # itr: 1500	 sup error: 3.24249267578125e-05
# --------approximate solution path for # itr = 1510 complete--------
# # itr: 1510	 sup error: 3.197789192199707e-05
# --------approximate solution path for # itr = 1520 complete--------
# # itr: 1520	 sup error: 3.165006637573242e-05
# --------approximate solution path for # itr = 1530 complete--------
# # itr: 1530	 sup error: 3.1441450119018555e-05
# --------approximate solution path for # itr = 1540 complete--------
# # itr: 1540	 sup error: 3.126263618469238e-05
# diminish at iteration #1550, new lr = 0.03723912774117531
# --------approximate solution path for # itr = 1550 complete--------
# # itr: 1550	 sup error: 3.129243850708008e-05
# --------approximate solution path for # itr = 1560 complete--------
# # itr: 1560	 sup error: 3.1441450119018555e-05
# --------approximate solution path for # itr = 1570 complete--------
# # itr: 1570	 sup error: 3.11732292175293e-05
# --------approximate solution path for # itr = 1580 complete--------
# # itr: 1580	 sup error: 3.090500831604004e-05
# --------approximate solution path for # itr = 1590 complete--------
# # itr: 1590	 sup error: 3.0875205993652344e-05
# --------approximate solution path for # itr = 1600 complete--------
# # itr: 1600	 sup error: 3.096461296081543e-05
# --------approximate solution path for # itr = 1610 complete--------
# # itr: 1610	 sup error: 3.1054019927978516e-05
# --------approximate solution path for # itr = 1620 complete--------
# # itr: 1620	 sup error: 3.11732292175293e-05
# --------approximate solution path for # itr = 1630 complete--------
# # itr: 1630	 sup error: 3.141164779663086e-05
# --------approximate solution path for # itr = 1640 complete--------
# # itr: 1640	 sup error: 3.17692756652832e-05
# --------approximate solution path for # itr = 1650 complete--------
# # itr: 1650	 sup error: 3.224611282348633e-05
# --------approximate solution path for # itr = 1660 complete--------
# # itr: 1660	 sup error: 3.2454729080200195e-05
# --------approximate solution path for # itr = 1670 complete--------
# # itr: 1670	 sup error: 3.215670585632324e-05
# --------approximate solution path for # itr = 1680 complete--------
# # itr: 1680	 sup error: 3.185868263244629e-05
# --------approximate solution path for # itr = 1690 complete--------
# # itr: 1690	 sup error: 3.170967102050781e-05
# --------approximate solution path for # itr = 1700 complete--------
# # itr: 1700	 sup error: 3.170967102050781e-05
# --------approximate solution path for # itr = 1710 complete--------
# # itr: 1710	 sup error: 3.173947334289551e-05
# --------approximate solution path for # itr = 1720 complete--------
# # itr: 1720	 sup error: 3.167986869812012e-05
# --------approximate solution path for # itr = 1730 complete--------
# # itr: 1730	 sup error: 3.17692756652832e-05
# --------approximate solution path for # itr = 1740 complete--------
# # itr: 1740	 sup error: 3.170967102050781e-05
# --------approximate solution path for # itr = 1750 complete--------
# # itr: 1750	 sup error: 3.1560659408569336e-05
# --------approximate solution path for # itr = 1760 complete--------
# # itr: 1760	 sup error: 3.147125244140625e-05
# --------approximate solution path for # itr = 1770 complete--------
# # itr: 1770	 sup error: 3.1501054763793945e-05
# --------approximate solution path for # itr = 1780 complete--------
# # itr: 1780	 sup error: 3.167986869812012e-05
# --------approximate solution path for # itr = 1790 complete--------
# # itr: 1790	 sup error: 3.2007694244384766e-05
# --------approximate solution path for # itr = 1800 complete--------
# # itr: 1800	 sup error: 3.2335519790649414e-05
# --------approximate solution path for # itr = 1810 complete--------
# # itr: 1810	 sup error: 3.275275230407715e-05
# --------approximate solution path for # itr = 1820 complete--------
# # itr: 1820	 sup error: 3.316998481750488e-05
# --------approximate solution path for # itr = 1830 complete--------
# # itr: 1830	 sup error: 3.36766242980957e-05
# --------approximate solution path for # itr = 1840 complete--------
# # itr: 1840	 sup error: 3.4183263778686523e-05
# --------approximate solution path for # itr = 1850 complete--------
# # itr: 1850	 sup error: 3.471970558166504e-05
# --------approximate solution path for # itr = 1860 complete--------
# # itr: 1860	 sup error: 3.534555435180664e-05
# --------approximate solution path for # itr = 1870 complete--------
# # itr: 1870	 sup error: 3.600120544433594e-05
# --------approximate solution path for # itr = 1880 complete--------
# # itr: 1880	 sup error: 3.668665885925293e-05
# --------approximate solution path for # itr = 1890 complete--------
# # itr: 1890	 sup error: 3.7342309951782227e-05
# --------approximate solution path for # itr = 1900 complete--------
# # itr: 1900	 sup error: 3.802776336669922e-05
# --------approximate solution path for # itr = 1910 complete--------
# # itr: 1910	 sup error: 3.8564205169677734e-05
# --------approximate solution path for # itr = 1920 complete--------
# # itr: 1920	 sup error: 3.9130449295043945e-05
# --------approximate solution path for # itr = 1930 complete--------
# # itr: 1930	 sup error: 3.847479820251465e-05
# --------approximate solution path for # itr = 1940 complete--------
# # itr: 1940	 sup error: 3.808736801147461e-05
# --------approximate solution path for # itr = 1950 complete--------
# # itr: 1950	 sup error: 3.784894943237305e-05
# --------approximate solution path for # itr = 1960 complete--------
# # itr: 1960	 sup error: 3.7789344787597656e-05
# --------approximate solution path for # itr = 1970 complete--------
# # itr: 1970	 sup error: 3.725290298461914e-05
# --------approximate solution path for # itr = 1980 complete--------
# # itr: 1980	 sup error: 3.692507743835449e-05
# --------approximate solution path for # itr = 1990 complete--------
# # itr: 1990	 sup error: 3.6835670471191406e-05
# --------approximate solution path for # itr = 2000 complete--------
# # itr: 2000	 sup error: 3.680586814880371e-05

# %%
file_path = 'LSP_results_exact_fixed_basis.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

df['sup_err_7'] = sup_err_history

# Save the DataFrame to a CSV file
df.to_csv(file_path, index=False)

# %% [markdown]
# ## num basis func = 9

# %%
basis_dim = 9
init_lr = 0.0625

# %%
np.random.seed(8675309)
torch.manual_seed(8675309)

num_itr_history, sup_err_history, weight, lr = learn_solution_path(input_dim, basis_dim, phi_lam, max_epochs,
                                                               GD_data_loader, test_data_loader, loss_fn,
                                                               lam_min, lam_max, true_losses, init_lr=init_lr,
                                                               diminish=True, thresh_basis=thresh_basis,
                                                               record_frequency=10, distribution='uniform',
                                                               device=device, trace_frequency=10)
sup_err_history = np.array(sup_err_history)
# Out:
# diminish at iteration #4, new lr = 0.060625
# --------approximate solution path for # itr = 10 complete--------
# # itr: 10	 sup error: 0.8996663689613342
# --------approximate solution path for # itr = 20 complete--------
# # itr: 20	 sup error: 6.192219525575638
# diminish at iteration #23, new lr = 0.05880625
# diminish at iteration #30, new lr = 0.0570420625
# --------approximate solution path for # itr = 30 complete--------
# # itr: 30	 sup error: 5.673669129610062
# diminish at iteration #39, new lr = 0.055330800624999996
# --------approximate solution path for # itr = 40 complete--------
# # itr: 40	 sup error: 3.775999575853348
# --------approximate solution path for # itr = 50 complete--------
# # itr: 50	 sup error: 0.6472294330596924
# diminish at iteration #51, new lr = 0.053670876606249994
# --------approximate solution path for # itr = 60 complete--------
# # itr: 60	 sup error: 0.6392213702201843
# diminish at iteration #66, new lr = 0.052060750308062495
# --------approximate solution path for # itr = 70 complete--------
# # itr: 70	 sup error: 0.6293364763259888
# --------approximate solution path for # itr = 80 complete--------
# # itr: 80	 sup error: 0.5935081243515015
# diminish at iteration #86, new lr = 0.05049892779882062
# --------approximate solution path for # itr = 90 complete--------
# # itr: 90	 sup error: 0.5536090731620789
# --------approximate solution path for # itr = 100 complete--------
# # itr: 100	 sup error: 0.4824126362800598
# --------approximate solution path for # itr = 110 complete--------
# # itr: 110	 sup error: 0.37240904569625854
# diminish at iteration #112, new lr = 0.048983959964856
# --------approximate solution path for # itr = 120 complete--------
# # itr: 120	 sup error: 0.2941906452178955
# --------approximate solution path for # itr = 130 complete--------
# # itr: 130	 sup error: 0.23955494165420532
# --------approximate solution path for # itr = 140 complete--------
# # itr: 140	 sup error: 0.19060122966766357
# diminish at iteration #146, new lr = 0.04751444116591032
# --------approximate solution path for # itr = 150 complete--------
# # itr: 150	 sup error: 0.146083801984787
# --------approximate solution path for # itr = 160 complete--------
# # itr: 160	 sup error: 0.11321315169334412
# --------approximate solution path for # itr = 170 complete--------
# # itr: 170	 sup error: 0.08841991424560547
# --------approximate solution path for # itr = 180 complete--------
# # itr: 180	 sup error: 0.06996980309486389
# diminish at iteration #190, new lr = 0.046089007930933006
# --------approximate solution path for # itr = 190 complete--------
# # itr: 190	 sup error: 0.056107163429260254
# --------approximate solution path for # itr = 200 complete--------
# # itr: 200	 sup error: 0.04539111256599426
# --------approximate solution path for # itr = 210 complete--------
# # itr: 210	 sup error: 0.03702288866043091
# --------approximate solution path for # itr = 220 complete--------
# # itr: 220	 sup error: 0.030420005321502686
# --------approximate solution path for # itr = 230 complete--------
# # itr: 230	 sup error: 0.025177866220474243
# --------approximate solution path for # itr = 240 complete--------
# # itr: 240	 sup error: 0.02174752950668335
# diminish at iteration #247, new lr = 0.04470633769300501
# --------approximate solution path for # itr = 250 complete--------
# # itr: 250	 sup error: 0.019044071435928345
# --------approximate solution path for # itr = 260 complete--------
# # itr: 260	 sup error: 0.016764461994171143
# --------approximate solution path for # itr = 270 complete--------
# # itr: 270	 sup error: 0.014827072620391846
# --------approximate solution path for # itr = 280 complete--------
# # itr: 280	 sup error: 0.01310989260673523
# --------approximate solution path for # itr = 290 complete--------
# # itr: 290	 sup error: 0.011598646640777588
# --------approximate solution path for # itr = 300 complete--------
# # itr: 300	 sup error: 0.010301798582077026
# --------approximate solution path for # itr = 310 complete--------
# # itr: 310	 sup error: 0.009185433387756348
# --------approximate solution path for # itr = 320 complete--------
# # itr: 320	 sup error: 0.00814482569694519
# diminish at iteration #321, new lr = 0.043365147562214865
# --------approximate solution path for # itr = 330 complete--------
# # itr: 330	 sup error: 0.007237493991851807
# --------approximate solution path for # itr = 340 complete--------
# # itr: 340	 sup error: 0.0064484477043151855
# --------approximate solution path for # itr = 350 complete--------
# # itr: 350	 sup error: 0.005758613348007202
# --------approximate solution path for # itr = 360 complete--------
# # itr: 360	 sup error: 0.00515669584274292
# --------approximate solution path for # itr = 370 complete--------
# # itr: 370	 sup error: 0.004629969596862793
# --------approximate solution path for # itr = 380 complete--------
# # itr: 380	 sup error: 0.0041682422161102295
# --------approximate solution path for # itr = 390 complete--------
# # itr: 390	 sup error: 0.0037612318992614746
# --------approximate solution path for # itr = 400 complete--------
# # itr: 400	 sup error: 0.00340878963470459
# --------approximate solution path for # itr = 410 complete--------
# # itr: 410	 sup error: 0.0030961036682128906
# diminish at iteration #417, new lr = 0.04206419313534842
# --------approximate solution path for # itr = 420 complete--------
# # itr: 420	 sup error: 0.002817988395690918
# --------approximate solution path for # itr = 430 complete--------
# # itr: 430	 sup error: 0.002570033073425293
# --------approximate solution path for # itr = 440 complete--------
# # itr: 440	 sup error: 0.0023482143878936768
# --------approximate solution path for # itr = 450 complete--------
# # itr: 450	 sup error: 0.0021491646766662598
# --------approximate solution path for # itr = 460 complete--------
# # itr: 460	 sup error: 0.0019702911376953125
# --------approximate solution path for # itr = 470 complete--------
# # itr: 470	 sup error: 0.001809239387512207
# --------approximate solution path for # itr = 480 complete--------
# # itr: 480	 sup error: 0.0016642510890960693
# --------approximate solution path for # itr = 490 complete--------
# # itr: 490	 sup error: 0.0015344321727752686
# --------approximate solution path for # itr = 500 complete--------
# # itr: 500	 sup error: 0.0014164447784423828
# --------approximate solution path for # itr = 510 complete--------
# # itr: 510	 sup error: 0.0013092756271362305
# --------approximate solution path for # itr = 520 complete--------
# # itr: 520	 sup error: 0.0012118816375732422
# --------approximate solution path for # itr = 530 complete--------
# # itr: 530	 sup error: 0.0011231005191802979
# --------approximate solution path for # itr = 540 complete--------
# # itr: 540	 sup error: 0.001042187213897705
# diminish at iteration #542, new lr = 0.040802267341287966
# --------approximate solution path for # itr = 550 complete--------
# # itr: 550	 sup error: 0.0009683966636657715
# --------approximate solution path for # itr = 560 complete--------
# # itr: 560	 sup error: 0.0009009242057800293
# --------approximate solution path for # itr = 570 complete--------
# # itr: 570	 sup error: 0.0008389949798583984
# --------approximate solution path for # itr = 580 complete--------
# # itr: 580	 sup error: 0.0007828474044799805
# --------approximate solution path for # itr = 590 complete--------
# # itr: 590	 sup error: 0.0007314085960388184
# --------approximate solution path for # itr = 600 complete--------
# # itr: 600	 sup error: 0.000683903694152832
# --------approximate solution path for # itr = 610 complete--------
# # itr: 610	 sup error: 0.0006400346755981445
# --------approximate solution path for # itr = 620 complete--------
# # itr: 620	 sup error: 0.0005995333194732666
# --------approximate solution path for # itr = 630 complete--------
# # itr: 630	 sup error: 0.0005620718002319336
# --------approximate solution path for # itr = 640 complete--------
# # itr: 640	 sup error: 0.0005274415016174316
# --------approximate solution path for # itr = 650 complete--------
# # itr: 650	 sup error: 0.0004953145980834961
# --------approximate solution path for # itr = 660 complete--------
# # itr: 660	 sup error: 0.0004654526710510254
# --------approximate solution path for # itr = 670 complete--------
# # itr: 670	 sup error: 0.00043779611587524414
# --------approximate solution path for # itr = 680 complete--------
# # itr: 680	 sup error: 0.00041216611862182617
# --------approximate solution path for # itr = 690 complete--------
# # itr: 690	 sup error: 0.0003883838653564453
# --------approximate solution path for # itr = 700 complete--------
# # itr: 700	 sup error: 0.0003662705421447754
# diminish at iteration #705, new lr = 0.03957819932104933
# --------approximate solution path for # itr = 710 complete--------
# # itr: 710	 sup error: 0.00034558773040771484
# --------approximate solution path for # itr = 720 complete--------
# # itr: 720	 sup error: 0.0003262758255004883
# --------approximate solution path for # itr = 730 complete--------
# # itr: 730	 sup error: 0.0003084242343902588
# --------approximate solution path for # itr = 740 complete--------
# # itr: 740	 sup error: 0.00029164552688598633
# --------approximate solution path for # itr = 750 complete--------
# # itr: 750	 sup error: 0.00027629733085632324
# --------approximate solution path for # itr = 760 complete--------
# # itr: 760	 sup error: 0.0002619922161102295
# --------approximate solution path for # itr = 770 complete--------
# # itr: 770	 sup error: 0.0002485513687133789
# --------approximate solution path for # itr = 780 complete--------
# # itr: 780	 sup error: 0.0002359449863433838
# --------approximate solution path for # itr = 790 complete--------
# # itr: 790	 sup error: 0.00022405385971069336
# --------approximate solution path for # itr = 800 complete--------
# # itr: 800	 sup error: 0.00021284818649291992
# --------approximate solution path for # itr = 810 complete--------
# # itr: 810	 sup error: 0.00020229816436767578
# --------approximate solution path for # itr = 820 complete--------
# # itr: 820	 sup error: 0.00019234418869018555
# --------approximate solution path for # itr = 830 complete--------
# # itr: 830	 sup error: 0.00018298625946044922
# --------approximate solution path for # itr = 840 complete--------
# # itr: 840	 sup error: 0.0001741945743560791
# --------approximate solution path for # itr = 850 complete--------
# # itr: 850	 sup error: 0.00016582012176513672
# --------approximate solution path for # itr = 860 complete--------
# # itr: 860	 sup error: 0.00015795230865478516
# --------approximate solution path for # itr = 870 complete--------
# # itr: 870	 sup error: 0.00015050172805786133
# --------approximate solution path for # itr = 880 complete--------
# # itr: 880	 sup error: 0.00014340877532958984
# --------approximate solution path for # itr = 890 complete--------
# # itr: 890	 sup error: 0.00013682246208190918
# --------approximate solution path for # itr = 900 complete--------
# # itr: 900	 sup error: 0.0001310110092163086
# --------approximate solution path for # itr = 910 complete--------
# # itr: 910	 sup error: 0.00012552738189697266
# diminish at iteration #917, new lr = 0.03839085334141785
# --------approximate solution path for # itr = 920 complete--------
# # itr: 920	 sup error: 0.00012028217315673828
# --------approximate solution path for # itr = 930 complete--------
# # itr: 930	 sup error: 0.0001150965690612793
# --------approximate solution path for # itr = 940 complete--------
# # itr: 940	 sup error: 0.00011014938354492188
# --------approximate solution path for # itr = 950 complete--------
# # itr: 950	 sup error: 0.0001055002212524414
# --------approximate solution path for # itr = 960 complete--------
# # itr: 960	 sup error: 0.0001010596752166748
# --------approximate solution path for # itr = 970 complete--------
# # itr: 970	 sup error: 9.679794311523438e-05
# --------approximate solution path for # itr = 980 complete--------
# # itr: 980	 sup error: 9.277462959289551e-05
# --------approximate solution path for # itr = 990 complete--------
# # itr: 990	 sup error: 8.893013000488281e-05
# --------approximate solution path for # itr = 1000 complete--------
# # itr: 1000	 sup error: 8.529424667358398e-05
# --------approximate solution path for # itr = 1010 complete--------
# # itr: 1010	 sup error: 8.20159912109375e-05
# --------approximate solution path for # itr = 1020 complete--------
# # itr: 1020	 sup error: 7.876753807067871e-05
# --------approximate solution path for # itr = 1030 complete--------
# # itr: 1030	 sup error: 7.572770118713379e-05
# --------approximate solution path for # itr = 1040 complete--------
# # itr: 1040	 sup error: 7.280707359313965e-05
# --------approximate solution path for # itr = 1050 complete--------
# # itr: 1050	 sup error: 7.000565528869629e-05
# --------approximate solution path for # itr = 1060 complete--------
# # itr: 1060	 sup error: 6.73830509185791e-05
# --------approximate solution path for # itr = 1070 complete--------
# # itr: 1070	 sup error: 6.4849853515625e-05
# --------approximate solution path for # itr = 1080 complete--------
# # itr: 1080	 sup error: 6.246566772460938e-05
# --------approximate solution path for # itr = 1090 complete--------
# # itr: 1090	 sup error: 6.008148193359375e-05
# --------approximate solution path for # itr = 1100 complete--------
# # itr: 1100	 sup error: 5.7816505432128906e-05
# --------approximate solution path for # itr = 1110 complete--------
# # itr: 1110	 sup error: 5.564093589782715e-05
# --------approximate solution path for # itr = 1120 complete--------
# # itr: 1120	 sup error: 5.3554773330688477e-05
# --------approximate solution path for # itr = 1130 complete--------
# # itr: 1130	 sup error: 5.155801773071289e-05
# --------approximate solution path for # itr = 1140 complete--------
# # itr: 1140	 sup error: 4.965066909790039e-05
# --------approximate solution path for # itr = 1150 complete--------
# # itr: 1150	 sup error: 4.780292510986328e-05
# --------approximate solution path for # itr = 1160 complete--------
# # itr: 1160	 sup error: 4.601478576660156e-05
# --------approximate solution path for # itr = 1170 complete--------
# # itr: 1170	 sup error: 4.4345855712890625e-05
# --------approximate solution path for # itr = 1180 complete--------
# # itr: 1180	 sup error: 4.270672798156738e-05
# --------approximate solution path for # itr = 1190 complete--------
# # itr: 1190	 sup error: 4.124641418457031e-05
# diminish at iteration #1192, new lr = 0.03723912774117531
# --------approximate solution path for # itr = 1200 complete--------
# # itr: 1200	 sup error: 3.975629806518555e-05
# --------approximate solution path for # itr = 1210 complete--------
# # itr: 1210	 sup error: 3.832578659057617e-05
# --------approximate solution path for # itr = 1220 complete--------
# # itr: 1220	 sup error: 3.695487976074219e-05
# --------approximate solution path for # itr = 1230 complete--------
# # itr: 1230	 sup error: 3.5643577575683594e-05
# --------approximate solution path for # itr = 1240 complete--------
# # itr: 1240	 sup error: 3.439188003540039e-05
# --------approximate solution path for # itr = 1250 complete--------
# # itr: 1250	 sup error: 3.319978713989258e-05
# --------approximate solution path for # itr = 1260 complete--------
# # itr: 1260	 sup error: 3.2007694244384766e-05
# --------approximate solution path for # itr = 1270 complete--------
# # itr: 1270	 sup error: 3.0875205993652344e-05
# --------approximate solution path for # itr = 1280 complete--------
# # itr: 1280	 sup error: 2.9861927032470703e-05
# --------approximate solution path for # itr = 1290 complete--------
# # itr: 1290	 sup error: 2.8818845748901367e-05
# --------approximate solution path for # itr = 1300 complete--------
# # itr: 1300	 sup error: 2.7835369110107422e-05
# --------approximate solution path for # itr = 1310 complete--------
# # itr: 1310	 sup error: 2.6881694793701172e-05
# --------approximate solution path for # itr = 1320 complete--------
# # itr: 1320	 sup error: 2.5987625122070312e-05
# --------approximate solution path for # itr = 1330 complete--------
# # itr: 1330	 sup error: 2.5093555450439453e-05
# --------approximate solution path for # itr = 1340 complete--------
# # itr: 1340	 sup error: 2.4259090423583984e-05
# --------approximate solution path for # itr = 1350 complete--------
# # itr: 1350	 sup error: 2.3484230041503906e-05
# --------approximate solution path for # itr = 1360 complete--------
# # itr: 1360	 sup error: 2.2709369659423828e-05
# --------approximate solution path for # itr = 1370 complete--------
# # itr: 1370	 sup error: 2.1964311599731445e-05
# --------approximate solution path for # itr = 1380 complete--------
# # itr: 1380	 sup error: 2.1219253540039062e-05
# --------approximate solution path for # itr = 1390 complete--------
# # itr: 1390	 sup error: 2.0563602447509766e-05
# --------approximate solution path for # itr = 1400 complete--------
# # itr: 1400	 sup error: 1.9848346710205078e-05
# --------approximate solution path for # itr = 1410 complete--------
# # itr: 1410	 sup error: 1.9282102584838867e-05
# --------approximate solution path for # itr = 1420 complete--------
# # itr: 1420	 sup error: 1.868605613708496e-05
# --------approximate solution path for # itr = 1430 complete--------
# # itr: 1430	 sup error: 1.8090009689331055e-05
# --------approximate solution path for # itr = 1440 complete--------
# # itr: 1440	 sup error: 1.7523765563964844e-05
# --------approximate solution path for # itr = 1450 complete--------
# # itr: 1450	 sup error: 1.6987323760986328e-05
# --------approximate solution path for # itr = 1460 complete--------
# # itr: 1460	 sup error: 1.6480684280395508e-05
# --------approximate solution path for # itr = 1470 complete--------
# # itr: 1470	 sup error: 1.6033649444580078e-05
# --------approximate solution path for # itr = 1480 complete--------
# # itr: 1480	 sup error: 1.5616416931152344e-05
# --------approximate solution path for # itr = 1490 complete--------
# # itr: 1490	 sup error: 1.5169382095336914e-05
# --------approximate solution path for # itr = 1500 complete--------
# # itr: 1500	 sup error: 1.4781951904296875e-05
# --------approximate solution path for # itr = 1510 complete--------
# # itr: 1510	 sup error: 1.436471939086914e-05
# --------approximate solution path for # itr = 1520 complete--------
# # itr: 1520	 sup error: 1.3947486877441406e-05
# --------approximate solution path for # itr = 1530 complete--------
# # itr: 1530	 sup error: 1.3530254364013672e-05
# --------approximate solution path for # itr = 1540 complete--------
# # itr: 1540	 sup error: 1.3202428817749023e-05
# diminish at iteration #1550, new lr = 0.036121953908940053
# --------approximate solution path for # itr = 1550 complete--------
# # itr: 1550	 sup error: 1.2785196304321289e-05
# --------approximate solution path for # itr = 1560 complete--------
# # itr: 1560	 sup error: 1.245737075805664e-05
# --------approximate solution path for # itr = 1570 complete--------
# # itr: 1570	 sup error: 1.2159347534179688e-05
# --------approximate solution path for # itr = 1580 complete--------
# # itr: 1580	 sup error: 1.1861324310302734e-05
# --------approximate solution path for # itr = 1590 complete--------
# # itr: 1590	 sup error: 1.1533498764038086e-05
# --------approximate solution path for # itr = 1600 complete--------
# # itr: 1600	 sup error: 1.1265277862548828e-05
# --------approximate solution path for # itr = 1610 complete--------
# # itr: 1610	 sup error: 1.0967254638671875e-05
# --------approximate solution path for # itr = 1620 complete--------
# # itr: 1620	 sup error: 1.0669231414794922e-05
# --------approximate solution path for # itr = 1630 complete--------
# # itr: 1630	 sup error: 1.043081283569336e-05
# --------approximate solution path for # itr = 1640 complete--------
# # itr: 1640	 sup error: 1.0192394256591797e-05
# --------approximate solution path for # itr = 1650 complete--------
# # itr: 1650	 sup error: 9.894371032714844e-06
# --------approximate solution path for # itr = 1660 complete--------
# # itr: 1660	 sup error: 9.655952453613281e-06
# --------approximate solution path for # itr = 1670 complete--------
# # itr: 1670	 sup error: 9.47713851928711e-06
# --------approximate solution path for # itr = 1680 complete--------
# # itr: 1680	 sup error: 9.208917617797852e-06
# --------approximate solution path for # itr = 1690 complete--------
# # itr: 1690	 sup error: 9.000301361083984e-06
# --------approximate solution path for # itr = 1700 complete--------
# # itr: 1700	 sup error: 8.821487426757812e-06
# --------approximate solution path for # itr = 1710 complete--------
# # itr: 1710	 sup error: 8.58306884765625e-06
# --------approximate solution path for # itr = 1720 complete--------
# # itr: 1720	 sup error: 8.344650268554688e-06
# --------approximate solution path for # itr = 1730 complete--------
# # itr: 1730	 sup error: 8.165836334228516e-06
# --------approximate solution path for # itr = 1740 complete--------
# # itr: 1740	 sup error: 7.987022399902344e-06
# --------approximate solution path for # itr = 1750 complete--------
# # itr: 1750	 sup error: 7.808208465576172e-06
# --------approximate solution path for # itr = 1760 complete--------
# # itr: 1760	 sup error: 7.62939453125e-06
# --------approximate solution path for # itr = 1770 complete--------
# # itr: 1770	 sup error: 7.450580596923828e-06
# --------approximate solution path for # itr = 1780 complete--------
# # itr: 1780	 sup error: 7.271766662597656e-06
# --------approximate solution path for # itr = 1790 complete--------
# # itr: 1790	 sup error: 7.12275505065918e-06
# --------approximate solution path for # itr = 1800 complete--------
# # itr: 1800	 sup error: 6.9141387939453125e-06
# --------approximate solution path for # itr = 1810 complete--------
# # itr: 1810	 sup error: 6.794929504394531e-06
# --------approximate solution path for # itr = 1820 complete--------
# # itr: 1820	 sup error: 6.616115570068359e-06
# --------approximate solution path for # itr = 1830 complete--------
# # itr: 1830	 sup error: 6.467103958129883e-06
# --------approximate solution path for # itr = 1840 complete--------
# # itr: 1840	 sup error: 6.318092346191406e-06
# --------approximate solution path for # itr = 1850 complete--------
# # itr: 1850	 sup error: 6.16908073425293e-06
# --------approximate solution path for # itr = 1860 complete--------
# # itr: 1860	 sup error: 6.020069122314453e-06
# --------approximate solution path for # itr = 1870 complete--------
# # itr: 1870	 sup error: 5.841255187988281e-06
# --------approximate solution path for # itr = 1880 complete--------
# # itr: 1880	 sup error: 5.751848220825195e-06
# --------approximate solution path for # itr = 1890 complete--------
# # itr: 1890	 sup error: 5.602836608886719e-06
# --------approximate solution path for # itr = 1900 complete--------
# # itr: 1900	 sup error: 5.4836273193359375e-06
# --------approximate solution path for # itr = 1910 complete--------
# # itr: 1910	 sup error: 5.334615707397461e-06
# --------approximate solution path for # itr = 1920 complete--------
# # itr: 1920	 sup error: 5.245208740234375e-06
# --------approximate solution path for # itr = 1930 complete--------
# # itr: 1930	 sup error: 5.155801773071289e-06
# --------approximate solution path for # itr = 1940 complete--------
# # itr: 1940	 sup error: 5.066394805908203e-06
# --------approximate solution path for # itr = 1950 complete--------
# # itr: 1950	 sup error: 5.0067901611328125e-06
# --------approximate solution path for # itr = 1960 complete--------
# # itr: 1960	 sup error: 4.887580871582031e-06
# --------approximate solution path for # itr = 1970 complete--------
# # itr: 1970	 sup error: 4.76837158203125e-06
# --------approximate solution path for # itr = 1980 complete--------
# # itr: 1980	 sup error: 4.649162292480469e-06
# --------approximate solution path for # itr = 1990 complete--------
# # itr: 1990	 sup error: 4.589557647705078e-06
# --------approximate solution path for # itr = 2000 complete--------
# # itr: 2000	 sup error: 4.470348358154297e-06

# %%
file_path = 'LSP_results_exact_fixed_basis.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

df['sup_err_9'] = sup_err_history

# Save the DataFrame to a CSV file
df.to_csv(file_path, index=False)

# %% [markdown]
# # Noisy Gradient Oracle with $lr = \beta/\sqrt{t}$

# %% [markdown]
# Train the SGD model for our method using noisy gradient (mini-batch SGD) and record the sup error along the solution path ($\epsilon$) achieved after executing some number of gradient calls (epochs).
#
# We use a shrinking rate $lr = \beta/\sqrt{t}$ for previously tuned $\beta$.

# %%
max_epochs = 3000

# %%
phi_lam = scaled_shifted_legendre

# %%
# beta/sqrt(t)
def step_size(t, beta):
    return beta/np.sqrt(t+1)

# %%
def thresh_basis(basis_dim):
    return 1e-9

# %% [markdown]
# ## num basis func = 5

# %%
basis_dim = 5
beta = 0.5

# %%
np.random.seed(8675309)
torch.manual_seed(8675309)

num_itr_history, sup_err_history, weight, lr = learn_solution_path(input_dim, basis_dim, phi_lam, max_epochs,
                                                               SGD_data_loader, test_data_loader, loss_fn,
                                                               lam_min, lam_max, true_losses,
                                                              #  init_lr=init_lr,
                                                               step_size=step_size, const=beta, weighted_avg=True,
                                                               thresh_basis=1e-9,
                                                               record_frequency=10, distribution='uniform',
                                                               device=device, trace_frequency=100)
sup_err_history = np.array(sup_err_history)
# Out:
# --------approximate solution path for # itr = 100 complete--------
# # itr: 100	 sup error: 0.002113640308380127
# --------approximate solution path for # itr = 200 complete--------
# # itr: 200	 sup error: 0.0008128881454467773
# --------approximate solution path for # itr = 300 complete--------
# # itr: 300	 sup error: 0.0010091662406921387
# --------approximate solution path for # itr = 400 complete--------
# # itr: 400	 sup error: 0.0006948709487915039
# --------approximate solution path for # itr = 500 complete--------
# # itr: 500	 sup error: 0.0007435381412506104
# --------approximate solution path for # itr = 600 complete--------
# # itr: 600	 sup error: 0.0009127557277679443
# --------approximate solution path for # itr = 700 complete--------
# # itr: 700	 sup error: 0.0008178055286407471
# --------approximate solution path for # itr = 800 complete--------
# # itr: 800	 sup error: 0.0010140836238861084
# --------approximate solution path for # itr = 900 complete--------
# # itr: 900	 sup error: 0.001011669635772705
# --------approximate solution path for # itr = 1000 complete--------
# # itr: 1000	 sup error: 0.0009169578552246094
# --------approximate solution path for # itr = 1100 complete--------
# # itr: 1100	 sup error: 0.0008589327335357666
# --------approximate solution path for # itr = 1200 complete--------
# # itr: 1200	 sup error: 0.0008987486362457275
# --------approximate solution path for # itr = 1300 complete--------
# # itr: 1300	 sup error: 0.0009972155094146729
# --------approximate solution path for # itr = 1400 complete--------
# # itr: 1400	 sup error: 0.0010146796703338623
# --------approximate solution path for # itr = 1500 complete--------
# # itr: 1500	 sup error: 0.0010071992874145508
# --------approximate solution path for # itr = 1600 complete--------
# # itr: 1600	 sup error: 0.0010292530059814453
# --------approximate solution path for # itr = 1700 complete--------
# # itr: 1700	 sup error: 0.0010174214839935303
# --------approximate solution path for # itr = 1800 complete--------
# # itr: 1800	 sup error: 0.0010910332202911377
# --------approximate solution path for # itr = 1900 complete--------
# # itr: 1900	 sup error: 0.0010818839073181152
# --------approximate solution path for # itr = 2000 complete--------
# # itr: 2000	 sup error: 0.0010464191436767578
# --------approximate solution path for # itr = 2100 complete--------
# # itr: 2100	 sup error: 0.0009699463844299316
# --------approximate solution path for # itr = 2200 complete--------
# # itr: 2200	 sup error: 0.0009326040744781494
# --------approximate solution path for # itr = 2300 complete--------
# # itr: 2300	 sup error: 0.0009311437606811523
# --------approximate solution path for # itr = 2400 complete--------
# # itr: 2400	 sup error: 0.0008984506130218506
# --------approximate solution path for # itr = 2500 complete--------
# # itr: 2500	 sup error: 0.0009329319000244141
# --------approximate solution path for # itr = 2600 complete--------
# # itr: 2600	 sup error: 0.0009509623050689697
# --------approximate solution path for # itr = 2700 complete--------
# # itr: 2700	 sup error: 0.0009603202342987061
# --------approximate solution path for # itr = 2800 complete--------
# # itr: 2800	 sup error: 0.0009520053863525391
# --------approximate solution path for # itr = 2900 complete--------
# # itr: 2900	 sup error: 0.0009667277336120605
# --------approximate solution path for # itr = 3000 complete--------
# # itr: 3000	 sup error: 0.0009679794311523438

# %%
file_path = 'LSP_results_noisy_fixed_basis.csv'

LSP_results_exact_fixed_basis = pd.DataFrame(np.column_stack((num_itr_history, sup_err_history)), columns=['num_itr', 'sup_err_5'])

# Save the DataFrame to a CSV file
LSP_results_exact_fixed_basis.to_csv(file_path, index=False)

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Display the DataFrame
df
# Out:
#      num_itr  sup_err_5
# 0       10.0   0.113425
# 1       20.0   0.014235
# 2       30.0   0.006429
# 3       40.0   0.005368
# 4       50.0   0.007031
# ..       ...        ...
# 295   2960.0   0.000971
# 296   2970.0   0.000973
# 297   2980.0   0.000970
# 298   2990.0   0.000969
# 299   3000.0   0.000968
#
# [300 rows x 2 columns]

# %%
file_path = 'LSP_results_exact_fixed_basis.csv'

df = pd.read_csv(file_path)

# Add a new column for a different basis dimension
df['sup_err_5'] = sup_err_history

# Save the updated DataFrame back to the CSV file
df.to_csv(file_path, index=False)

# %% [markdown]
# ## num basis func = 7

# %%
basis_dim = 7
beta = 0.125

# %%
np.random.seed(8675309)
torch.manual_seed(8675309)

num_itr_history, sup_err_history, weight, lr = learn_solution_path(input_dim, basis_dim, phi_lam, max_epochs,
                                                               SGD_data_loader, test_data_loader, loss_fn,
                                                               lam_min, lam_max, true_losses,
                                                               step_size=step_size, const=beta, weighted_avg=True,
                                                               thresh_basis=thresh_basis,
                                                               record_frequency=10, distribution='uniform',
                                                               device=device, trace_frequency=100)
sup_err_history = np.array(sup_err_history)
# Out:
# --------approximate solution path for # itr = 100 complete--------
# # itr: 100	 sup error: 0.0057676732540130615
# --------approximate solution path for # itr = 200 complete--------
# # itr: 200	 sup error: 0.0025493204593658447
# --------approximate solution path for # itr = 300 complete--------
# # itr: 300	 sup error: 0.001119852066040039
# --------approximate solution path for # itr = 400 complete--------
# # itr: 400	 sup error: 0.0006137937307357788
# --------approximate solution path for # itr = 500 complete--------
# # itr: 500	 sup error: 0.0008137822151184082
# --------approximate solution path for # itr = 600 complete--------
# # itr: 600	 sup error: 0.0004491657018661499
# --------approximate solution path for # itr = 700 complete--------
# # itr: 700	 sup error: 0.00023087859153747559
# --------approximate solution path for # itr = 800 complete--------
# # itr: 800	 sup error: 0.00036960840225219727
# --------approximate solution path for # itr = 900 complete--------
# # itr: 900	 sup error: 0.00021415948867797852
# --------approximate solution path for # itr = 1000 complete--------
# # itr: 1000	 sup error: 0.00022751092910766602
# --------approximate solution path for # itr = 1100 complete--------
# # itr: 1100	 sup error: 0.00022810697555541992
# --------approximate solution path for # itr = 1200 complete--------
# # itr: 1200	 sup error: 0.0001719444990158081
# --------approximate solution path for # itr = 1300 complete--------
# # itr: 1300	 sup error: 0.00012148916721343994
# --------approximate solution path for # itr = 1400 complete--------
# # itr: 1400	 sup error: 0.00016450881958007812
# --------approximate solution path for # itr = 1500 complete--------
# # itr: 1500	 sup error: 0.00015729665756225586
# --------approximate solution path for # itr = 1600 complete--------
# # itr: 1600	 sup error: 9.074807167053223e-05
# --------approximate solution path for # itr = 1700 complete--------
# # itr: 1700	 sup error: 8.806586265563965e-05
# --------approximate solution path for # itr = 1800 complete--------
# # itr: 1800	 sup error: 8.830428123474121e-05
# --------approximate solution path for # itr = 1900 complete--------
# # itr: 1900	 sup error: 8.627772331237793e-05
# --------approximate solution path for # itr = 2000 complete--------
# # itr: 2000	 sup error: 9.098649024963379e-05
# --------approximate solution path for # itr = 2100 complete--------
# # itr: 2100	 sup error: 8.851289749145508e-05
# --------approximate solution path for # itr = 2200 complete--------
# # itr: 2200	 sup error: 9.757280349731445e-05
# --------approximate solution path for # itr = 2300 complete--------
# # itr: 2300	 sup error: 0.00011944770812988281
# --------approximate solution path for # itr = 2400 complete--------
# # itr: 2400	 sup error: 0.00013622641563415527
# --------approximate solution path for # itr = 2500 complete--------
# # itr: 2500	 sup error: 0.00011050701141357422
# --------approximate solution path for # itr = 2600 complete--------
# # itr: 2600	 sup error: 0.00010955333709716797
# --------approximate solution path for # itr = 2700 complete--------
# # itr: 2700	 sup error: 0.00011923909187316895
# --------approximate solution path for # itr = 2800 complete--------
# # itr: 2800	 sup error: 9.751319885253906e-05
# --------approximate solution path for # itr = 2900 complete--------
# # itr: 2900	 sup error: 7.861852645874023e-05
# --------approximate solution path for # itr = 3000 complete--------
# # itr: 3000	 sup error: 9.116530418395996e-05

# %%
file_path = 'LSP_results_exact_fixed_basis.csv'

df = pd.read_csv(file_path)

# Add a new column for a different basis dimension
df['sup_err_7'] = sup_err_history

# Save the updated DataFrame back to the CSV file
df.to_csv(file_path, index=False)

# %% [markdown]
# ## num basis func = 9

# %%
basis_dim = 9
beta = 0.0625

# %%
np.random.seed(8675309)
torch.manual_seed(8675309)

num_itr_history, sup_err_history, weight, lr = learn_solution_path(input_dim, basis_dim, phi_lam, max_epochs,
                                                               SGD_data_loader, test_data_loader, loss_fn,
                                                               lam_min, lam_max, true_losses,
                                                               step_size=step_size, const=beta, weighted_avg=True,
                                                               thresh_basis=thresh_basis,
                                                               record_frequency=10, distribution='uniform',
                                                               device=device, trace_frequency=100)
sup_err_history = np.array(sup_err_history)
# Out:
# --------approximate solution path for # itr = 100 complete--------
# # itr: 100	 sup error: 0.00862722098827362
# --------approximate solution path for # itr = 200 complete--------
# # itr: 200	 sup error: 0.0019429028034210205
# --------approximate solution path for # itr = 300 complete--------
# # itr: 300	 sup error: 0.0006385147571563721
# --------approximate solution path for # itr = 400 complete--------
# # itr: 400	 sup error: 0.0005068778991699219
# --------approximate solution path for # itr = 500 complete--------
# # itr: 500	 sup error: 0.0006736516952514648
# --------approximate solution path for # itr = 600 complete--------
# # itr: 600	 sup error: 0.0006954818964004517
# --------approximate solution path for # itr = 700 complete--------
# # itr: 700	 sup error: 0.00048214197158813477
# --------approximate solution path for # itr = 800 complete--------
# # itr: 800	 sup error: 0.00037291646003723145
# --------approximate solution path for # itr = 900 complete--------
# # itr: 900	 sup error: 0.0003770887851715088
# --------approximate solution path for # itr = 1000 complete--------
# # itr: 1000	 sup error: 0.0004097968339920044
# --------approximate solution path for # itr = 1100 complete--------
# # itr: 1100	 sup error: 0.00021645426750183105
# --------approximate solution path for # itr = 1200 complete--------
# # itr: 1200	 sup error: 0.0001577138900756836
# --------approximate solution path for # itr = 1300 complete--------
# # itr: 1300	 sup error: 0.00012737512588500977
# --------approximate solution path for # itr = 1400 complete--------
# # itr: 1400	 sup error: 0.00014519691467285156
# --------approximate solution path for # itr = 1500 complete--------
# # itr: 1500	 sup error: 0.00013785064220428467
# --------approximate solution path for # itr = 1600 complete--------
# # itr: 1600	 sup error: 0.0001240372657775879
# --------approximate solution path for # itr = 1700 complete--------
# # itr: 1700	 sup error: 0.00011608004570007324
# --------approximate solution path for # itr = 1800 complete--------
# # itr: 1800	 sup error: 0.000161096453666687
# --------approximate solution path for # itr = 1900 complete--------
# # itr: 1900	 sup error: 0.00022998452186584473
# --------approximate solution path for # itr = 2000 complete--------
# # itr: 2000	 sup error: 0.00029847025871276855
# --------approximate solution path for # itr = 2100 complete--------
# # itr: 2100	 sup error: 0.00033248960971832275
# --------approximate solution path for # itr = 2200 complete--------
# # itr: 2200	 sup error: 0.0002807825803756714
# --------approximate solution path for # itr = 2300 complete--------
# # itr: 2300	 sup error: 0.0002960711717605591
# --------approximate solution path for # itr = 2400 complete--------
# # itr: 2400	 sup error: 0.0002840757369995117
# --------approximate solution path for # itr = 2500 complete--------
# # itr: 2500	 sup error: 0.00025750696659088135
# --------approximate solution path for # itr = 2600 complete--------
# # itr: 2600	 sup error: 0.00024572014808654785
# --------approximate solution path for # itr = 2700 complete--------
# # itr: 2700	 sup error: 0.0002409517765045166
# --------approximate solution path for # itr = 2800 complete--------
# # itr: 2800	 sup error: 0.00024902820587158203
# --------approximate solution path for # itr = 2900 complete--------
# # itr: 2900	 sup error: 0.0002689063549041748
# --------approximate solution path for # itr = 3000 complete--------
# # itr: 3000	 sup error: 0.00023953616619110107

# %%
file_path = 'LSP_results_exact_fixed_basis.csv'

df = pd.read_csv(file_path)

# Add a new column for a different basis dimension
df['sup_err_9'] = sup_err_history

# Save the updated DataFrame back to the CSV file
df.to_csv(file_path, index=False)
