# %% [markdown]
# # Import necessary libraries

# %%
import numpy as np
import torch

device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
import importlib

# %% [markdown]
# ## Import our own modules

# %%
# !rm -r Learning-the-Optimal-Solution-Path
# !git clone https://github.com/Cumberkid/Learning-the-Optimal-Solution-Path.git
# Out:
# rm: cannot remove 'Learning-the-Optimal-Solution-Path': No such file or directory
# Cloning into 'Learning-the-Optimal-Solution-Path'...
# remote: Enumerating objects: 1734, done.
# remote: Counting objects: 100% (704/704), done.
# remote: Compressing objects: 100% (345/345), done.
# remote: Total 1734 (delta 534), reused 479 (delta 359), pack-reused 1030 (from 1)
# Receiving objects: 100% (1734/1734), 13.25 MiB | 4.59 MiB/s, done.
# Resolving deltas: 100% (1171/1171), done.

# %% [markdown]
# (Using Colab)

# %%
import sys

# %%
# Add the parent directory to sys.path
sys.path.append('/content/Learning-the-Optimal-Solution-Path')

# %%
import lib
importlib.reload(lib)
# Out:
# <module 'lib' from '/content/Learning-the-Optimal-Solution-Path/lib/__init__.py'>

# %%
from lib.fast_tensor_data_loader import FastTensorDataLoader
from lib.ngs.naive_grid_search import naive_grid_search
from lib.ngs.utils_ngs import get_sup_error
from lib.ngs.loss_fn import reg_unif_weighted_logit

# %% [markdown]
# # Load data

# %%
# file path for Colab. May need to change this
X_df = pd.read_csv('/content/Learning-the-Optimal-Solution-Path/experiments/fair-regression/data/X_processed.csv')
y_df = pd.read_csv('/content/Learning-the-Optimal-Solution-Path/experiments/fair-regression/data/y_processed.csv')

# %%
X = np.array(X_df)
y = np.array(y_df).squeeze()

# %%
train_X = torch.tensor(X, dtype=torch.float32)
train_y = torch.tensor(y, dtype=torch.float32)

# %%
# full gradient descent uses all data points
GD_data_loader = FastTensorDataLoader(train_X, train_y, batch_size=1000, shuffle=True, )
# stochastic gradient descent uses mini-batch
SGD_data_loader = FastTensorDataLoader(train_X, train_y, batch_size=20, shuffle=True, )
# test data
test_data_loader = FastTensorDataLoader(train_X, train_y, batch_size=1000, shuffle=False, )

# %%
lam_max = 1
lam_min = 0
input_dim = X.shape[1]

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import time

# %%
# Read the CSV file into a DataFrame
# truth = pd.read_csv('/content/Learning-the-Optimal-Solution-Path/experiments/fair-regression/results/exact_soln_list.csv')
truth = pd.read_csv('exact_soln_list_legendre.csv')

# Display the DataFrame
truth
# Out:
#         losses   theta_0   theta_1   theta_2   theta_3   theta_4   theta_5  \
# 0     0.190793 -0.373029  0.186622  0.227443 -0.023583  0.164822  0.142992
# 1     0.192130 -0.371212  0.186634  0.227586 -0.023679  0.164875  0.142262
# 2     0.193463 -0.369401  0.186645  0.227729 -0.023775  0.164927  0.141535
# 3     0.194792 -0.367595  0.186656  0.227870 -0.023870  0.164977  0.140811
# 4     0.196117 -0.365794  0.186665  0.228009 -0.023964  0.165027  0.140089
# ...        ...       ...       ...       ...       ...       ...       ...
# 1019  0.327684  0.692472 -0.029101 -0.033382 -0.017462 -0.005831 -0.225541
# 1020  0.325866  0.693930 -0.029932 -0.034521 -0.017548 -0.006565 -0.226194
# 1021  0.324032  0.695399 -0.030769 -0.035668 -0.017634 -0.007304 -0.226853
# 1022  0.322184  0.696878 -0.031613 -0.036822 -0.017720 -0.008050 -0.227517
# 1023  0.320320  0.698369 -0.032464 -0.037983 -0.017807 -0.008802 -0.228186
#
#        theta_6   theta_7   theta_8  ...  theta_36  theta_37  theta_38  \
# 0     0.168018  0.026305  0.142661  ... -0.018010  0.054908 -0.005629
# 1     0.167428  0.025960  0.142993  ... -0.017600  0.054199 -0.005657
# 2     0.166842  0.025615  0.143323  ... -0.017191  0.053493 -0.005685
# 3     0.166258  0.025271  0.143653  ... -0.016784  0.052790 -0.005713
# 4     0.165677  0.024927  0.143982  ... -0.016378  0.052089 -0.005741
# ...        ...       ...       ...  ...       ...       ...       ...
# 1019 -0.146453 -0.051680  0.070009  ...  0.105324 -0.201982  0.000913
# 1020 -0.148351 -0.051246  0.068693  ...  0.105340 -0.202186  0.000990
# 1021 -0.150274 -0.050809  0.067366  ...  0.105357 -0.202393  0.001066
# 1022 -0.152223 -0.050369  0.066028  ...  0.105374 -0.202601  0.001143
# 1023 -0.154196 -0.049927  0.064680  ...  0.105391 -0.202811  0.001220
#
#       theta_39  theta_40  theta_41  theta_42  theta_43  theta_44  theta_45
# 0     0.000000  0.000000 -0.031270 -0.018010 -0.139608 -0.116840 -0.061673
# 1     0.000069  0.000098 -0.031115 -0.017600 -0.139385 -0.116402 -0.061226
# 2     0.000137  0.000195 -0.030961 -0.017191 -0.139162 -0.115965 -0.060781
# 3     0.000205  0.000293 -0.030808 -0.016784 -0.138939 -0.115529 -0.060337
# 4     0.000273  0.000390 -0.030655 -0.016378 -0.138717 -0.115094 -0.059894
# ...        ...       ...       ...       ...       ...       ...       ...
# 1019  0.013100  0.018598  0.063129  0.105324  0.157442  0.161747  0.171301
# 1020  0.013040  0.018537  0.063366  0.105340  0.158131  0.162149  0.171464
# 1021  0.012980  0.018475  0.063604  0.105357  0.158825  0.162554  0.171627
# 1022  0.012919  0.018415  0.063843  0.105374  0.159523  0.162962  0.171792
# 1023  0.012859  0.018354  0.064084  0.105391  0.160226  0.163374  0.171958
#
# [1024 rows x 47 columns]

# %%
selected_columns = ['theta_0', 'theta_1', 'theta_2', 'theta_3', 'theta_4',
                    'theta_5', 'theta_6', 'theta_7', 'theta_8', 'theta_9',
                    'theta_10', 'theta_11', 'theta_12', 'theta_13', 'theta_14',
                    'theta_15', 'theta_16', 'theta_17', 'theta_18', 'theta_19',
                    'theta_20', 'theta_21', 'theta_22', 'theta_23', 'theta_24',
                    'theta_25', 'theta_26', 'theta_27', 'theta_28', 'theta_29',
                    'theta_30', 'theta_31', 'theta_32', 'theta_33', 'theta_34',
                    'theta_35', 'theta_36', 'theta_37', 'theta_38', 'theta_39',
                    'theta_40', 'theta_41', 'theta_42', 'theta_43', 'theta_44',
                    'theta_45']
true_thetas = truth[selected_columns].to_numpy()
true_losses = truth['losses'].to_numpy()

# %% [markdown]
# # Loss function

# %%
loss_fn = reg_unif_weighted_logit

# %% [markdown]
# # Exact Gradient

# %% [markdown]
# Use the previously tuned lr = 1.

# %%
lam_max = 1
lam_min = 0
lr = 1

# %% [markdown]
# ## Assume access to a true loss oracle

# %%
max_epochs = 1000
# a list of solution accuracy delta wish to be achieved
delta_list = 0.5 ** np.arange(6, 18, 0.5)

# %%
total_pass_list = []
sup_error_list = []
for delta in delta_list:
    # number of grids according to 1/sqrt(delta)
    num_grid = round(1 / np.sqrt(delta))

    start_time = time.time()
    total_pass, reg_params, intercepts, weights, grid_pass_error = naive_grid_search(lam_min=lam_min, lam_max=lam_max,
                                num_grid=num_grid, epochs=max_epochs, loss_fn=loss_fn,
                                trainDataLoader=GD_data_loader, data_input_dim=input_dim,
                                lr=lr, weighted_avg=False, testDataLoader=test_data_loader, oracle=True,
                                true_loss_list=true_losses, stopping_criterion=delta, check_frequency=5, device=device)

    end_time = time.time()
    execution_time = end_time - start_time

    total_pass_list.append(total_pass)

    sup_error = get_sup_error(lam_min, lam_max, true_losses, intercepts,
                                  weights, reg_params, test_data_loader, loss_fn, device)

    sup_error_list.append(sup_error)

    print(f"grid #: {num_grid}\t total passes #: {total_pass}\t sup error: {sup_error}\t Execution time: {execution_time} seconds")

total_itr_list = np.array(total_pass_list)
sup_error_list = np.array(sup_error_list)
# Out:
# grid #: 8	 total passes #: 40	 sup error: 0.03043559193611145	 Execution time: 0.13949203491210938 seconds
# grid #: 10	 total passes #: 50	 sup error: 0.019861072301864624	 Execution time: 0.1079564094543457 seconds
# grid #: 11	 total passes #: 55	 sup error: 0.01615923643112188	 Execution time: 0.1540083885192871 seconds
# grid #: 13	 total passes #: 65	 sup error: 0.011225312948226929	 Execution time: 0.15323305130004883 seconds
# grid #: 16	 total passes #: 80	 sup error: 0.007516980171203613	 Execution time: 0.23071551322937012 seconds
# grid #: 19	 total passes #: 95	 sup error: 0.005176275968551691	 Execution time: 0.17084145545959473 seconds
# grid #: 23	 total passes #: 115	 sup error: 0.003537416458129883	 Execution time: 0.21767306327819824 seconds
# grid #: 27	 total passes #: 140	 sup error: 0.0024376809597015936	 Execution time: 0.2464449405670166 seconds
# grid #: 32	 total passes #: 165	 sup error: 0.0017411112785339355	 Execution time: 0.29334378242492676 seconds
# grid #: 38	 total passes #: 195	 sup error: 0.0012416243553161621	 Execution time: 0.34172940254211426 seconds
# grid #: 45	 total passes #: 230	 sup error: 0.0008320212364196777	 Execution time: 0.4008040428161621 seconds
# grid #: 54	 total passes #: 275	 sup error: 0.000561982393264826	 Execution time: 0.5050091743469238 seconds
# grid #: 64	 total passes #: 325	 sup error: 0.00045558810234069824	 Execution time: 0.5980896949768066 seconds
# grid #: 76	 total passes #: 385	 sup error: 0.00035446882247930356	 Execution time: 0.700294017791748 seconds
# grid #: 91	 total passes #: 460	 sup error: 0.00023484230041509457	 Execution time: 1.1507258415222168 seconds
# grid #: 108	 total passes #: 545	 sup error: 0.00018799304962163754	 Execution time: 1.1499266624450684 seconds
# grid #: 128	 total passes #: 645	 sup error: 0.00012367963790899106	 Execution time: 1.1741549968719482 seconds
# grid #: 152	 total passes #: 765	 sup error: 7.110834121709653e-05	 Execution time: 1.352592945098877 seconds
# grid #: 181	 total passes #: 910	 sup error: 7.021427154546567e-05	 Execution time: 1.6330151557922363 seconds
# grid #: 215	 total passes #: 1080	 sup error: 3.25143337250311e-05	 Execution time: 1.9210119247436523 seconds
# grid #: 256	 total passes #: 1290	 sup error: 3.230571746826172e-05	 Execution time: 3.1418933868408203 seconds
# grid #: 304	 total passes #: 1530	 sup error: 3.05771827698309e-05	 Execution time: 2.7511744499206543 seconds
# grid #: 362	 total passes #: 1820	 sup error: 8.553266525268555e-06	 Execution time: 3.283445119857788 seconds
# grid #: 431	 total passes #: 2165	 sup error: 8.612871170043945e-06	 Execution time: 4.732988357543945 seconds

# %%
df = pd.DataFrame(np.column_stack((total_pass_list, sup_error_list)), columns=['num_itr', 'sup_err'])

# Save the DataFrame to a CSV file
df.to_csv('NGS_results_exact_oracle.csv', index=False)

# Read the CSV file into a DataFrame
df = pd.read_csv('NGS_results_exact_oracle.csv')

# %%
# plot result of learning the solution path
plt.figure(figsize=(10,10))
plt.plot(total_pass_list, np.log(sup_error_list), '--o')
plt.xlabel('# pass')
plt.ylabel('$\\log\\epsilon$')
plt.legend()
plt.grid(True)
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Assume no access to true loss

# %%
# a list of solution accuracy delta wish to be achieved
delta_list = 0.5 ** np.arange(6, 18, 0.5)

# %%
total_pass_list = []
sup_error_list = []
grid_error_list = []
for delta in delta_list:
    # number of grids according to 1/sqrt(delta)
    num_grid = round(1 / np.sqrt(delta))
    epochs = round(np.log(0.5/delta))

    # start_time = time.time()
    total_pass, reg_params, intercepts, weights, grid_pass_error = naive_grid_search(lam_min=lam_min, lam_max=lam_max,
                                num_grid=num_grid, epochs=epochs, loss_fn=loss_fn,
                                trainDataLoader=GD_data_loader, data_input_dim=input_dim,
                                lr=lr, weighted_avg=False, testDataLoader=test_data_loader,
                                oracle=False, true_loss_list=true_losses,
                                check_frequency=1, device=device)

    # end_time = time.time()
    # execution_time = end_time - start_time

    total_pass_list.append(total_pass)

    # solution path error
    sup_error = get_sup_error(lam_min, lam_max, true_losses, intercepts,
                                  weights, reg_params, test_data_loader, loss_fn, device)

    sup_error_list.append(sup_error)
    grid_error_list.append(grid_pass_error)
    # print(f"grid #: {num_grid}\t total iteration #: {total_itr}\t sup error: {sup_error}\t Execution time: {execution_time} seconds")
    print(f"grid #: {num_grid}\t total iteration #: {total_pass}\t sup error: {sup_error}\t grid error: {grid_pass_error}")

total_pass_list = np.array(total_pass_list)
sup_error_list = np.array(sup_error_list)
grid_error_list = np.array(grid_error_list)
# Out:
# grid #: 8	 total iteration #: 24	 sup error: 0.04880702495574957	 grid error: 0.021548405289649963
# grid #: 10	 total iteration #: 40	 sup error: 0.019930720329284668	 grid error: 0.008066773414611816
# grid #: 11	 total iteration #: 44	 sup error: 0.017006754875183105	 grid error: 0.00752180814743042
# grid #: 13	 total iteration #: 65	 sup error: 0.011225312948226929	 grid error: 0.0015870332717895508
# grid #: 16	 total iteration #: 80	 sup error: 0.007516980171203613	 grid error: 0.0015870332717895508
# grid #: 19	 total iteration #: 95	 sup error: 0.005176275968551691	 grid error: 0.0015870332717895508
# grid #: 23	 total iteration #: 138	 sup error: 0.004353463649749756	 grid error: 0.0021057724952697754
# grid #: 27	 total iteration #: 162	 sup error: 0.003331899642944336	 grid error: 0.0016693472862243652
# grid #: 32	 total iteration #: 192	 sup error: 0.002621889114379883	 grid error: 0.001382291316986084
# grid #: 38	 total iteration #: 266	 sup error: 0.0012104511260986328	 grid error: 0.0002323836088180542
# grid #: 45	 total iteration #: 315	 sup error: 0.0008720755577087402	 grid error: 0.0002323836088180542
# grid #: 54	 total iteration #: 378	 sup error: 0.0005871951580048163	 grid error: 0.0002323836088180542
# grid #: 64	 total iteration #: 512	 sup error: 0.0005472898483276367	 grid error: 0.0002683401107788086
# grid #: 76	 total iteration #: 608	 sup error: 0.0004016757011413574	 grid error: 0.00019443035125732422
# grid #: 91	 total iteration #: 728	 sup error: 0.0002766251564025879	 grid error: 0.0001450181007385254
# grid #: 108	 total iteration #: 972	 sup error: 0.00017821788787847348	 grid error: 4.309415817260742e-05
# grid #: 128	 total iteration #: 1152	 sup error: 0.00011613965034490414	 grid error: 4.3079257011413574e-05
# grid #: 152	 total iteration #: 1368	 sup error: 6.741285324102231e-05	 grid error: 4.3079257011413574e-05
# grid #: 181	 total iteration #: 1810	 sup error: 6.610155105596371e-05	 grid error: 2.276897430419922e-05
# grid #: 215	 total iteration #: 2150	 sup error: 3.3020973205566406e-05	 grid error: 1.940131187438965e-05
# grid #: 256	 total iteration #: 2560	 sup error: 2.995133399963379e-05	 grid error: 1.940131187438965e-05
# grid #: 304	 total iteration #: 3344	 sup error: 2.893805503850766e-05	 grid error: 8.985400199890137e-06
# grid #: 362	 total iteration #: 3982	 sup error: 9.000301361083984e-06	 grid error: 9.000301361083984e-06
# grid #: 431	 total iteration #: 4741	 sup error: 8.985400199890137e-06	 grid error: 8.985400199890137e-06

# %%
total_pass_list = []
sup_error_list = []
grid_error_list = []
for delta in delta_list:
    # number of grids according to 1/sqrt(delta)
    num_grid = round(1 / np.sqrt(delta))
    epochs = round(np.log(0.5/delta))

    # start_time = time.time()
    total_pass, reg_params, intercepts, weights, grid_pass_error = naive_grid_search(lam_min=lam_min, lam_max=lam_max,
                                num_grid=num_grid, epochs=epochs, loss_fn=loss_fn,
                                trainDataLoader=GD_data_loader, data_input_dim=input_dim,
                                lr=lr, weighted_avg=False, testDataLoader=test_data_loader,
                                oracle=False, true_loss_list=true_losses,
                                check_frequency=1, device=device)

    # end_time = time.time()
    # execution_time = end_time - start_time

    total_pass_list.append(total_pass)

    # solution path error
    sup_error = get_sup_error(lam_min, lam_max, true_losses, intercepts,
                                  weights, reg_params, test_data_loader, loss_fn, device)

    sup_error_list.append(sup_error)
    grid_error_list.append(grid_pass_error)
    # print(f"grid #: {num_grid}\t total iteration #: {total_itr}\t sup error: {sup_error}\t Execution time: {execution_time} seconds")
    print(f"grid #: {num_grid}\t total iteration #: {total_pass}\t sup error: {sup_error}\t grid error: {grid_pass_error}")

total_pass_list = np.array(total_pass_list)
sup_error_list = np.array(sup_error_list)
grid_error_list = np.array(grid_error_list)
# Out:
# grid #: 8	 total iteration #: 24	 sup error: 0.04880702495574957	 grid error: 0.021548405289649963
# grid #: 10	 total iteration #: 40	 sup error: 0.019930779933929443	 grid error: 0.008066833019256592
# grid #: 11	 total iteration #: 44	 sup error: 0.017006635665893555	 grid error: 0.007521867752075195
# grid #: 13	 total iteration #: 65	 sup error: 0.011225312948226929	 grid error: 0.0015870332717895508
# grid #: 16	 total iteration #: 80	 sup error: 0.007516980171203613	 grid error: 0.0015870332717895508
# grid #: 19	 total iteration #: 95	 sup error: 0.005176275968551691	 grid error: 0.0015870332717895508
# grid #: 23	 total iteration #: 138	 sup error: 0.004353463649749756	 grid error: 0.0021057724952697754
# grid #: 27	 total iteration #: 162	 sup error: 0.003331899642944336	 grid error: 0.0016693472862243652
# grid #: 32	 total iteration #: 192	 sup error: 0.002621889114379883	 grid error: 0.001382291316986084
# grid #: 38	 total iteration #: 266	 sup error: 0.0012104809284210205	 grid error: 0.00023236870765686035
# grid #: 45	 total iteration #: 315	 sup error: 0.0008721053600311279	 grid error: 0.00023236870765686035
# grid #: 54	 total iteration #: 378	 sup error: 0.0005871951580048163	 grid error: 0.0002323836088180542
# grid #: 64	 total iteration #: 512	 sup error: 0.0005473494529724121	 grid error: 0.0002683401107788086
# grid #: 76	 total iteration #: 608	 sup error: 0.00040161609649658203	 grid error: 0.00019437074661254883
# grid #: 91	 total iteration #: 728	 sup error: 0.0002766251564025879	 grid error: 0.00014507770538330078
# grid #: 108	 total iteration #: 972	 sup error: 0.00017821788787847348	 grid error: 4.312396049499512e-05
# grid #: 128	 total iteration #: 1152	 sup error: 0.00011616945266729184	 grid error: 4.312396049499512e-05
# grid #: 152	 total iteration #: 1368	 sup error: 6.741285324102231e-05	 grid error: 4.312396049499512e-05
# grid #: 181	 total iteration #: 1810	 sup error: 6.610155105596371e-05	 grid error: 2.276897430419922e-05
# grid #: 215	 total iteration #: 2150	 sup error: 3.3020973205566406e-05	 grid error: 1.940131187438965e-05
# grid #: 256	 total iteration #: 2560	 sup error: 2.995133399963379e-05	 grid error: 1.93864107131958e-05
# grid #: 304	 total iteration #: 3344	 sup error: 2.8908252716119964e-05	 grid error: 8.970499038696289e-06
# grid #: 362	 total iteration #: 3982	 sup error: 8.970499038696289e-06	 grid error: 8.970499038696289e-06
# grid #: 431	 total iteration #: 4741	 sup error: 8.970499038696289e-06	 grid error: 8.970499038696289e-06

# %%
df = pd.DataFrame(np.column_stack((total_pass_list, sup_error_list)), columns=['num_itr', 'sup_err'])

# Save the DataFrame to a CSV file
df.to_csv('NGS_results_exact.csv', index=False)

# Read the CSV file into a DataFrame
df = pd.read_csv('NGS_results_exact.csv')

# %%
# plot result of learning the solution path
plt.figure(figsize=(18,18))
plt.plot(total_pass_list, np.log10(sup_error_list), '--o', linewidth=8, markersize=20, label="solution path error")
plt.plot(total_pass_list, np.log10(grid_error_list), '--o', linewidth=8, markersize=20, label="grid pass error")
plt.plot(total_pass_list, np.log10(delta_list), '-', linewidth=50, label="ideal stopping criterion", alpha=0.35)

# Set global font size
mpl.rcParams['font.size'] = 55

font_size = 55
# Tick labels
plt.xticks(fontsize=font_size)
plt.yticks(fontsize=font_size)

# Legend, if applicable
plt.legend(fontsize=font_size)

plt.xlabel('# passage', fontsize=font_size)
plt.ylabel('Presented in $\\log_{10}$', fontsize=font_size)
plt.legend()
plt.grid(True)
plt.savefig("NGS_stopping_criterion_exact.png")

# %% [markdown]
# # Noisy Gradient Oracle Diminishing LR

# %% [markdown]
# Use the previously tuned diminishing factor $\beta = 1$ where lr = $\beta/\sqrt{T}$.

# %%
lam_max = 1
lam_min = 0
beta = 1

# %%
# beta/sqrt(t)
def step_size(t, beta):
    return beta/np.sqrt(t+1)

# %% [markdown]
# ## Assume access to a true loss oracle

# %%
max_epochs = 1000
# a list of solution accuracy delta wish to be achieved
delta_list = 0.5 ** np.arange(6, 12.6, 0.3)

# %%
total_pass_list = []
sup_error_list = []
np.random.seed(8675309)
torch.manual_seed(8675309)
for delta in delta_list:
    # number of grids according to 1/sqrt(delta)
    num_grid = round(1 / np.sqrt(delta))

    start_time = time.time()
    total_pass, reg_params, intercepts, weights, grid_pass_error = naive_grid_search(lam_min=lam_min, lam_max=lam_max,
                                num_grid=num_grid, epochs=max_epochs, loss_fn=loss_fn,
                                trainDataLoader=SGD_data_loader, data_input_dim=input_dim,
                                step_size=step_size, const=beta, weighted_avg=True, testDataLoader=test_data_loader,
                                oracle=True, true_loss_list=true_losses, stopping_criterion=delta,
                                                                   check_frequency=1, device=device)

    end_time = time.time()
    execution_time = end_time - start_time

    total_pass_list.append(total_pass)

    sup_error = get_sup_error(lam_min, lam_max, true_losses, intercepts,
                                  weights, reg_params, test_data_loader, loss_fn, device)

    sup_error_list.append(sup_error)

    print(f"grid #: {num_grid}\t total passes #: {total_pass}\t sup error: {sup_error}\t Execution time: {execution_time} seconds")

total_pass_list = np.array(total_pass_list)
sup_error_list = np.array(sup_error_list)
# Out:
# grid #: 8	 total passes #: 12	 sup error: 0.03675830364227295	 Execution time: 0.9347550868988037 seconds
# grid #: 9	 total passes #: 13	 sup error: 0.02425205707550049	 Execution time: 1.0331952571868896 seconds
# grid #: 10	 total passes #: 16	 sup error: 0.01890265941619873	 Execution time: 1.3155486583709717 seconds
# grid #: 11	 total passes #: 17	 sup error: 0.01885697245597845	 Execution time: 1.3724465370178223 seconds
# grid #: 12	 total passes #: 20	 sup error: 0.019037842750549372	 Execution time: 2.320213794708252 seconds
# grid #: 13	 total passes #: 26	 sup error: 0.010909885168075562	 Execution time: 2.137644052505493 seconds
# grid #: 15	 total passes #: 28	 sup error: 0.009801328182220459	 Execution time: 2.259530782699585 seconds
# grid #: 17	 total passes #: 37	 sup error: 0.009106874465942383	 Execution time: 2.9454667568206787 seconds
# grid #: 18	 total passes #: 41	 sup error: 0.005914747714996338	 Execution time: 3.6717426776885986 seconds
# grid #: 20	 total passes #: 55	 sup error: 0.0058519840240478516	 Execution time: 4.524609327316284 seconds
# grid #: 23	 total passes #: 69	 sup error: 0.005612075328826904	 Execution time: 6.4841907024383545 seconds
# grid #: 25	 total passes #: 82	 sup error: 0.004540830850601252	 Execution time: 6.728985786437988 seconds
# grid #: 28	 total passes #: 93	 sup error: 0.005124151706695612	 Execution time: 8.21475601196289 seconds
# grid #: 31	 total passes #: 106	 sup error: 0.003277719020843506	 Execution time: 9.63893723487854 seconds
# grid #: 34	 total passes #: 147	 sup error: 0.002979427576065119	 Execution time: 12.638858318328857 seconds
# grid #: 38	 total passes #: 158	 sup error: 0.0021113157272339422	 Execution time: 13.30636739730835 seconds
# grid #: 42	 total passes #: 201	 sup error: 0.001512527465820368	 Execution time: 16.912821054458618 seconds
# grid #: 47	 total passes #: 249	 sup error: 0.0013856291770935614	 Execution time: 21.463935375213623 seconds
# grid #: 52	 total passes #: 339	 sup error: 0.0011203587055206854	 Execution time: 30.359822988510132 seconds
# grid #: 58	 total passes #: 414	 sup error: 0.001174777746200617	 Execution time: 35.662906646728516 seconds
# grid #: 64	 total passes #: 546	 sup error: 0.0009424090385437012	 Execution time: 48.179213523864746 seconds
# grid #: 71	 total passes #: 683	 sup error: 0.0005475282669067383	 Execution time: 57.94365382194519 seconds

# %%
df = pd.DataFrame(np.column_stack((total_pass_list, sup_error_list)), columns=['num_itr', 'sup_err'])

# Save the DataFrame to a CSV file
df.to_csv('NGS_results_noisy_oracle.csv', index=False)

# Read the CSV file into a DataFrame
df = pd.read_csv('NGS_results_noisy_oracle.csv')

# %%
# plot result of learning the solution path
plt.figure(figsize=(10,10))
plt.plot(total_pass_list, np.log(sup_error_list), '--o', )
plt.ylabel('# passage')
plt.xlabel('$\\log\\epsilon$')
plt.legend()
plt.grid(True)

# %% [markdown]
# ## Assume no access to true loss

# %%
delta_list = 0.5 ** np.arange(6, 12.6, 0.3)

# %%
total_pass_list = []
sup_error_list = []
grid_error_list = []
np.random.seed(8675309)
torch.manual_seed(8675309)
for delta in delta_list:
    # number of grids according to 1/sqrt(delta)
    num_grid = round(1 / np.sqrt(delta))
    epochs = round(0.0019/(0.25*delta))

    # start_time = time.time()
    total_pass, reg_params, intercepts, weights, grid_pass_error = naive_grid_search(lam_min=lam_min, lam_max=lam_max,
                                num_grid=num_grid, epochs=epochs, loss_fn=loss_fn,
                                trainDataLoader=SGD_data_loader, data_input_dim=input_dim,
                                step_size=step_size, const=beta, weighted_avg=True, testDataLoader=test_data_loader,
                                oracle=False, true_loss_list=true_losses, check_frequency=1, device=device)

    # end_time = time.time()
    # execution_time = end_time - start_time

    total_pass_list.append(total_pass)

    # solution path error
    sup_error = get_sup_error(lam_min, lam_max, true_losses, intercepts,
                                  weights, reg_params, test_data_loader, loss_fn, device)
    sup_error_list.append(sup_error)

    # grid pass error
    grid_error_list.append(grid_pass_error)

    # print(f"grid #: {num_grid}\t total iteration #: {total_pass}\t sup error: {sup_error}\t Execution time: {execution_time} seconds")
    print(f"grid #: {num_grid}\t total pass #: {total_pass}\t sup error: {sup_error}\t grid pass error: {grid_pass_error}")

total_pass_list = np.array(total_pass_list)
sup_error_list = np.array(sup_error_list)
grid_error_list = np.array(grid_error_list)
# Out:
# grid #: 8	 total pass #: 0	 sup error: 0.5023539960384369	 grid pass error: 0
# grid #: 9	 total pass #: 9	 sup error: 0.07281601428985596	 grid pass error: 0.050116002559661865
# grid #: 10	 total pass #: 10	 sup error: 0.05904155969619751	 grid pass error: 0.04150956869125366
# grid #: 11	 total pass #: 11	 sup error: 0.06414851546287542	 grid pass error: 0.04934766888618475
# grid #: 12	 total pass #: 12	 sup error: 0.07216012477874756	 grid pass error: 0.053286164999008234
# grid #: 13	 total pass #: 13	 sup error: 0.06608879566192627	 grid pass error: 0.04987978935241699
# grid #: 15	 total pass #: 30	 sup error: 0.009993374347686768	 grid pass error: 0.005137920379638672
# grid #: 17	 total pass #: 34	 sup error: 0.018286466598510742	 grid pass error: 0.012959778308868408
# grid #: 18	 total pass #: 54	 sup error: 0.005941987037658691	 grid pass error: 0.003231555223464966
# grid #: 20	 total pass #: 60	 sup error: 0.0051024556159973145	 grid pass error: 0.00234144926071167
# grid #: 23	 total pass #: 92	 sup error: 0.004458248615264893	 grid pass error: 0.0027358233928680975
# grid #: 25	 total pass #: 125	 sup error: 0.0031073987483978827	 grid pass error: 0.0015318989753723145
# grid #: 28	 total pass #: 168	 sup error: 0.00236350297927862	 grid pass error: 0.0007322430610656738
# grid #: 31	 total pass #: 217	 sup error: 0.0021955370903015137	 grid pass error: 0.0012750625610351562
# grid #: 34	 total pass #: 306	 sup error: 0.0017014443874359686	 grid pass error: 0.0008751749992370605
# grid #: 38	 total pass #: 418	 sup error: 0.0013024210929870605	 grid pass error: 0.0004379749298095703
# grid #: 42	 total pass #: 588	 sup error: 0.0010901093482971747	 grid pass error: 0.00035268068313598633
# grid #: 47	 total pass #: 799	 sup error: 0.0007774233818054199	 grid pass error: 0.00040227174758911133
# grid #: 52	 total pass #: 1092	 sup error: 0.0006182491779327948	 grid pass error: 0.0002014636993408203
# grid #: 58	 total pass #: 1450	 sup error: 0.0005080699920654852	 grid pass error: 0.00019973516464233398
# grid #: 64	 total pass #: 1984	 sup error: 0.0004172325134277344	 grid pass error: 0.00013762712478637695
# grid #: 71	 total pass #: 2698	 sup error: 0.00037431716918950864	 grid pass error: 0.0001233816146850586

# %%
df = pd.DataFrame(np.column_stack((total_pass_list, sup_error_list)), columns=['num_itr', 'sup_err'])

# Save the DataFrame to a CSV file
df.to_csv('NGS_results_noisy.csv', index=False)

# Read the CSV file into a DataFrame
df = pd.read_csv('NGS_results_noisy.csv')

# %%
# plot result of learning the solution path
plt.figure(figsize=(18,18))
plt.plot(total_pass_list, np.log(sup_error_list), '--o', linewidth=8, markersize=20, label="solution path error")
plt.plot(total_pass_list, np.log(grid_error_list), '--o', linewidth=8, markersize=20, label="grid pass error")
plt.plot(total_pass_list, np.log(delta_list), '-', linewidth=50, label="ideal stopping criterion", alpha=0.35)

# Set global font size
mpl.rcParams['font.size'] = 55

font_size = 55
# Tick labels
plt.xticks(fontsize=font_size)
plt.yticks(fontsize=font_size)

# Legend, if applicable
plt.legend(fontsize=font_size)

plt.xlabel('# passes', fontsize=font_size)
plt.ylabel('$\\log\\epsilon$', fontsize=font_size)
plt.legend()
plt.grid(True)
plt.savefig("NGS_stopping_criterion_noisy.png")
# Out:
# <ipython-input-54-133865a46889>:4: RuntimeWarning: divide by zero encountered in log
#   plt.plot(total_pass_list, np.log(grid_error_list), '--o', linewidth=8, markersize=20, label="grid pass error")
