# %% [markdown]
# # 01 Import libraries

# %%
import numpy as np
import torch

device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
import pandas as pd

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import importlib

# %%
import lib
importlib.reload(lib)
# Out:
# <module 'lib' from 'c:\\Users\\dongq\\OneDrive\\Desktop\\New results\\Portfolio Allocation\\Learning-the-Optimal-Solution-Path\\lib\\__init__.py'>

# %%
from lib.lsp.basis_generator import scaled_shifted_legendre
from lib.lsp.basis_tf_module import Basis_TF_SGD
from lib.lsp.learn_solution_path import learn_solution_path
from lib.lsp.loss_fn_lsp import reg_unif_weighted_logit
from lib.fast_tensor_data_loader import FastTensorDataLoader
from lib.lsp.utils_lsp import get_errs_lsp

# %% [markdown]
# # 02 Instantiate dataset

# %%
# file path
X_df = pd.read_csv('X_processed.csv')
y_df = pd.read_csv('y_processed.csv')

# %%
X = np.array(X_df)
y = np.array(y_df).squeeze()

# %%
train_X = torch.tensor(X, dtype=torch.float32)
train_y = torch.tensor(y, dtype=torch.float32)

# %%
# full gradient descent uses all data points
GD_data_loader = FastTensorDataLoader(train_X, train_y, batch_size=1000, shuffle=True, )
# test data
test_data_loader = FastTensorDataLoader(train_X, train_y, batch_size=1000, shuffle=False, )

# %%
lam_max = [1]
lam_min = [0]
input_dim = X.shape[1]
loss_fn = reg_unif_weighted_logit

# %%
# Read the CSV file into a DataFrame
truth = pd.read_csv('exact_soln_list_legendre.csv')

# Display the DataFrame
truth
# Out:
#         losses   theta_0   theta_1   theta_2   theta_3   theta_4   theta_5  \
# 0     0.190793 -0.373029  0.186622  0.227443 -0.023583  0.164822  0.142992
# 1     0.192130 -0.371212  0.186634  0.227586 -0.023679  0.164875  0.142262
# 2     0.193463 -0.369401  0.186645  0.227729 -0.023775  0.164927  0.141535
# 3     0.194792 -0.367595  0.186656  0.227870 -0.023870  0.164977  0.140811
# 4     0.196117 -0.365794  0.186665  0.228009 -0.023964  0.165027  0.140089
# ...        ...       ...       ...       ...       ...       ...       ...
# 1019  0.327684  0.692472 -0.029101 -0.033382 -0.017462 -0.005831 -0.225541
# 1020  0.325866  0.693930 -0.029932 -0.034521 -0.017548 -0.006565 -0.226194
# 1021  0.324032  0.695399 -0.030769 -0.035668 -0.017634 -0.007304 -0.226853
# 1022  0.322184  0.696878 -0.031613 -0.036822 -0.017720 -0.008050 -0.227517
# 1023  0.320320  0.698369 -0.032464 -0.037983 -0.017807 -0.008802 -0.228186
#
#        theta_6   theta_7   theta_8  ...  theta_36  theta_37  theta_38  \
# 0     0.168018  0.026305  0.142661  ... -0.018010  0.054908 -0.005629
# 1     0.167428  0.025960  0.142993  ... -0.017600  0.054199 -0.005657
# 2     0.166842  0.025615  0.143323  ... -0.017191  0.053493 -0.005685
# 3     0.166258  0.025271  0.143653  ... -0.016784  0.052790 -0.005713
# 4     0.165677  0.024927  0.143982  ... -0.016378  0.052089 -0.005741
# ...        ...       ...       ...  ...       ...       ...       ...
# 1019 -0.146453 -0.051680  0.070009  ...  0.105324 -0.201982  0.000913
# 1020 -0.148351 -0.051246  0.068693  ...  0.105340 -0.202186  0.000990
# 1021 -0.150274 -0.050809  0.067366  ...  0.105357 -0.202393  0.001066
# 1022 -0.152223 -0.050369  0.066028  ...  0.105374 -0.202601  0.001143
# 1023 -0.154196 -0.049927  0.064680  ...  0.105391 -0.202811  0.001220
#
#       theta_39  theta_40  theta_41  theta_42  theta_43  theta_44  theta_45
# 0     0.000000  0.000000 -0.031270 -0.018010 -0.139608 -0.116840 -0.061673
# 1     0.000069  0.000098 -0.031115 -0.017600 -0.139385 -0.116402 -0.061226
# 2     0.000137  0.000195 -0.030961 -0.017191 -0.139162 -0.115965 -0.060781
# 3     0.000205  0.000293 -0.030808 -0.016784 -0.138939 -0.115529 -0.060337
# 4     0.000273  0.000390 -0.030655 -0.016378 -0.138717 -0.115094 -0.059894
# ...        ...       ...       ...       ...       ...       ...       ...
# 1019  0.013100  0.018598  0.063129  0.105324  0.157442  0.161747  0.171301
# 1020  0.013040  0.018537  0.063366  0.105340  0.158131  0.162149  0.171464
# 1021  0.012980  0.018475  0.063604  0.105357  0.158825  0.162554  0.171627
# 1022  0.012919  0.018415  0.063843  0.105374  0.159523  0.162962  0.171792
# 1023  0.012859  0.018354  0.064084  0.105391  0.160226  0.163374  0.171958
#
# [1024 rows x 47 columns]

# %%
selected_columns = ['theta_0', 'theta_1', 'theta_2', 'theta_3', 'theta_4',
                    'theta_5', 'theta_6', 'theta_7', 'theta_8', 'theta_9',
                    'theta_10', 'theta_11', 'theta_12', 'theta_13', 'theta_14',
                    'theta_15', 'theta_16', 'theta_17', 'theta_18', 'theta_19',
                    'theta_20', 'theta_21', 'theta_22', 'theta_23', 'theta_24',
                    'theta_25', 'theta_26', 'theta_27', 'theta_28', 'theta_29',
                    'theta_30', 'theta_31', 'theta_32', 'theta_33', 'theta_34',
                    'theta_35', 'theta_36', 'theta_37', 'theta_38', 'theta_39',
                    'theta_40', 'theta_41', 'theta_42', 'theta_43', 'theta_44',
                    'theta_45']
true_thetas = truth[selected_columns].to_numpy()
true_losses = truth['losses'].to_numpy()

# %% [markdown]
# # 03 Exact Gradient with Diminishing LR by Distance Diagnostic

# %% [markdown]
# Recall that our method runs SGD over random $\tilde λ$'s with a linear basis $\Phi(\tilde \lambda)$ of our choice. We want to approximate $\theta$ with $\Phi(\lambda)\beta$, so the objective function is $\min_\beta h(\Phi(\tilde\lambda)\beta, \tilde\lambda) = (1-\tilde\lambda) BCE(X_\text{pass}\Phi(\tilde\lambda)\beta,\ y_\text{pass}) + \tilde\lambda BCE(X_\text{fail}\Phi(\tilde\lambda)\beta,\ y_\text{fail})$. For each batch of training data set, we randomize $\tilde\lambda$.

# %% [markdown]
# We use diminishing learning rate for better demonstrate convergence. If we use a constant learning rate, the solution path error will eventually do a random walk after descending to a certain threshold value.
#
# Set weighted_avg to 'False' see this random walk.

# %%
max_epochs = 2000

# %%
phi_lam = scaled_shifted_legendre

# %%
def thresh_basis(basis_dim):
    return 1e-9

# %% [markdown]
# ## num basis func = 5

# %%
basis_dim = 5
init_lr = 0.125

# %%
np.random.seed(8675309)
torch.manual_seed(8675309)

num_itr_history, sup_err_history_last_itr, weight, lr, itr = learn_solution_path(input_dim, basis_dim, phi_lam, max_epochs,
                                                               GD_data_loader, test_data_loader, loss_fn,
                                                               lam_min, lam_max, true_losses, init_lr=init_lr,
                                                               diminish=True, thresh_basis=thresh_basis,
                                                               weighted_avg=False,
                                                               record_frequency=10, distribution='uniform',
                                                               device=device, trace_frequency=10)

sup_err_history_last_itr = np.array(sup_err_history_last_itr)
# Out:
# --------approximate solution path for # itr = 10 complete--------
# # epoch: 10	 sup error: 0.567403107881546
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 20	 sup error: 0.030949950218200684
# --------approximate solution path for # itr = 30 complete--------
# # epoch: 30	 sup error: 0.012224674224853516
# --------approximate solution path for # itr = 40 complete--------
# # epoch: 40	 sup error: 0.0041100382804870605
# --------approximate solution path for # itr = 50 complete--------
# # epoch: 50	 sup error: 0.002075016498565674
# --------approximate solution path for # itr = 60 complete--------
# # epoch: 60	 sup error: 0.0009251236915588379
# --------approximate solution path for # itr = 70 complete--------
# # epoch: 70	 sup error: 0.001246124505996704
# --------approximate solution path for # itr = 80 complete--------
# # epoch: 80	 sup error: 0.001986593008041382
# --------approximate solution path for # itr = 90 complete--------
# # epoch: 90	 sup error: 0.0009643435478210449
# --------approximate solution path for # itr = 100 complete--------
# # epoch: 100	 sup error: 0.0009657144546508789
# --------approximate solution path for # itr = 110 complete--------
# # epoch: 110	 sup error: 0.0008968710899353582
# --------approximate solution path for # itr = 120 complete--------
# # epoch: 120	 sup error: 0.0007880330085754395
# --------approximate solution path for # itr = 130 complete--------
# # epoch: 130	 sup error: 0.001124367117881775
# --------approximate solution path for # itr = 140 complete--------
# # epoch: 140	 sup error: 0.00048291683197021484
# --------approximate solution path for # itr = 150 complete--------
# # epoch: 150	 sup error: 0.00159376859664917
# --------approximate solution path for # itr = 160 complete--------
# # epoch: 160	 sup error: 0.0016896426677703857
# --------approximate solution path for # itr = 170 complete--------
# # epoch: 170	 sup error: 0.0006467700004577637
# --------approximate solution path for # itr = 180 complete--------
# # epoch: 180	 sup error: 0.0008105337619781494
# --------approximate solution path for # itr = 190 complete--------
# # epoch: 190	 sup error: 0.00047892332077026367
# --------approximate solution path for # itr = 200 complete--------
# # epoch: 200	 sup error: 0.0006931424140930176
# --------approximate solution path for # itr = 210 complete--------
# # epoch: 210	 sup error: 0.0006054043769836426
# --------approximate solution path for # itr = 220 complete--------
# # epoch: 220	 sup error: 0.0004423856735229492
# --------approximate solution path for # itr = 230 complete--------
# # epoch: 230	 sup error: 0.0006254613399505615
# --------approximate solution path for # itr = 240 complete--------
# # epoch: 240	 sup error: 0.000650405883789118
# --------approximate solution path for # itr = 250 complete--------
# # epoch: 250	 sup error: 0.0008370280265808661
# --------approximate solution path for # itr = 260 complete--------
# # epoch: 260	 sup error: 0.0008606612682343084
# --------approximate solution path for # itr = 270 complete--------
# # epoch: 270	 sup error: 0.0006014704704284668
# --------approximate solution path for # itr = 280 complete--------
# # epoch: 280	 sup error: 0.0011374056339263916
# --------approximate solution path for # itr = 290 complete--------
# # epoch: 290	 sup error: 0.0006362795829772949
# --------approximate solution path for # itr = 300 complete--------
# # epoch: 300	 sup error: 0.0006616115570068359
# --------approximate solution path for # itr = 310 complete--------
# # epoch: 310	 sup error: 0.0003932565450668335
# --------approximate solution path for # itr = 320 complete--------
# # epoch: 320	 sup error: 0.0009264349937438965
# --------approximate solution path for # itr = 330 complete--------
# # epoch: 330	 sup error: 0.001110672950744629
# --------approximate solution path for # itr = 340 complete--------
# # epoch: 340	 sup error: 0.001836538314819336
# --------approximate solution path for # itr = 350 complete--------
# # epoch: 350	 sup error: 0.002159714698791504
# --------approximate solution path for # itr = 360 complete--------
# # epoch: 360	 sup error: 0.002620309591293335
# --------approximate solution path for # itr = 370 complete--------
# # epoch: 370	 sup error: 0.0030155181884765625
# --------approximate solution path for # itr = 380 complete--------
# # epoch: 380	 sup error: 0.0017847120761871338
# --------approximate solution path for # itr = 390 complete--------
# # epoch: 390	 sup error: 0.0007198154926300049
# --------approximate solution path for # itr = 400 complete--------
# # epoch: 400	 sup error: 0.0007772743701934814
# --------approximate solution path for # itr = 410 complete--------
# # epoch: 410	 sup error: 0.0010712146759033203
# --------approximate solution path for # itr = 420 complete--------
# # epoch: 420	 sup error: 0.0018557310104370117
# --------approximate solution path for # itr = 430 complete--------
# # epoch: 430	 sup error: 0.0022491812705993652
# --------approximate solution path for # itr = 440 complete--------
# # epoch: 440	 sup error: 0.0022125244140625
# --------approximate solution path for # itr = 450 complete--------
# # epoch: 450	 sup error: 0.002727299928665161
# --------approximate solution path for # itr = 460 complete--------
# # epoch: 460	 sup error: 0.0026308000087738037
# --------approximate solution path for # itr = 470 complete--------
# # epoch: 470	 sup error: 0.003163546323776245
# --------approximate solution path for # itr = 480 complete--------
# # epoch: 480	 sup error: 0.002136528491973877
# --------approximate solution path for # itr = 490 complete--------
# # epoch: 490	 sup error: 0.0009531080722808838
# --------approximate solution path for # itr = 500 complete--------
# # epoch: 500	 sup error: 0.00130385160446167
# --------approximate solution path for # itr = 510 complete--------
# # epoch: 510	 sup error: 0.0016461610794067383
# --------approximate solution path for # itr = 520 complete--------
# # epoch: 520	 sup error: 0.0005041062831878662
# --------approximate solution path for # itr = 530 complete--------
# # epoch: 530	 sup error: 0.0007621049880981445
# --------approximate solution path for # itr = 540 complete--------
# # epoch: 540	 sup error: 0.0007127821445465088
# --------approximate solution path for # itr = 550 complete--------
# # epoch: 550	 sup error: 0.0014301836490631104
# --------approximate solution path for # itr = 560 complete--------
# # epoch: 560	 sup error: 0.0010596513748168945
# --------approximate solution path for # itr = 570 complete--------
# # epoch: 570	 sup error: 0.0010388493537902832
# --------approximate solution path for # itr = 580 complete--------
# # epoch: 580	 sup error: 0.000838547945022583
# --------approximate solution path for # itr = 590 complete--------
# # epoch: 590	 sup error: 0.0010396242141723633
# --------approximate solution path for # itr = 600 complete--------
# # epoch: 600	 sup error: 0.0011653900146484375
# --------approximate solution path for # itr = 610 complete--------
# # epoch: 610	 sup error: 0.0005922019481658936
# --------approximate solution path for # itr = 620 complete--------
# # epoch: 620	 sup error: 0.0003624856472015381
# --------approximate solution path for # itr = 630 complete--------
# # epoch: 630	 sup error: 0.0004302561283111572
# --------approximate solution path for # itr = 640 complete--------
# # epoch: 640	 sup error: 0.0006994307041168213
# --------approximate solution path for # itr = 650 complete--------
# # epoch: 650	 sup error: 0.0009349584579467773
# --------approximate solution path for # itr = 660 complete--------
# # epoch: 660	 sup error: 0.000771254301071167
# --------approximate solution path for # itr = 670 complete--------
# # epoch: 670	 sup error: 0.001001119613647461
# --------approximate solution path for # itr = 680 complete--------
# # epoch: 680	 sup error: 0.0015508830547332764
# --------approximate solution path for # itr = 690 complete--------
# # epoch: 690	 sup error: 0.0014951527118682861
# --------approximate solution path for # itr = 700 complete--------
# # epoch: 700	 sup error: 0.0019189715385437012
# --------approximate solution path for # itr = 710 complete--------
# # epoch: 710	 sup error: 0.0018387436866760254
# --------approximate solution path for # itr = 720 complete--------
# # epoch: 720	 sup error: 0.0023031234741210938
# --------approximate solution path for # itr = 730 complete--------
# # epoch: 730	 sup error: 0.002787351608276367
# --------approximate solution path for # itr = 740 complete--------
# # epoch: 740	 sup error: 0.0029792487621307373
# --------approximate solution path for # itr = 750 complete--------
# # epoch: 750	 sup error: 0.0031545162200927734
# --------approximate solution path for # itr = 760 complete--------
# # epoch: 760	 sup error: 0.0033394694328308105
# --------approximate solution path for # itr = 770 complete--------
# # epoch: 770	 sup error: 0.0026827454566955566
# --------approximate solution path for # itr = 780 complete--------
# # epoch: 780	 sup error: 0.0017398297786712646
# --------approximate solution path for # itr = 790 complete--------
# # epoch: 790	 sup error: 0.0015040040016174316
# --------approximate solution path for # itr = 800 complete--------
# # epoch: 800	 sup error: 0.0015202760696411133
# --------approximate solution path for # itr = 810 complete--------
# # epoch: 810	 sup error: 0.0016642510890960693
# --------approximate solution path for # itr = 820 complete--------
# # epoch: 820	 sup error: 0.0019132792949676514
# --------approximate solution path for # itr = 830 complete--------
# # epoch: 830	 sup error: 0.0023111701011657715
# --------approximate solution path for # itr = 840 complete--------
# # epoch: 840	 sup error: 0.0007807314395904541
# --------approximate solution path for # itr = 850 complete--------
# # epoch: 850	 sup error: 0.0005168914794921875
# --------approximate solution path for # itr = 860 complete--------
# # epoch: 860	 sup error: 0.000569760799407959
# --------approximate solution path for # itr = 870 complete--------
# # epoch: 870	 sup error: 0.0005850791931152344
# --------approximate solution path for # itr = 880 complete--------
# # epoch: 880	 sup error: 0.0005206316709518433
# --------approximate solution path for # itr = 890 complete--------
# # epoch: 890	 sup error: 0.0004723668098450262
# --------approximate solution path for # itr = 900 complete--------
# # epoch: 900	 sup error: 0.0004495084285736084
# --------approximate solution path for # itr = 910 complete--------
# # epoch: 910	 sup error: 0.0007649362087249756
# --------approximate solution path for # itr = 920 complete--------
# # epoch: 920	 sup error: 0.0013443827629089355
# --------approximate solution path for # itr = 930 complete--------
# # epoch: 930	 sup error: 0.0015031993389129639
# --------approximate solution path for # itr = 940 complete--------
# # epoch: 940	 sup error: 0.000665515661239624
# --------approximate solution path for # itr = 950 complete--------
# # epoch: 950	 sup error: 0.001062840223312378
# --------approximate solution path for # itr = 960 complete--------
# # epoch: 960	 sup error: 0.0015221238136291504
# --------approximate solution path for # itr = 970 complete--------
# # epoch: 970	 sup error: 0.0020669102668762207
# --------approximate solution path for # itr = 980 complete--------
# # epoch: 980	 sup error: 0.0007635354995727539
# --------approximate solution path for # itr = 990 complete--------
# # epoch: 990	 sup error: 0.0012540221214294434
# --------approximate solution path for # itr = 1000 complete--------
# # epoch: 1000	 sup error: 0.0016646981239318848
# --------approximate solution path for # itr = 1010 complete--------
# # epoch: 1010	 sup error: 0.0005235970020294189
# --------approximate solution path for # itr = 1020 complete--------
# # epoch: 1020	 sup error: 0.0008346438407897949
# --------approximate solution path for # itr = 1030 complete--------
# # epoch: 1030	 sup error: 0.0010786354541778564
# --------approximate solution path for # itr = 1040 complete--------
# # epoch: 1040	 sup error: 0.0017840862274169922
# --------approximate solution path for # itr = 1050 complete--------
# # epoch: 1050	 sup error: 0.00039309263229370117
# --------approximate solution path for # itr = 1060 complete--------
# # epoch: 1060	 sup error: 0.00043767690658569336
# --------approximate solution path for # itr = 1070 complete--------
# # epoch: 1070	 sup error: 0.0009077489376068115
# --------approximate solution path for # itr = 1080 complete--------
# # epoch: 1080	 sup error: 0.0005547106266022284
# --------approximate solution path for # itr = 1090 complete--------
# # epoch: 1090	 sup error: 0.0005265772342681885
# --------approximate solution path for # itr = 1100 complete--------
# # epoch: 1100	 sup error: 0.0008698105812072754
# --------approximate solution path for # itr = 1110 complete--------
# # epoch: 1110	 sup error: 0.0014502406120300293
# --------approximate solution path for # itr = 1120 complete--------
# # epoch: 1120	 sup error: 0.0020219087600708008
# --------approximate solution path for # itr = 1130 complete--------
# # epoch: 1130	 sup error: 0.0004443228244781494
# --------approximate solution path for # itr = 1140 complete--------
# # epoch: 1140	 sup error: 0.000661313533782959
# --------approximate solution path for # itr = 1150 complete--------
# # epoch: 1150	 sup error: 0.0009353756904602051
# --------approximate solution path for # itr = 1160 complete--------
# # epoch: 1160	 sup error: 0.0011855363845825195
# --------approximate solution path for # itr = 1170 complete--------
# # epoch: 1170	 sup error: 0.0014743208885192871
# --------approximate solution path for # itr = 1180 complete--------
# # epoch: 1180	 sup error: 0.0013499259948730469
# --------approximate solution path for # itr = 1190 complete--------
# # epoch: 1190	 sup error: 0.0017576813697814941
# --------approximate solution path for # itr = 1200 complete--------
# # epoch: 1200	 sup error: 0.0022194087505340576
# --------approximate solution path for # itr = 1210 complete--------
# # epoch: 1210	 sup error: 0.0012821555137634277
# --------approximate solution path for # itr = 1220 complete--------
# # epoch: 1220	 sup error: 0.0019137263298034668
# --------approximate solution path for # itr = 1230 complete--------
# # epoch: 1230	 sup error: 0.00038546323776245117
# --------approximate solution path for # itr = 1240 complete--------
# # epoch: 1240	 sup error: 0.0004628896713256836
# --------approximate solution path for # itr = 1250 complete--------
# # epoch: 1250	 sup error: 0.0008800029754638672
# --------approximate solution path for # itr = 1260 complete--------
# # epoch: 1260	 sup error: 0.0009780824184417725
# --------approximate solution path for # itr = 1270 complete--------
# # epoch: 1270	 sup error: 0.0012491941452026367
# --------approximate solution path for # itr = 1280 complete--------
# # epoch: 1280	 sup error: 0.0012023448944091797
# --------approximate solution path for # itr = 1290 complete--------
# # epoch: 1290	 sup error: 0.0013195574283599854
# --------approximate solution path for # itr = 1300 complete--------
# # epoch: 1300	 sup error: 0.0006298422813415527
# --------approximate solution path for # itr = 1310 complete--------
# # epoch: 1310	 sup error: 0.0011681914329528809
# --------approximate solution path for # itr = 1320 complete--------
# # epoch: 1320	 sup error: 0.0009899884462356567
# --------approximate solution path for # itr = 1330 complete--------
# # epoch: 1330	 sup error: 0.00031179189682006836
# --------approximate solution path for # itr = 1340 complete--------
# # epoch: 1340	 sup error: 0.0008827149868011475
# --------approximate solution path for # itr = 1350 complete--------
# # epoch: 1350	 sup error: 0.0011665523052215576
# --------approximate solution path for # itr = 1360 complete--------
# # epoch: 1360	 sup error: 0.0005058944225311279
# --------approximate solution path for # itr = 1370 complete--------
# # epoch: 1370	 sup error: 0.0010346174240112305
# --------approximate solution path for # itr = 1380 complete--------
# # epoch: 1380	 sup error: 0.001202315092086792
# --------approximate solution path for # itr = 1390 complete--------
# # epoch: 1390	 sup error: 0.0013371109962463379
# --------approximate solution path for # itr = 1400 complete--------
# # epoch: 1400	 sup error: 0.001770317554473877
# --------approximate solution path for # itr = 1410 complete--------
# # epoch: 1410	 sup error: 0.0017620325088500977
# --------approximate solution path for # itr = 1420 complete--------
# # epoch: 1420	 sup error: 0.0018482208251953125
# --------approximate solution path for # itr = 1430 complete--------
# # epoch: 1430	 sup error: 0.0024681687355041504
# --------approximate solution path for # itr = 1440 complete--------
# # epoch: 1440	 sup error: 0.0029497146606445312
# --------approximate solution path for # itr = 1450 complete--------
# # epoch: 1450	 sup error: 0.0022659897804260254
# --------approximate solution path for # itr = 1460 complete--------
# # epoch: 1460	 sup error: 0.0027955174446105957
# --------approximate solution path for # itr = 1470 complete--------
# # epoch: 1470	 sup error: 0.0029016435146331787
# --------approximate solution path for # itr = 1480 complete--------
# # epoch: 1480	 sup error: 0.000359803438186701
# --------approximate solution path for # itr = 1490 complete--------
# # epoch: 1490	 sup error: 0.0005206465721130371
# --------approximate solution path for # itr = 1500 complete--------
# # epoch: 1500	 sup error: 0.0009819865226745605
# --------approximate solution path for # itr = 1510 complete--------
# # epoch: 1510	 sup error: 0.0009715557098388672
# --------approximate solution path for # itr = 1520 complete--------
# # epoch: 1520	 sup error: 0.0013254880905151367
# --------approximate solution path for # itr = 1530 complete--------
# # epoch: 1530	 sup error: 0.0015715956687927246
# --------approximate solution path for # itr = 1540 complete--------
# # epoch: 1540	 sup error: 0.0011063218116760254
# --------approximate solution path for # itr = 1550 complete--------
# # epoch: 1550	 sup error: 0.001367121934890747
# --------approximate solution path for # itr = 1560 complete--------
# # epoch: 1560	 sup error: 0.0006409883499146063
# --------approximate solution path for # itr = 1570 complete--------
# # epoch: 1570	 sup error: 0.0006743073463439941
# --------approximate solution path for # itr = 1580 complete--------
# # epoch: 1580	 sup error: 0.0007149577140808105
# --------approximate solution path for # itr = 1590 complete--------
# # epoch: 1590	 sup error: 0.0011082589626312256
# --------approximate solution path for # itr = 1600 complete--------
# # epoch: 1600	 sup error: 0.0013154447078704834
# --------approximate solution path for # itr = 1610 complete--------
# # epoch: 1610	 sup error: 0.0004247128963470459
# --------approximate solution path for # itr = 1620 complete--------
# # epoch: 1620	 sup error: 0.0012052059173583984
# --------approximate solution path for # itr = 1630 complete--------
# # epoch: 1630	 sup error: 0.001716017723083496
# --------approximate solution path for # itr = 1640 complete--------
# # epoch: 1640	 sup error: 0.0021826326847076416
# --------approximate solution path for # itr = 1650 complete--------
# # epoch: 1650	 sup error: 0.002414226531982422
# --------approximate solution path for # itr = 1660 complete--------
# # epoch: 1660	 sup error: 0.0006033629179000854
# --------approximate solution path for # itr = 1670 complete--------
# # epoch: 1670	 sup error: 0.0005603283643722534
# --------approximate solution path for # itr = 1680 complete--------
# # epoch: 1680	 sup error: 0.0005372166633606512
# --------approximate solution path for # itr = 1690 complete--------
# # epoch: 1690	 sup error: 0.000496596097946167
# --------approximate solution path for # itr = 1700 complete--------
# # epoch: 1700	 sup error: 0.0003478527069091797
# --------approximate solution path for # itr = 1710 complete--------
# # epoch: 1710	 sup error: 0.0003726482391357422
# --------approximate solution path for # itr = 1720 complete--------
# # epoch: 1720	 sup error: 0.00030086934566497803
# --------approximate solution path for # itr = 1730 complete--------
# # epoch: 1730	 sup error: 0.0005935430526733398
# --------approximate solution path for # itr = 1740 complete--------
# # epoch: 1740	 sup error: 0.0003350377082824707
# --------approximate solution path for # itr = 1750 complete--------
# # epoch: 1750	 sup error: 0.0003828108310699463
# --------approximate solution path for # itr = 1760 complete--------
# # epoch: 1760	 sup error: 0.0006061196327209473
# --------approximate solution path for # itr = 1770 complete--------
# # epoch: 1770	 sup error: 0.0008123517036437988
# --------approximate solution path for # itr = 1780 complete--------
# # epoch: 1780	 sup error: 0.0007300376892089844
# --------approximate solution path for # itr = 1790 complete--------
# # epoch: 1790	 sup error: 0.0005635321140289307
# --------approximate solution path for # itr = 1800 complete--------
# # epoch: 1800	 sup error: 0.0007770359516143799
# --------approximate solution path for # itr = 1810 complete--------
# # epoch: 1810	 sup error: 0.0011114180088043213
# --------approximate solution path for # itr = 1820 complete--------
# # epoch: 1820	 sup error: 0.0014818012714385986
# --------approximate solution path for # itr = 1830 complete--------
# # epoch: 1830	 sup error: 0.001781165599822998
# --------approximate solution path for # itr = 1840 complete--------
# # epoch: 1840	 sup error: 0.0022489428520202637
# --------approximate solution path for # itr = 1850 complete--------
# # epoch: 1850	 sup error: 0.001720815896987915
# --------approximate solution path for # itr = 1860 complete--------
# # epoch: 1860	 sup error: 0.0005914568901062012
# --------approximate solution path for # itr = 1870 complete--------
# # epoch: 1870	 sup error: 0.0009789466857910156
# --------approximate solution path for # itr = 1880 complete--------
# # epoch: 1880	 sup error: 0.000973820686340332
# --------approximate solution path for # itr = 1890 complete--------
# # epoch: 1890	 sup error: 0.0017021000385284424
# --------approximate solution path for # itr = 1900 complete--------
# # epoch: 1900	 sup error: 0.0019347071647644043
# --------approximate solution path for # itr = 1910 complete--------
# # epoch: 1910	 sup error: 0.0023227334022521973
# --------approximate solution path for # itr = 1920 complete--------
# # epoch: 1920	 sup error: 0.0017619132995605469
# --------approximate solution path for # itr = 1930 complete--------
# # epoch: 1930	 sup error: 0.001877427101135254
# --------approximate solution path for # itr = 1940 complete--------
# # epoch: 1940	 sup error: 0.002108454704284668
# --------approximate solution path for # itr = 1950 complete--------
# # epoch: 1950	 sup error: 0.0020014047622680664
# --------approximate solution path for # itr = 1960 complete--------
# # epoch: 1960	 sup error: 0.002486675977706909
# --------approximate solution path for # itr = 1970 complete--------
# # epoch: 1970	 sup error: 0.0027634501457214355
# --------approximate solution path for # itr = 1980 complete--------
# # epoch: 1980	 sup error: 0.0019447803497314453
# --------approximate solution path for # itr = 1990 complete--------
# # epoch: 1990	 sup error: 0.0019865036010742188
# --------approximate solution path for # itr = 2000 complete--------
# # epoch: 2000	 sup error: 0.002207338809967041

# %%
file_path = 'LSP_results_exact_fixed_basis_last_iterate_shrink_lr.csv'

LSP_results_exact_fixed_basis = pd.DataFrame(np.column_stack((num_itr_history, sup_err_history_last_itr)), columns=['num_itr', 'sup_err_5'])

# Save the DataFrame to a CSV file
LSP_results_exact_fixed_basis.to_csv(file_path, index=False)

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Display the DataFrame
df
# Out:
#      num_itr  sup_err_5
# 0       10.0   0.567403
# 1       20.0   0.030950
# 2       30.0   0.012225
# 3       40.0   0.004110
# 4       50.0   0.002075
# ..       ...        ...
# 195   1960.0   0.002487
# 196   1970.0   0.002763
# 197   1980.0   0.001945
# 198   1990.0   0.001987
# 199   2000.0   0.002207
#
# [200 rows x 2 columns]

# %% [markdown]
# ## num basis func = 7

# %%
basis_dim = 7
init_lr = 0.0625

# %%
np.random.seed(8675309)
torch.manual_seed(8675309)

num_itr_history, sup_err_history_last_itr, weight, lr, itr = learn_solution_path(input_dim, basis_dim, phi_lam, max_epochs,
                                                               GD_data_loader, test_data_loader, loss_fn,
                                                               lam_min, lam_max, true_losses, init_lr=init_lr,
                                                               diminish=True, thresh_basis=thresh_basis,
                                                               weighted_avg=False,
                                                               record_frequency=10, distribution='uniform',
                                                               device=device, trace_frequency=10)

sup_err_history_last_itr = np.array(sup_err_history_last_itr)
# Out:
# --------approximate solution path for # itr = 10 complete--------
# # epoch: 10	 sup error: 1.2821851074695587
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 20	 sup error: 1.2866181433200836
# --------approximate solution path for # itr = 30 complete--------
# # epoch: 30	 sup error: 0.056447505950927734
# --------approximate solution path for # itr = 40 complete--------
# # epoch: 40	 sup error: 0.02253568172454834
# --------approximate solution path for # itr = 50 complete--------
# # epoch: 50	 sup error: 0.025891542434692383
# --------approximate solution path for # itr = 60 complete--------
# # epoch: 60	 sup error: 0.02229166030883789
# --------approximate solution path for # itr = 70 complete--------
# # epoch: 70	 sup error: 0.006445050239562988
# --------approximate solution path for # itr = 80 complete--------
# # epoch: 80	 sup error: 0.0041193366050720215
# --------approximate solution path for # itr = 90 complete--------
# # epoch: 90	 sup error: 0.003005087375640869
# --------approximate solution path for # itr = 100 complete--------
# # epoch: 100	 sup error: 0.003039836883544922
# --------approximate solution path for # itr = 110 complete--------
# # epoch: 110	 sup error: 0.0020621418952941895
# --------approximate solution path for # itr = 120 complete--------
# # epoch: 120	 sup error: 0.0020688772201538086
# --------approximate solution path for # itr = 130 complete--------
# # epoch: 130	 sup error: 0.0008317828178405762
# --------approximate solution path for # itr = 140 complete--------
# # epoch: 140	 sup error: 0.0005491971969604492
# --------approximate solution path for # itr = 150 complete--------
# # epoch: 150	 sup error: 0.00042825937271118164
# --------approximate solution path for # itr = 160 complete--------
# # epoch: 160	 sup error: 0.0003345012664794922
# --------approximate solution path for # itr = 170 complete--------
# # epoch: 170	 sup error: 0.0002688169479370117
# --------approximate solution path for # itr = 180 complete--------
# # epoch: 180	 sup error: 0.00022548437118530273
# --------approximate solution path for # itr = 190 complete--------
# # epoch: 190	 sup error: 0.0001900792121887207
# --------approximate solution path for # itr = 200 complete--------
# # epoch: 200	 sup error: 0.0001284480094909668
# --------approximate solution path for # itr = 210 complete--------
# # epoch: 210	 sup error: 8.893013000488281e-05
# --------approximate solution path for # itr = 220 complete--------
# # epoch: 220	 sup error: 6.669759750366211e-05
# --------approximate solution path for # itr = 230 complete--------
# # epoch: 230	 sup error: 5.245208740234375e-05
# --------approximate solution path for # itr = 240 complete--------
# # epoch: 240	 sup error: 3.457069396972656e-05
# --------approximate solution path for # itr = 250 complete--------
# # epoch: 250	 sup error: 2.887845039373227e-05
# --------approximate solution path for # itr = 260 complete--------
# # epoch: 260	 sup error: 2.9146671295166016e-05
# --------approximate solution path for # itr = 270 complete--------
# # epoch: 270	 sup error: 2.9861927032470703e-05
# --------approximate solution path for # itr = 280 complete--------
# # epoch: 280	 sup error: 3.585219383245297e-05
# --------approximate solution path for # itr = 290 complete--------
# # epoch: 290	 sup error: 3.960728645324707e-05
# --------approximate solution path for # itr = 300 complete--------
# # epoch: 300	 sup error: 4.0203332901000977e-05
# --------approximate solution path for # itr = 310 complete--------
# # epoch: 310	 sup error: 2.9802322387695312e-05
# --------approximate solution path for # itr = 320 complete--------
# # epoch: 320	 sup error: 3.781914710998535e-05
# --------approximate solution path for # itr = 330 complete--------
# # epoch: 330	 sup error: 2.8252601623535156e-05
# --------approximate solution path for # itr = 340 complete--------
# # epoch: 340	 sup error: 1.6778707504327972e-05
# --------approximate solution path for # itr = 350 complete--------
# # epoch: 350	 sup error: 1.958012580871582e-05
# --------approximate solution path for # itr = 360 complete--------
# # epoch: 360	 sup error: 1.6897916793823242e-05
# --------approximate solution path for # itr = 370 complete--------
# # epoch: 370	 sup error: 2.7567148208618164e-05
# --------approximate solution path for # itr = 380 complete--------
# # epoch: 380	 sup error: 5.456805229187012e-05
# --------approximate solution path for # itr = 390 complete--------
# # epoch: 390	 sup error: 2.1904706954956055e-05
# --------approximate solution path for # itr = 400 complete--------
# # epoch: 400	 sup error: 3.463029861450195e-05
# --------approximate solution path for # itr = 410 complete--------
# # epoch: 410	 sup error: 5.2034854888916016e-05
# --------approximate solution path for # itr = 420 complete--------
# # epoch: 420	 sup error: 5.492568016052246e-05
# --------approximate solution path for # itr = 430 complete--------
# # epoch: 430	 sup error: 6.303191184997559e-05
# --------approximate solution path for # itr = 440 complete--------
# # epoch: 440	 sup error: 6.42538070678711e-05
# --------approximate solution path for # itr = 450 complete--------
# # epoch: 450	 sup error: 7.584691047668457e-05
# --------approximate solution path for # itr = 460 complete--------
# # epoch: 460	 sup error: 8.702278137207031e-05
# --------approximate solution path for # itr = 470 complete--------
# # epoch: 470	 sup error: 9.28342342376709e-05
# --------approximate solution path for # itr = 480 complete--------
# # epoch: 480	 sup error: 0.00011262297630310059
# --------approximate solution path for # itr = 490 complete--------
# # epoch: 490	 sup error: 0.0001048743724822998
# --------approximate solution path for # itr = 500 complete--------
# # epoch: 500	 sup error: 0.00011798739433288574
# --------approximate solution path for # itr = 510 complete--------
# # epoch: 510	 sup error: 0.00012683868408203125
# --------approximate solution path for # itr = 520 complete--------
# # epoch: 520	 sup error: 3.2007694244384766e-05
# --------approximate solution path for # itr = 530 complete--------
# # epoch: 530	 sup error: 3.6269426345825195e-05
# --------approximate solution path for # itr = 540 complete--------
# # epoch: 540	 sup error: 4.6312808990478516e-05
# --------approximate solution path for # itr = 550 complete--------
# # epoch: 550	 sup error: 5.97536563873291e-05
# --------approximate solution path for # itr = 560 complete--------
# # epoch: 560	 sup error: 7.396936416625977e-05
# --------approximate solution path for # itr = 570 complete--------
# # epoch: 570	 sup error: 4.494190216064453e-05
# --------approximate solution path for # itr = 580 complete--------
# # epoch: 580	 sup error: 5.9992074966430664e-05
# --------approximate solution path for # itr = 590 complete--------
# # epoch: 590	 sup error: 6.854534149169922e-05
# --------approximate solution path for # itr = 600 complete--------
# # epoch: 600	 sup error: 7.611513137817383e-05
# --------approximate solution path for # itr = 610 complete--------
# # epoch: 610	 sup error: 5.093216896057129e-05
# --------approximate solution path for # itr = 620 complete--------
# # epoch: 620	 sup error: 4.5299530029296875e-05
# --------approximate solution path for # itr = 630 complete--------
# # epoch: 630	 sup error: 4.073977470397949e-05
# --------approximate solution path for # itr = 640 complete--------
# # epoch: 640	 sup error: 5.0127506256103516e-05
# --------approximate solution path for # itr = 650 complete--------
# # epoch: 650	 sup error: 5.2541494369506836e-05
# --------approximate solution path for # itr = 660 complete--------
# # epoch: 660	 sup error: 6.127357482910156e-05
# --------approximate solution path for # itr = 670 complete--------
# # epoch: 670	 sup error: 7.000565528869629e-05
# --------approximate solution path for # itr = 680 complete--------
# # epoch: 680	 sup error: 7.471442222595215e-05
# --------approximate solution path for # itr = 690 complete--------
# # epoch: 690	 sup error: 9.548664093017578e-05
# --------approximate solution path for # itr = 700 complete--------
# # epoch: 700	 sup error: 9.429454803466797e-05
# --------approximate solution path for # itr = 710 complete--------
# # epoch: 710	 sup error: 0.00010570883750915527
# --------approximate solution path for # itr = 720 complete--------
# # epoch: 720	 sup error: 0.00010442733764648438
# --------approximate solution path for # itr = 730 complete--------
# # epoch: 730	 sup error: 0.00012093782424926758
# --------approximate solution path for # itr = 740 complete--------
# # epoch: 740	 sup error: 0.0001232922077178955
# --------approximate solution path for # itr = 750 complete--------
# # epoch: 750	 sup error: 0.0001304149627685547
# --------approximate solution path for # itr = 760 complete--------
# # epoch: 760	 sup error: 0.00014325976371765137
# --------approximate solution path for # itr = 770 complete--------
# # epoch: 770	 sup error: 0.00014123320579528809
# --------approximate solution path for # itr = 780 complete--------
# # epoch: 780	 sup error: 0.00013551115989685059
# --------approximate solution path for # itr = 790 complete--------
# # epoch: 790	 sup error: 0.0001468360424041748
# --------approximate solution path for # itr = 800 complete--------
# # epoch: 800	 sup error: 0.00015181303024291992
# --------approximate solution path for # itr = 810 complete--------
# # epoch: 810	 sup error: 0.00017315149307250977
# --------approximate solution path for # itr = 820 complete--------
# # epoch: 820	 sup error: 0.00018349289894104004
# --------approximate solution path for # itr = 830 complete--------
# # epoch: 830	 sup error: 0.0001894831657409668
# --------approximate solution path for # itr = 840 complete--------
# # epoch: 840	 sup error: 0.00013715028762817383
# --------approximate solution path for # itr = 850 complete--------
# # epoch: 850	 sup error: 2.8908252716064453e-05
# --------approximate solution path for # itr = 860 complete--------
# # epoch: 860	 sup error: 3.4362077713012695e-05
# --------approximate solution path for # itr = 870 complete--------
# # epoch: 870	 sup error: 3.466010093688965e-05
# --------approximate solution path for # itr = 880 complete--------
# # epoch: 880	 sup error: 2.3305416107177734e-05
# --------approximate solution path for # itr = 890 complete--------
# # epoch: 890	 sup error: 2.6613473892211914e-05
# --------approximate solution path for # itr = 900 complete--------
# # epoch: 900	 sup error: 1.633167266845703e-05
# --------approximate solution path for # itr = 910 complete--------
# # epoch: 910	 sup error: 2.3543834686279297e-05
# --------approximate solution path for # itr = 920 complete--------
# # epoch: 920	 sup error: 2.4139881134033203e-05
# --------approximate solution path for # itr = 930 complete--------
# # epoch: 930	 sup error: 3.343820571899414e-05
# --------approximate solution path for # itr = 940 complete--------
# # epoch: 940	 sup error: 4.398822784423828e-05
# --------approximate solution path for # itr = 950 complete--------
# # epoch: 950	 sup error: 4.9591064453125e-05
# --------approximate solution path for # itr = 960 complete--------
# # epoch: 960	 sup error: 5.46574592590332e-05
# --------approximate solution path for # itr = 970 complete--------
# # epoch: 970	 sup error: 6.538629531860352e-05
# --------approximate solution path for # itr = 980 complete--------
# # epoch: 980	 sup error: 5.009770393371582e-05
# --------approximate solution path for # itr = 990 complete--------
# # epoch: 990	 sup error: 6.99162483215332e-05
# --------approximate solution path for # itr = 1000 complete--------
# # epoch: 1000	 sup error: 8.219480514526367e-05
# --------approximate solution path for # itr = 1010 complete--------
# # epoch: 1010	 sup error: 5.8710575103759766e-05
# --------approximate solution path for # itr = 1020 complete--------
# # epoch: 1020	 sup error: 6.377696990966797e-05
# --------approximate solution path for # itr = 1030 complete--------
# # epoch: 1030	 sup error: 7.385015487670898e-05
# --------approximate solution path for # itr = 1040 complete--------
# # epoch: 1040	 sup error: 7.486343383789062e-05
# --------approximate solution path for # itr = 1050 complete--------
# # epoch: 1050	 sup error: 1.5497207641601562e-05
# --------approximate solution path for # itr = 1060 complete--------
# # epoch: 1060	 sup error: 2.2530555725097656e-05
# --------approximate solution path for # itr = 1070 complete--------
# # epoch: 1070	 sup error: 3.522634506225586e-05
# --------approximate solution path for # itr = 1080 complete--------
# # epoch: 1080	 sup error: 2.816319465637207e-05
# --------approximate solution path for # itr = 1090 complete--------
# # epoch: 1090	 sup error: 5.200505256652832e-05
# --------approximate solution path for # itr = 1100 complete--------
# # epoch: 1100	 sup error: 4.845857620239258e-05
# --------approximate solution path for # itr = 1110 complete--------
# # epoch: 1110	 sup error: 5.5909156799316406e-05
# --------approximate solution path for # itr = 1120 complete--------
# # epoch: 1120	 sup error: 6.747245788574219e-05
# --------approximate solution path for # itr = 1130 complete--------
# # epoch: 1130	 sup error: 3.6776065826416016e-05
# --------approximate solution path for # itr = 1140 complete--------
# # epoch: 1140	 sup error: 4.51207160949707e-05
# --------approximate solution path for # itr = 1150 complete--------
# # epoch: 1150	 sup error: 5.9098005294799805e-05
# --------approximate solution path for # itr = 1160 complete--------
# # epoch: 1160	 sup error: 6.306171417236328e-05
# --------approximate solution path for # itr = 1170 complete--------
# # epoch: 1170	 sup error: 7.456541061401367e-05
# --------approximate solution path for # itr = 1180 complete--------
# # epoch: 1180	 sup error: 0.00010091066360473633
# --------approximate solution path for # itr = 1190 complete--------
# # epoch: 1190	 sup error: 0.00011223554611206055
# --------approximate solution path for # itr = 1200 complete--------
# # epoch: 1200	 sup error: 0.00011211633682250977
# --------approximate solution path for # itr = 1210 complete--------
# # epoch: 1210	 sup error: 0.00010076165199279785
# --------approximate solution path for # itr = 1220 complete--------
# # epoch: 1220	 sup error: 0.00010779500007629395
# --------approximate solution path for # itr = 1230 complete--------
# # epoch: 1230	 sup error: 1.0967254638671875e-05
# --------approximate solution path for # itr = 1240 complete--------
# # epoch: 1240	 sup error: 9.447336196899414e-06
# --------approximate solution path for # itr = 1250 complete--------
# # epoch: 1250	 sup error: 1.96993350982666e-05
# --------approximate solution path for # itr = 1260 complete--------
# # epoch: 1260	 sup error: 3.108382225036621e-05
# --------approximate solution path for # itr = 1270 complete--------
# # epoch: 1270	 sup error: 4.607439041137695e-05
# --------approximate solution path for # itr = 1280 complete--------
# # epoch: 1280	 sup error: 5.841255187988281e-05
# --------approximate solution path for # itr = 1290 complete--------
# # epoch: 1290	 sup error: 7.039308547973633e-05
# --------approximate solution path for # itr = 1300 complete--------
# # epoch: 1300	 sup error: 3.847479820251465e-05
# --------approximate solution path for # itr = 1310 complete--------
# # epoch: 1310	 sup error: 4.7832727432250977e-05
# --------approximate solution path for # itr = 1320 complete--------
# # epoch: 1320	 sup error: 2.1278858184814453e-05
# --------approximate solution path for # itr = 1330 complete--------
# # epoch: 1330	 sup error: 2.2083520889282227e-05
# --------approximate solution path for # itr = 1340 complete--------
# # epoch: 1340	 sup error: 1.633167266845703e-05
# --------approximate solution path for # itr = 1350 complete--------
# # epoch: 1350	 sup error: 2.6404857635498047e-05
# --------approximate solution path for # itr = 1360 complete--------
# # epoch: 1360	 sup error: 2.491474151611328e-05
# --------approximate solution path for # itr = 1370 complete--------
# # epoch: 1370	 sup error: 2.956390380859375e-05
# --------approximate solution path for # itr = 1380 complete--------
# # epoch: 1380	 sup error: 3.454089164733887e-05
# --------approximate solution path for # itr = 1390 complete--------
# # epoch: 1390	 sup error: 5.301833152770996e-05
# --------approximate solution path for # itr = 1400 complete--------
# # epoch: 1400	 sup error: 6.4849853515625e-05
# --------approximate solution path for # itr = 1410 complete--------
# # epoch: 1410	 sup error: 8.311867713928223e-05
# --------approximate solution path for # itr = 1420 complete--------
# # epoch: 1420	 sup error: 8.940696716308594e-05
# --------approximate solution path for # itr = 1430 complete--------
# # epoch: 1430	 sup error: 9.924173355102539e-05
# --------approximate solution path for # itr = 1440 complete--------
# # epoch: 1440	 sup error: 0.0001150965690612793
# --------approximate solution path for # itr = 1450 complete--------
# # epoch: 1450	 sup error: 0.00012922286987304688
# --------approximate solution path for # itr = 1460 complete--------
# # epoch: 1460	 sup error: 0.00012817978858947754
# --------approximate solution path for # itr = 1470 complete--------
# # epoch: 1470	 sup error: 0.0001360177993774414
# --------approximate solution path for # itr = 1480 complete--------
# # epoch: 1480	 sup error: 2.0742416381835938e-05
# --------approximate solution path for # itr = 1490 complete--------
# # epoch: 1490	 sup error: 2.5719404220581055e-05
# --------approximate solution path for # itr = 1500 complete--------
# # epoch: 1500	 sup error: 4.291534423828125e-05
# --------approximate solution path for # itr = 1510 complete--------
# # epoch: 1510	 sup error: 5.239248275756836e-05
# --------approximate solution path for # itr = 1520 complete--------
# # epoch: 1520	 sup error: 5.78463077545166e-05
# --------approximate solution path for # itr = 1530 complete--------
# # epoch: 1530	 sup error: 6.315112113952637e-05
# --------approximate solution path for # itr = 1540 complete--------
# # epoch: 1540	 sup error: 7.262825965881348e-05
# --------approximate solution path for # itr = 1550 complete--------
# # epoch: 1550	 sup error: 7.95125961303711e-05
# --------approximate solution path for # itr = 1560 complete--------
# # epoch: 1560	 sup error: 2.7298927307128906e-05
# --------approximate solution path for # itr = 1570 complete--------
# # epoch: 1570	 sup error: 3.2901763916015625e-05
# --------approximate solution path for # itr = 1580 complete--------
# # epoch: 1580	 sup error: 3.6656856536865234e-05
# --------approximate solution path for # itr = 1590 complete--------
# # epoch: 1590	 sup error: 4.13060188293457e-05
# --------approximate solution path for # itr = 1600 complete--------
# # epoch: 1600	 sup error: 2.288818359375e-05
# --------approximate solution path for # itr = 1610 complete--------
# # epoch: 1610	 sup error: 2.5093555450439453e-05
# --------approximate solution path for # itr = 1620 complete--------
# # epoch: 1620	 sup error: 2.7835369110107422e-05
# --------approximate solution path for # itr = 1630 complete--------
# # epoch: 1630	 sup error: 3.9696693420410156e-05
# --------approximate solution path for # itr = 1640 complete--------
# # epoch: 1640	 sup error: 4.458427429199219e-05
# --------approximate solution path for # itr = 1650 complete--------
# # epoch: 1650	 sup error: 5.2601099014282227e-05
# --------approximate solution path for # itr = 1660 complete--------
# # epoch: 1660	 sup error: 1.430511474609375e-05
# --------approximate solution path for # itr = 1670 complete--------
# # epoch: 1670	 sup error: 1.5854835510309417e-05
# --------approximate solution path for # itr = 1680 complete--------
# # epoch: 1680	 sup error: 1.9431114196777344e-05
# --------approximate solution path for # itr = 1690 complete--------
# # epoch: 1690	 sup error: 2.9325485229492188e-05
# --------approximate solution path for # itr = 1700 complete--------
# # epoch: 1700	 sup error: 3.3020973205566406e-05
# --------approximate solution path for # itr = 1710 complete--------
# # epoch: 1710	 sup error: 3.975629806518555e-05
# --------approximate solution path for # itr = 1720 complete--------
# # epoch: 1720	 sup error: 2.44826078414917e-05
# --------approximate solution path for # itr = 1730 complete--------
# # epoch: 1730	 sup error: 2.6792287826538086e-05
# --------approximate solution path for # itr = 1740 complete--------
# # epoch: 1740	 sup error: 2.321600914001465e-05
# --------approximate solution path for # itr = 1750 complete--------
# # epoch: 1750	 sup error: 1.5527009963989258e-05
# --------approximate solution path for # itr = 1760 complete--------
# # epoch: 1760	 sup error: 2.9385089874267578e-05
# --------approximate solution path for # itr = 1770 complete--------
# # epoch: 1770	 sup error: 4.0978193283081055e-05
# --------approximate solution path for # itr = 1780 complete--------
# # epoch: 1780	 sup error: 3.802776336669922e-05
# --------approximate solution path for # itr = 1790 complete--------
# # epoch: 1790	 sup error: 3.454089164733887e-05
# --------approximate solution path for # itr = 1800 complete--------
# # epoch: 1800	 sup error: 3.719329833984375e-05
# --------approximate solution path for # itr = 1810 complete--------
# # epoch: 1810	 sup error: 4.5746564865112305e-05
# --------approximate solution path for # itr = 1820 complete--------
# # epoch: 1820	 sup error: 6.687641143798828e-05
# --------approximate solution path for # itr = 1830 complete--------
# # epoch: 1830	 sup error: 8.442997932434082e-05
# --------approximate solution path for # itr = 1840 complete--------
# # epoch: 1840	 sup error: 7.805228233337402e-05
# --------approximate solution path for # itr = 1850 complete--------
# # epoch: 1850	 sup error: 8.627772331237793e-05
# --------approximate solution path for # itr = 1860 complete--------
# # epoch: 1860	 sup error: 9.149312973022461e-06
# --------approximate solution path for # itr = 1870 complete--------
# # epoch: 1870	 sup error: 2.0444393157958984e-05
# --------approximate solution path for # itr = 1880 complete--------
# # epoch: 1880	 sup error: 2.804398536682129e-05
# --------approximate solution path for # itr = 1890 complete--------
# # epoch: 1890	 sup error: 4.762411117553711e-05
# --------approximate solution path for # itr = 1900 complete--------
# # epoch: 1900	 sup error: 5.507469177246094e-05
# --------approximate solution path for # itr = 1910 complete--------
# # epoch: 1910	 sup error: 6.61611557006836e-05
# --------approximate solution path for # itr = 1920 complete--------
# # epoch: 1920	 sup error: 8.046627044677734e-05
# --------approximate solution path for # itr = 1930 complete--------
# # epoch: 1930	 sup error: 8.7738037109375e-05
# --------approximate solution path for # itr = 1940 complete--------
# # epoch: 1940	 sup error: 9.906291961669922e-05
# --------approximate solution path for # itr = 1950 complete--------
# # epoch: 1950	 sup error: 0.00011473894119262695
# --------approximate solution path for # itr = 1960 complete--------
# # epoch: 1960	 sup error: 0.00010761618614196777
# --------approximate solution path for # itr = 1970 complete--------
# # epoch: 1970	 sup error: 0.00011521577835083008
# --------approximate solution path for # itr = 1980 complete--------
# # epoch: 1980	 sup error: 0.0001214146614074707
# --------approximate solution path for # itr = 1990 complete--------
# # epoch: 1990	 sup error: 0.0001328587532043457
# --------approximate solution path for # itr = 2000 complete--------
# # epoch: 2000	 sup error: 0.00014284253120422363

# %%
file_path = 'LSP_results_exact_fixed_basis_last_iterate_shrink_lr.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

df['sup_err_7'] = sup_err_history_last_itr

# Save the DataFrame to a CSV file
df.to_csv(file_path, index=False)

# %% [markdown]
# ## num basis func = 9

# %%
basis_dim = 9
init_lr = 0.0625

# %%
np.random.seed(8675309)
torch.manual_seed(8675309)

num_itr_history, sup_err_history_last_itr, weight, lr, itr = learn_solution_path(input_dim, basis_dim, phi_lam, max_epochs,
                                                               GD_data_loader, test_data_loader, loss_fn,
                                                               lam_min, lam_max, true_losses, init_lr=init_lr,
                                                               diminish=True, thresh_basis=thresh_basis,
                                                               weighted_avg=False,
                                                               record_frequency=10, distribution='uniform',
                                                               device=device, trace_frequency=10)

sup_err_history_last_itr = np.array(sup_err_history_last_itr)
# Out:
# --------approximate solution path for # itr = 10 complete--------
# # epoch: 10	 sup error: 0.7621528506278992
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 20	 sup error: 2.0932967960834503
# --------approximate solution path for # itr = 30 complete--------
# # epoch: 30	 sup error: 0.14752325415611275
# --------approximate solution path for # itr = 40 complete--------
# # epoch: 40	 sup error: 0.1849474310874939
# --------approximate solution path for # itr = 50 complete--------
# # epoch: 50	 sup error: 0.24545922875404358
# --------approximate solution path for # itr = 60 complete--------
# # epoch: 60	 sup error: 0.28169503808021545
# --------approximate solution path for # itr = 70 complete--------
# # epoch: 70	 sup error: 0.1042853593826294
# --------approximate solution path for # itr = 80 complete--------
# # epoch: 80	 sup error: 0.09814915060997009
# --------approximate solution path for # itr = 90 complete--------
# # epoch: 90	 sup error: 0.09452655911445618
# --------approximate solution path for # itr = 100 complete--------
# # epoch: 100	 sup error: 0.0797174870967865
# --------approximate solution path for # itr = 110 complete--------
# # epoch: 110	 sup error: 0.01561155915260315
# --------approximate solution path for # itr = 120 complete--------
# # epoch: 120	 sup error: 0.013402491807937622
# --------approximate solution path for # itr = 130 complete--------
# # epoch: 130	 sup error: 0.013037174940109253
# --------approximate solution path for # itr = 140 complete--------
# # epoch: 140	 sup error: 0.0005724430084228516
# --------approximate solution path for # itr = 150 complete--------
# # epoch: 150	 sup error: 0.00044971704483032227
# --------approximate solution path for # itr = 160 complete--------
# # epoch: 160	 sup error: 0.0003771781921386719
# --------approximate solution path for # itr = 170 complete--------
# # epoch: 170	 sup error: 0.0003237724304199219
# --------approximate solution path for # itr = 180 complete--------
# # epoch: 180	 sup error: 0.00029671192169189453
# --------approximate solution path for # itr = 190 complete--------
# # epoch: 190	 sup error: 0.0002378225326538086
# --------approximate solution path for # itr = 200 complete--------
# # epoch: 200	 sup error: 0.00017386674880981445
# --------approximate solution path for # itr = 210 complete--------
# # epoch: 210	 sup error: 0.000125885009765625
# --------approximate solution path for # itr = 220 complete--------
# # epoch: 220	 sup error: 8.553266525268555e-05
# --------approximate solution path for # itr = 230 complete--------
# # epoch: 230	 sup error: 6.186962127685547e-05
# --------approximate solution path for # itr = 240 complete--------
# # epoch: 240	 sup error: 3.9517879486083984e-05
# --------approximate solution path for # itr = 250 complete--------
# # epoch: 250	 sup error: 2.3066997528076172e-05
# --------approximate solution path for # itr = 260 complete--------
# # epoch: 260	 sup error: 1.2576580047607422e-05
# --------approximate solution path for # itr = 270 complete--------
# # epoch: 270	 sup error: 1.2159347534179688e-05
# --------approximate solution path for # itr = 280 complete--------
# # epoch: 280	 sup error: 7.62939453125e-06
# --------approximate solution path for # itr = 290 complete--------
# # epoch: 290	 sup error: 5.841255187988281e-06
# --------approximate solution path for # itr = 300 complete--------
# # epoch: 300	 sup error: 4.231929779052734e-06
# --------approximate solution path for # itr = 310 complete--------
# # epoch: 310	 sup error: 3.6954879760742188e-06
# --------approximate solution path for # itr = 320 complete--------
# # epoch: 320	 sup error: 2.8014183044433594e-06
# --------approximate solution path for # itr = 330 complete--------
# # epoch: 330	 sup error: 2.205371856689453e-06
# --------approximate solution path for # itr = 340 complete--------
# # epoch: 340	 sup error: 1.7285346984863281e-06
# --------approximate solution path for # itr = 350 complete--------
# # epoch: 350	 sup error: 1.4901161193847656e-06
# --------approximate solution path for # itr = 360 complete--------
# # epoch: 360	 sup error: 1.4305114746648862e-06
# --------approximate solution path for # itr = 370 complete--------
# # epoch: 370	 sup error: 1.519918441827972e-06
# --------approximate solution path for # itr = 380 complete--------
# # epoch: 380	 sup error: 1.2814998626708984e-06
# --------approximate solution path for # itr = 390 complete--------
# # epoch: 390	 sup error: 1.1324882507324219e-06
# --------approximate solution path for # itr = 400 complete--------
# # epoch: 400	 sup error: 1.1622905731201172e-06
# --------approximate solution path for # itr = 410 complete--------
# # epoch: 410	 sup error: 1.2814998626708984e-06
# --------approximate solution path for # itr = 420 complete--------
# # epoch: 420	 sup error: 1.3709068298339844e-06
# --------approximate solution path for # itr = 430 complete--------
# # epoch: 430	 sup error: 1.5497207641601562e-06
# --------approximate solution path for # itr = 440 complete--------
# # epoch: 440	 sup error: 1.6093254089355469e-06
# --------approximate solution path for # itr = 450 complete--------
# # epoch: 450	 sup error: 1.6391277313232422e-06
# --------approximate solution path for # itr = 460 complete--------
# # epoch: 460	 sup error: 1.7583370208740234e-06
# --------approximate solution path for # itr = 470 complete--------
# # epoch: 470	 sup error: 1.9669532775878906e-06
# --------approximate solution path for # itr = 480 complete--------
# # epoch: 480	 sup error: 2.086162567138672e-06
# --------approximate solution path for # itr = 490 complete--------
# # epoch: 490	 sup error: 2.6226043701171875e-06
# --------approximate solution path for # itr = 500 complete--------
# # epoch: 500	 sup error: 2.8014183044433594e-06
# --------approximate solution path for # itr = 510 complete--------
# # epoch: 510	 sup error: 2.9802322387695312e-06
# --------approximate solution path for # itr = 520 complete--------
# # epoch: 520	 sup error: 1.2516975402832031e-06
# --------approximate solution path for # itr = 530 complete--------
# # epoch: 530	 sup error: 1.3113021850585938e-06
# --------approximate solution path for # itr = 540 complete--------
# # epoch: 540	 sup error: 1.4007091522216797e-06
# --------approximate solution path for # itr = 550 complete--------
# # epoch: 550	 sup error: 1.6391277313232422e-06
# --------approximate solution path for # itr = 560 complete--------
# # epoch: 560	 sup error: 1.817941665649414e-06
# --------approximate solution path for # itr = 570 complete--------
# # epoch: 570	 sup error: 1.6093254089355469e-06
# --------approximate solution path for # itr = 580 complete--------
# # epoch: 580	 sup error: 1.817941665649414e-06
# --------approximate solution path for # itr = 590 complete--------
# # epoch: 590	 sup error: 1.996755599975586e-06
# --------approximate solution path for # itr = 600 complete--------
# # epoch: 600	 sup error: 2.1457672119140625e-06
# --------approximate solution path for # itr = 610 complete--------
# # epoch: 610	 sup error: 1.3113021850585938e-06
# --------approximate solution path for # itr = 620 complete--------
# # epoch: 620	 sup error: 1.3113021850585938e-06
# --------approximate solution path for # itr = 630 complete--------
# # epoch: 630	 sup error: 1.3113021850585938e-06
# --------approximate solution path for # itr = 640 complete--------
# # epoch: 640	 sup error: 1.3709068298339844e-06
# --------approximate solution path for # itr = 650 complete--------
# # epoch: 650	 sup error: 1.4901161193847656e-06
# --------approximate solution path for # itr = 660 complete--------
# # epoch: 660	 sup error: 1.6391277313232422e-06
# --------approximate solution path for # itr = 670 complete--------
# # epoch: 670	 sup error: 1.817941665649414e-06
# --------approximate solution path for # itr = 680 complete--------
# # epoch: 680	 sup error: 2.175569534301758e-06
# --------approximate solution path for # itr = 690 complete--------
# # epoch: 690	 sup error: 2.3245811462402344e-06
# --------approximate solution path for # itr = 700 complete--------
# # epoch: 700	 sup error: 2.473592758178711e-06
# --------approximate solution path for # itr = 710 complete--------
# # epoch: 710	 sup error: 2.7120113372802734e-06
# --------approximate solution path for # itr = 720 complete--------
# # epoch: 720	 sup error: 3.1888484954833984e-06
# --------approximate solution path for # itr = 730 complete--------
# # epoch: 730	 sup error: 3.606081008911133e-06
# --------approximate solution path for # itr = 740 complete--------
# # epoch: 740	 sup error: 3.993511199951172e-06
# --------approximate solution path for # itr = 750 complete--------
# # epoch: 750	 sup error: 3.993511199951172e-06
# --------approximate solution path for # itr = 760 complete--------
# # epoch: 760	 sup error: 4.082918167114258e-06
# --------approximate solution path for # itr = 770 complete--------
# # epoch: 770	 sup error: 3.6954879760742188e-06
# --------approximate solution path for # itr = 780 complete--------
# # epoch: 780	 sup error: 3.725290298461914e-06
# --------approximate solution path for # itr = 790 complete--------
# # epoch: 790	 sup error: 3.933906555175781e-06
# --------approximate solution path for # itr = 800 complete--------
# # epoch: 800	 sup error: 4.231929779052734e-06
# --------approximate solution path for # itr = 810 complete--------
# # epoch: 810	 sup error: 4.5299530029296875e-06
# --------approximate solution path for # itr = 820 complete--------
# # epoch: 820	 sup error: 4.589557647705078e-06
# --------approximate solution path for # itr = 830 complete--------
# # epoch: 830	 sup error: 4.76837158203125e-06
# --------approximate solution path for # itr = 840 complete--------
# # epoch: 840	 sup error: 4.857778549194336e-06
# --------approximate solution path for # itr = 850 complete--------
# # epoch: 850	 sup error: 1.1026859283447266e-06
# --------approximate solution path for # itr = 860 complete--------
# # epoch: 860	 sup error: 1.2516975402832031e-06
# --------approximate solution path for # itr = 870 complete--------
# # epoch: 870	 sup error: 1.341104507446289e-06
# --------approximate solution path for # itr = 880 complete--------
# # epoch: 880	 sup error: 7.301568984985352e-07
# --------approximate solution path for # itr = 890 complete--------
# # epoch: 890	 sup error: 7.450580596923828e-07
# --------approximate solution path for # itr = 900 complete--------
# # epoch: 900	 sup error: 6.258487701416016e-07
# --------approximate solution path for # itr = 910 complete--------
# # epoch: 910	 sup error: 1.4603137969970703e-06
# --------approximate solution path for # itr = 920 complete--------
# # epoch: 920	 sup error: 1.0728836059570312e-06
# --------approximate solution path for # itr = 930 complete--------
# # epoch: 930	 sup error: 7.897615433016814e-07
# --------approximate solution path for # itr = 940 complete--------
# # epoch: 940	 sup error: 7.003545761385954e-07
# --------approximate solution path for # itr = 950 complete--------
# # epoch: 950	 sup error: 5.960464477816618e-07
# --------approximate solution path for # itr = 960 complete--------
# # epoch: 960	 sup error: 5.364418029785156e-07
# --------approximate solution path for # itr = 970 complete--------
# # epoch: 970	 sup error: 5.066394805908203e-07
# --------approximate solution path for # itr = 980 complete--------
# # epoch: 980	 sup error: 9.5367431640625e-07
# --------approximate solution path for # itr = 990 complete--------
# # epoch: 990	 sup error: 8.940696716308594e-07
# --------approximate solution path for # itr = 1000 complete--------
# # epoch: 1000	 sup error: 1.1026859283447266e-06
# --------approximate solution path for # itr = 1010 complete--------
# # epoch: 1010	 sup error: 1.519918441772461e-06
# --------approximate solution path for # itr = 1020 complete--------
# # epoch: 1020	 sup error: 1.7881393432617188e-06
# --------approximate solution path for # itr = 1030 complete--------
# # epoch: 1030	 sup error: 1.9073486328125e-06
# --------approximate solution path for # itr = 1040 complete--------
# # epoch: 1040	 sup error: 2.2351741790771484e-06
# --------approximate solution path for # itr = 1050 complete--------
# # epoch: 1050	 sup error: 5.364418029785156e-07
# --------approximate solution path for # itr = 1060 complete--------
# # epoch: 1060	 sup error: 5.364418029785156e-07
# --------approximate solution path for # itr = 1070 complete--------
# # epoch: 1070	 sup error: 7.450580596923828e-07
# --------approximate solution path for # itr = 1080 complete--------
# # epoch: 1080	 sup error: 6.556510925292969e-07
# --------approximate solution path for # itr = 1090 complete--------
# # epoch: 1090	 sup error: 8.344650268554688e-07
# --------approximate solution path for # itr = 1100 complete--------
# # epoch: 1100	 sup error: 1.0728836059570312e-06
# --------approximate solution path for # itr = 1110 complete--------
# # epoch: 1110	 sup error: 1.1324882507324219e-06
# --------approximate solution path for # itr = 1120 complete--------
# # epoch: 1120	 sup error: 1.3709068298339844e-06
# --------approximate solution path for # itr = 1130 complete--------
# # epoch: 1130	 sup error: 1.1026859283447266e-06
# --------approximate solution path for # itr = 1140 complete--------
# # epoch: 1140	 sup error: 1.341104507446289e-06
# --------approximate solution path for # itr = 1150 complete--------
# # epoch: 1150	 sup error: 1.6689300537109375e-06
# --------approximate solution path for # itr = 1160 complete--------
# # epoch: 1160	 sup error: 1.4901161193847656e-06
# --------approximate solution path for # itr = 1170 complete--------
# # epoch: 1170	 sup error: 1.6391277313232422e-06
# --------approximate solution path for # itr = 1180 complete--------
# # epoch: 1180	 sup error: 1.4901161193847656e-06
# --------approximate solution path for # itr = 1190 complete--------
# # epoch: 1190	 sup error: 1.6093254089355469e-06
# --------approximate solution path for # itr = 1200 complete--------
# # epoch: 1200	 sup error: 1.7881393432617188e-06
# --------approximate solution path for # itr = 1210 complete--------
# # epoch: 1210	 sup error: 1.9073486328125e-06
# --------approximate solution path for # itr = 1220 complete--------
# # epoch: 1220	 sup error: 2.3543834686279297e-06
# --------approximate solution path for # itr = 1230 complete--------
# # epoch: 1230	 sup error: 5.960464477539062e-07
# --------approximate solution path for # itr = 1240 complete--------
# # epoch: 1240	 sup error: 2.980232239324643e-07
# --------approximate solution path for # itr = 1250 complete--------
# # epoch: 1250	 sup error: 3.5762786865234375e-07
# --------approximate solution path for # itr = 1260 complete--------
# # epoch: 1260	 sup error: 2.6822090154476896e-07
# --------approximate solution path for # itr = 1270 complete--------
# # epoch: 1270	 sup error: 3.5762786865234375e-07
# --------approximate solution path for # itr = 1280 complete--------
# # epoch: 1280	 sup error: 3.129243850708008e-07
# --------approximate solution path for # itr = 1290 complete--------
# # epoch: 1290	 sup error: 3.8743019104003906e-07
# --------approximate solution path for # itr = 1300 complete--------
# # epoch: 1300	 sup error: 3.725290298461914e-07
# --------approximate solution path for # itr = 1310 complete--------
# # epoch: 1310	 sup error: 5.960464477539062e-07
# --------approximate solution path for # itr = 1320 complete--------
# # epoch: 1320	 sup error: 6.109476089477539e-07
# --------approximate solution path for # itr = 1330 complete--------
# # epoch: 1330	 sup error: 8.642673492431641e-07
# --------approximate solution path for # itr = 1340 complete--------
# # epoch: 1340	 sup error: 2.3841857915707365e-07
# --------approximate solution path for # itr = 1350 complete--------
# # epoch: 1350	 sup error: 2.980232239324643e-07
# --------approximate solution path for # itr = 1360 complete--------
# # epoch: 1360	 sup error: 5.662441253662109e-07
# --------approximate solution path for # itr = 1370 complete--------
# # epoch: 1370	 sup error: 6.258487701416016e-07
# --------approximate solution path for # itr = 1380 complete--------
# # epoch: 1380	 sup error: 6.854534149169922e-07
# --------approximate solution path for # itr = 1390 complete--------
# # epoch: 1390	 sup error: 7.748603820800781e-07
# --------approximate solution path for # itr = 1400 complete--------
# # epoch: 1400	 sup error: 8.344650268554688e-07
# --------approximate solution path for # itr = 1410 complete--------
# # epoch: 1410	 sup error: 9.834766387939453e-07
# --------approximate solution path for # itr = 1420 complete--------
# # epoch: 1420	 sup error: 1.0728836059570312e-06
# --------approximate solution path for # itr = 1430 complete--------
# # epoch: 1430	 sup error: 1.2516975402832031e-06
# --------approximate solution path for # itr = 1440 complete--------
# # epoch: 1440	 sup error: 1.430511474609375e-06
# --------approximate solution path for # itr = 1450 complete--------
# # epoch: 1450	 sup error: 1.6093254089355469e-06
# --------approximate solution path for # itr = 1460 complete--------
# # epoch: 1460	 sup error: 1.6689300537109375e-06
# --------approximate solution path for # itr = 1470 complete--------
# # epoch: 1470	 sup error: 1.8477439880371094e-06
# --------approximate solution path for # itr = 1480 complete--------
# # epoch: 1480	 sup error: 4.470348358154297e-07
# --------approximate solution path for # itr = 1490 complete--------
# # epoch: 1490	 sup error: 5.960464477539062e-07
# --------approximate solution path for # itr = 1500 complete--------
# # epoch: 1500	 sup error: 6.556510925292969e-07
# --------approximate solution path for # itr = 1510 complete--------
# # epoch: 1510	 sup error: 7.450580596923828e-07
# --------approximate solution path for # itr = 1520 complete--------
# # epoch: 1520	 sup error: 7.748603820800781e-07
# --------approximate solution path for # itr = 1530 complete--------
# # epoch: 1530	 sup error: 9.5367431640625e-07
# --------approximate solution path for # itr = 1540 complete--------
# # epoch: 1540	 sup error: 1.2218952178955078e-06
# --------approximate solution path for # itr = 1550 complete--------
# # epoch: 1550	 sup error: 1.430511474609375e-06
# --------approximate solution path for # itr = 1560 complete--------
# # epoch: 1560	 sup error: 1.3113021850585938e-06
# --------approximate solution path for # itr = 1570 complete--------
# # epoch: 1570	 sup error: 1.4007091522216797e-06
# --------approximate solution path for # itr = 1580 complete--------
# # epoch: 1580	 sup error: 1.4007091522216797e-06
# --------approximate solution path for # itr = 1590 complete--------
# # epoch: 1590	 sup error: 1.6689300537109375e-06
# --------approximate solution path for # itr = 1600 complete--------
# # epoch: 1600	 sup error: 1.2516975402832031e-06
# --------approximate solution path for # itr = 1610 complete--------
# # epoch: 1610	 sup error: 1.1026859283447266e-06
# --------approximate solution path for # itr = 1620 complete--------
# # epoch: 1620	 sup error: 9.685754776000977e-07
# --------approximate solution path for # itr = 1630 complete--------
# # epoch: 1630	 sup error: 5.364418029785156e-07
# --------approximate solution path for # itr = 1640 complete--------
# # epoch: 1640	 sup error: 6.854534149169922e-07
# --------approximate solution path for # itr = 1650 complete--------
# # epoch: 1650	 sup error: 7.748603820800781e-07
# --------approximate solution path for # itr = 1660 complete--------
# # epoch: 1660	 sup error: 4.768371582586362e-07
# --------approximate solution path for # itr = 1670 complete--------
# # epoch: 1670	 sup error: 5.662441253662109e-07
# --------approximate solution path for # itr = 1680 complete--------
# # epoch: 1680	 sup error: 7.152557373046875e-07
# --------approximate solution path for # itr = 1690 complete--------
# # epoch: 1690	 sup error: 1.1920928955078125e-06
# --------approximate solution path for # itr = 1700 complete--------
# # epoch: 1700	 sup error: 1.1920928955078125e-06
# --------approximate solution path for # itr = 1710 complete--------
# # epoch: 1710	 sup error: 1.4901161193847656e-06
# --------approximate solution path for # itr = 1720 complete--------
# # epoch: 1720	 sup error: 3.8743019104003906e-07
# --------approximate solution path for # itr = 1730 complete--------
# # epoch: 1730	 sup error: 4.470348358154297e-07
# --------approximate solution path for # itr = 1740 complete--------
# # epoch: 1740	 sup error: 3.5762786865234375e-07
# --------approximate solution path for # itr = 1750 complete--------
# # epoch: 1750	 sup error: 3.2782554626464844e-07
# --------approximate solution path for # itr = 1760 complete--------
# # epoch: 1760	 sup error: 4.172325134277344e-07
# --------approximate solution path for # itr = 1770 complete--------
# # epoch: 1770	 sup error: 5.662441253662109e-07
# --------approximate solution path for # itr = 1780 complete--------
# # epoch: 1780	 sup error: 8.344650268554688e-07
# --------approximate solution path for # itr = 1790 complete--------
# # epoch: 1790	 sup error: 6.556510925292969e-07
# --------approximate solution path for # itr = 1800 complete--------
# # epoch: 1800	 sup error: 9.5367431640625e-07
# --------approximate solution path for # itr = 1810 complete--------
# # epoch: 1810	 sup error: 1.1324882507324219e-06
# --------approximate solution path for # itr = 1820 complete--------
# # epoch: 1820	 sup error: 1.6093254089355469e-06
# --------approximate solution path for # itr = 1830 complete--------
# # epoch: 1830	 sup error: 1.817941665649414e-06
# --------approximate solution path for # itr = 1840 complete--------
# # epoch: 1840	 sup error: 1.8477439880371094e-06
# --------approximate solution path for # itr = 1850 complete--------
# # epoch: 1850	 sup error: 1.8775463104248047e-06
# --------approximate solution path for # itr = 1860 complete--------
# # epoch: 1860	 sup error: 3.5762786865234375e-07
# --------approximate solution path for # itr = 1870 complete--------
# # epoch: 1870	 sup error: 2.682209014892578e-07
# --------approximate solution path for # itr = 1880 complete--------
# # epoch: 1880	 sup error: 4.172325134277344e-07
# --------approximate solution path for # itr = 1890 complete--------
# # epoch: 1890	 sup error: 4.76837158203125e-07
# --------approximate solution path for # itr = 1900 complete--------
# # epoch: 1900	 sup error: 5.364418029785156e-07
# --------approximate solution path for # itr = 1910 complete--------
# # epoch: 1910	 sup error: 6.258487701416016e-07
# --------approximate solution path for # itr = 1920 complete--------
# # epoch: 1920	 sup error: 7.748603820800781e-07
# --------approximate solution path for # itr = 1930 complete--------
# # epoch: 1930	 sup error: 8.344650268554688e-07
# --------approximate solution path for # itr = 1940 complete--------
# # epoch: 1940	 sup error: 1.0132789611816406e-06
# --------approximate solution path for # itr = 1950 complete--------
# # epoch: 1950	 sup error: 1.0132789611816406e-06
# --------approximate solution path for # itr = 1960 complete--------
# # epoch: 1960	 sup error: 1.2218952178955078e-06
# --------approximate solution path for # itr = 1970 complete--------
# # epoch: 1970	 sup error: 1.341104507446289e-06
# --------approximate solution path for # itr = 1980 complete--------
# # epoch: 1980	 sup error: 1.430511474609375e-06
# --------approximate solution path for # itr = 1990 complete--------
# # epoch: 1990	 sup error: 1.4901161193847656e-06
# --------approximate solution path for # itr = 2000 complete--------
# # epoch: 2000	 sup error: 1.7285346984863281e-06

# %%
file_path = 'LSP_results_exact_fixed_basis_last_iterate_shrink_lr.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

df['sup_err_9'] = sup_err_history_last_itr

# Save the DataFrame to a CSV file
df.to_csv(file_path, index=False)

# %% [markdown]
# # 04 Error Across $\Lambda$

# %%
model = Basis_TF_SGD(input_dim, 9, phi_lam, init_weight=weight, intercept=True).to(device)

# %%
errs = get_errs_lsp(lam_min[0], lam_max[0], true_losses, model, test_data_loader, loss_fn)

# %%
lambdas = np.linspace(lam_max[0], lam_min[0], len(true_losses))

# %%
pd.DataFrame(np.column_stack((errs, lambdas)), columns=['errs', 'lambdas']).to_csv('LSP_errs_legendre_basis_9.csv', index=False)
