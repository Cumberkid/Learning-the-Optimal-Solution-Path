# %% [markdown]
# # 01 Import libraries

# %%
import numpy as np
import torch

device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
import pandas as pd

# %%
import importlib

# %% [markdown]
# ## Import our own modules

# %%
# !rm -r Learning-the-Optimal-Solution-Path
# !git clone https://github.com/Cumberkid/Learning-the-Optimal-Solution-Path.git
# Out:
# rm: cannot remove 'Learning-the-Optimal-Solution-Path': No such file or directory
# Cloning into 'Learning-the-Optimal-Solution-Path'...
# remote: Enumerating objects: 1744, done.
# remote: Counting objects: 100% (714/714), done.
# remote: Compressing objects: 100% (355/355), done.
# remote: Total 1744 (delta 542), reused 479 (delta 359), pack-reused 1030 (from 1)
# Receiving objects: 100% (1744/1744), 13.25 MiB | 16.37 MiB/s, done.
# Resolving deltas: 100% (1179/1179), done.

# %% [markdown]
# (Using Colab)

# %%
import sys

# %%
# Add the parent directory to sys.path
sys.path.append('/content/Learning-the-Optimal-Solution-Path')

# %%
import lib
importlib.reload(lib)
# Out:
# <module 'lib' from '/content/Learning-the-Optimal-Solution-Path/lib/__init__.py'>

# %%
from lib.lsp.basis_generator import scaled_shifted_legendre
from lib.lsp.basis_tf_module import Basis_TF_SGD
from lib.lsp.learn_solution_path import lsp_boosting
from lib.lsp.loss_fn_lsp import reg_unif_weighted_logit
from lib.fast_tensor_data_loader import FastTensorDataLoader

# %% [markdown]
# # 02 Load data

# %%
# file path for Colab. May need to change this
X_df = pd.read_csv('/content/Learning-the-Optimal-Solution-Path/experiments/fair-regression/data/X_processed.csv')
y_df = pd.read_csv('/content/Learning-the-Optimal-Solution-Path/experiments/fair-regression/data/y_processed.csv')

# %%
X = np.array(X_df)
y = np.array(y_df).squeeze()

# %%
train_X = torch.tensor(X, dtype=torch.float32)
train_y = torch.tensor(y, dtype=torch.float32)

# %%
# full gradient descent uses all data points
GD_data_loader = FastTensorDataLoader(train_X, train_y, batch_size=1000, shuffle=True, )
# stochastic gradient descent uses mini-batch
SGD_data_loader = FastTensorDataLoader(train_X, train_y, batch_size=20, shuffle=True, )
# test data
test_data_loader = FastTensorDataLoader(train_X, train_y, batch_size=1000, shuffle=False, )

# %%
lam_max = 1
lam_min = 0
input_dim = X.shape[1]
loss_fn = reg_unif_weighted_logit

# %%
# Read the CSV file into a DataFrame
# truth = pd.read_csv('/content/Learning-the-Optimal-Solution-Path/experiments/fair-regression/results/exact_soln_list.csv')
truth = pd.read_csv('exact_soln_list_legendre.csv')

# Display the DataFrame
truth
# Out:
#         losses   theta_0   theta_1   theta_2   theta_3   theta_4   theta_5  \
# 0     0.190793 -0.373029  0.186622  0.227443 -0.023583  0.164822  0.142992
# 1     0.192130 -0.371212  0.186634  0.227586 -0.023679  0.164875  0.142262
# 2     0.193463 -0.369401  0.186645  0.227729 -0.023775  0.164927  0.141535
# 3     0.194792 -0.367595  0.186656  0.227870 -0.023870  0.164977  0.140811
# 4     0.196117 -0.365794  0.186665  0.228009 -0.023964  0.165027  0.140089
# ...        ...       ...       ...       ...       ...       ...       ...
# 1019  0.327684  0.692472 -0.029101 -0.033382 -0.017462 -0.005831 -0.225541
# 1020  0.325866  0.693930 -0.029932 -0.034521 -0.017548 -0.006565 -0.226194
# 1021  0.324032  0.695399 -0.030769 -0.035668 -0.017634 -0.007304 -0.226853
# 1022  0.322184  0.696878 -0.031613 -0.036822 -0.017720 -0.008050 -0.227517
# 1023  0.320320  0.698369 -0.032464 -0.037983 -0.017807 -0.008802 -0.228186
#
#        theta_6   theta_7   theta_8  ...  theta_36  theta_37  theta_38  \
# 0     0.168018  0.026305  0.142661  ... -0.018010  0.054908 -0.005629
# 1     0.167428  0.025960  0.142993  ... -0.017600  0.054199 -0.005657
# 2     0.166842  0.025615  0.143323  ... -0.017191  0.053493 -0.005685
# 3     0.166258  0.025271  0.143653  ... -0.016784  0.052790 -0.005713
# 4     0.165677  0.024927  0.143982  ... -0.016378  0.052089 -0.005741
# ...        ...       ...       ...  ...       ...       ...       ...
# 1019 -0.146453 -0.051680  0.070009  ...  0.105324 -0.201982  0.000913
# 1020 -0.148351 -0.051246  0.068693  ...  0.105340 -0.202186  0.000990
# 1021 -0.150274 -0.050809  0.067366  ...  0.105357 -0.202393  0.001066
# 1022 -0.152223 -0.050369  0.066028  ...  0.105374 -0.202601  0.001143
# 1023 -0.154196 -0.049927  0.064680  ...  0.105391 -0.202811  0.001220
#
#       theta_39  theta_40  theta_41  theta_42  theta_43  theta_44  theta_45
# 0     0.000000  0.000000 -0.031270 -0.018010 -0.139608 -0.116840 -0.061673
# 1     0.000069  0.000098 -0.031115 -0.017600 -0.139385 -0.116402 -0.061226
# 2     0.000137  0.000195 -0.030961 -0.017191 -0.139162 -0.115965 -0.060781
# 3     0.000205  0.000293 -0.030808 -0.016784 -0.138939 -0.115529 -0.060337
# 4     0.000273  0.000390 -0.030655 -0.016378 -0.138717 -0.115094 -0.059894
# ...        ...       ...       ...       ...       ...       ...       ...
# 1019  0.013100  0.018598  0.063129  0.105324  0.157442  0.161747  0.171301
# 1020  0.013040  0.018537  0.063366  0.105340  0.158131  0.162149  0.171464
# 1021  0.012980  0.018475  0.063604  0.105357  0.158825  0.162554  0.171627
# 1022  0.012919  0.018415  0.063843  0.105374  0.159523  0.162962  0.171792
# 1023  0.012859  0.018354  0.064084  0.105391  0.160226  0.163374  0.171958
#
# [1024 rows x 47 columns]

# %%
selected_columns = ['theta_0', 'theta_1', 'theta_2', 'theta_3', 'theta_4',
                    'theta_5', 'theta_6', 'theta_7', 'theta_8', 'theta_9',
                    'theta_10', 'theta_11', 'theta_12', 'theta_13', 'theta_14',
                    'theta_15', 'theta_16', 'theta_17', 'theta_18', 'theta_19',
                    'theta_20', 'theta_21', 'theta_22', 'theta_23', 'theta_24',
                    'theta_25', 'theta_26', 'theta_27', 'theta_28', 'theta_29',
                    'theta_30', 'theta_31', 'theta_32', 'theta_33', 'theta_34',
                    'theta_35', 'theta_36', 'theta_37', 'theta_38', 'theta_39',
                    'theta_40', 'theta_41', 'theta_42', 'theta_43', 'theta_44',
                    'theta_45']
true_thetas = truth[selected_columns].to_numpy()
true_losses = truth['losses'].to_numpy()

# %%
# import time

# %% [markdown]
# # 03 Exact gradient

# %%
max_epochs = 300

# %%
phi_lam = scaled_shifted_legendre

# %%
start_basis_dim = 5
end_basis_dim = 13
init_lr = 0.125

# %%
def thresh_basis(basis_dim):
    return 0.1**(basis_dim/5 + 2.5)

# %%
np.random.seed(8675309)
torch.manual_seed(8675309)

num_itr_history, sup_err_history, breaks = lsp_boosting(input_dim, start_basis_dim, end_basis_dim,
                                        phi_lam, max_epochs, GD_data_loader,  test_data_loader,
                                        loss_fn, lam_min, lam_max, true_losses, init_lr=init_lr,
                                        thresh_basis=thresh_basis, record_frequency=10,
                                        distribution='uniform', device=device, trace_frequency=10)
# Out:
# ********** now running lsp with #basis dimension = 5 ***********
# --------approximate solution path for # itr = 10 complete--------
# # epoch: 10	 sup error: 3.808290511369705
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 20	 sup error: 0.4882354736328125
# --------approximate solution path for # itr = 30 complete--------
# # epoch: 30	 sup error: 0.3149908185005188
# --------approximate solution path for # itr = 40 complete--------
# # epoch: 40	 sup error: 0.06118583679199219
# --------approximate solution path for # itr = 50 complete--------
# # epoch: 50	 sup error: 0.040966540575027466
# --------approximate solution path for # itr = 60 complete--------
# # epoch: 60	 sup error: 0.02363187074661255
# --------approximate solution path for # itr = 70 complete--------
# # epoch: 70	 sup error: 0.01431553065776825
# --------approximate solution path for # itr = 80 complete--------
# # epoch: 80	 sup error: 0.009075149893760681
# --------approximate solution path for # itr = 90 complete--------
# # epoch: 90	 sup error: 0.006006985902786255
# --------approximate solution path for # itr = 100 complete--------
# # epoch: 100	 sup error: 0.004100710153579712
# --------approximate solution path for # itr = 110 complete--------
# # epoch: 110	 sup error: 0.002818584442138672
# --------approximate solution path for # itr = 120 complete--------
# # epoch: 120	 sup error: 0.0019757449626922607
# ********** now running lsp with #basis dimension = 6 ***********
# --------approximate solution path for # itr = 10 complete--------
# # epoch: 10	 sup error: 0.0013887286186218262
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 20	 sup error: 0.0013052523136138916
# --------approximate solution path for # itr = 30 complete--------
# # epoch: 30	 sup error: 0.0004302859306335449
# --------approximate solution path for # itr = 40 complete--------
# # epoch: 40	 sup error: 0.00031509995460510254
# --------approximate solution path for # itr = 50 complete--------
# # epoch: 50	 sup error: 0.00033146142959594727
# --------approximate solution path for # itr = 60 complete--------
# # epoch: 60	 sup error: 0.0003336668014526367
# --------approximate solution path for # itr = 70 complete--------
# # epoch: 70	 sup error: 0.0003446340560913086
# --------approximate solution path for # itr = 80 complete--------
# # epoch: 80	 sup error: 0.0003695487976074219
# ********** now running lsp with #basis dimension = 7 ***********
# --------approximate solution path for # itr = 10 complete--------
# # epoch: 10	 sup error: 0.0003202855587005615
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 20	 sup error: 1.3887882232721527e-05
# --------approximate solution path for # itr = 30 complete--------
# # epoch: 30	 sup error: 1.4275312423706055e-05
# --------approximate solution path for # itr = 40 complete--------
# # epoch: 40	 sup error: 4.851818084716797e-05
# ********** now running lsp with #basis dimension = 8 ***********
# --------approximate solution path for # itr = 10 complete--------
# # epoch: 10	 sup error: 3.7670135498046875e-05
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 20	 sup error: 1.531839370727539e-05
# ********** now running lsp with #basis dimension = 9 ***********
# --------approximate solution path for # itr = 10 complete--------
# # epoch: 10	 sup error: 1.3053417205810547e-05
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 20	 sup error: 1.2308359146118164e-05
# ********** now running lsp with #basis dimension = 10 ***********
# --------approximate solution path for # itr = 10 complete--------
# # epoch: 10	 sup error: 1.1861324310302734e-05
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 20	 sup error: 1.132488250787933e-06
# --------approximate solution path for # itr = 30 complete--------
# # epoch: 30	 sup error: 8.940696716308594e-07
# ********** now running lsp with #basis dimension = 11 ***********
# --------approximate solution path for # itr = 10 complete--------
# # epoch: 10	 sup error: 6.556510925292969e-07
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 20	 sup error: 6.556510925292969e-07
# ********** now running lsp with #basis dimension = 12 ***********
# --------approximate solution path for # itr = 10 complete--------
# # epoch: 10	 sup error: 6.556510925292969e-07
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 20	 sup error: 6.556510925292969e-07

# %%
def thresh_basis(basis_dim):
    return 0.1**(4)

# %%
np.random.seed(8675309)
torch.manual_seed(8675309)

num_itr_history, sup_err_history, breaks = lsp_boosting(input_dim, start_basis_dim, end_basis_dim,
                                        phi_lam, max_epochs, GD_data_loader,  test_data_loader,
                                        loss_fn, lam_min, lam_max, true_losses, init_lr=init_lr,
                                        thresh_basis=thresh_basis, record_frequency=10,
                                        distribution='uniform', device=device, trace_frequency=10)
# Out:
# ********** now running lsp with #basis dimension = 5 ***********
# --------approximate solution path for # itr = 10 complete--------
# # epoch: 10	 sup error: 3.808290511369705
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 20	 sup error: 0.4882354736328125
# --------approximate solution path for # itr = 30 complete--------
# # epoch: 30	 sup error: 0.314990758895874
# --------approximate solution path for # itr = 40 complete--------
# # epoch: 40	 sup error: 0.061185866594314575
# --------approximate solution path for # itr = 50 complete--------
# # epoch: 50	 sup error: 0.04096655547618866
# --------approximate solution path for # itr = 60 complete--------
# # epoch: 60	 sup error: 0.023631885647773743
# --------approximate solution path for # itr = 70 complete--------
# # epoch: 70	 sup error: 0.01431553065776825
# --------approximate solution path for # itr = 80 complete--------
# # epoch: 80	 sup error: 0.009075149893760681
# --------approximate solution path for # itr = 90 complete--------
# # epoch: 90	 sup error: 0.006007015705108643
# --------approximate solution path for # itr = 100 complete--------
# # epoch: 100	 sup error: 0.004100725054740906
# --------approximate solution path for # itr = 110 complete--------
# # epoch: 110	 sup error: 0.0028186142444610596
# --------approximate solution path for # itr = 120 complete--------
# # epoch: 120	 sup error: 0.0019757449626922607
# --------approximate solution path for # itr = 130 complete--------
# # epoch: 130	 sup error: 0.0013907700777053833
# --------approximate solution path for # itr = 140 complete--------
# # epoch: 140	 sup error: 0.0009855926036834717
# --------approximate solution path for # itr = 150 complete--------
# # epoch: 150	 sup error: 0.0007232129573822021
# --------approximate solution path for # itr = 160 complete--------
# # epoch: 160	 sup error: 0.000594794750213623
# --------approximate solution path for # itr = 170 complete--------
# # epoch: 170	 sup error: 0.0005450248718262274
# --------approximate solution path for # itr = 180 complete--------
# # epoch: 180	 sup error: 0.0005306601524353027
# --------approximate solution path for # itr = 190 complete--------
# # epoch: 190	 sup error: 0.0005258321762085516
# --------approximate solution path for # itr = 200 complete--------
# # epoch: 200	 sup error: 0.00048810243606572934
# --------approximate solution path for # itr = 210 complete--------
# # epoch: 210	 sup error: 0.00046437978744506836
# --------approximate solution path for # itr = 220 complete--------
# # epoch: 220	 sup error: 0.0005176067352294922
# ********** now running lsp with #basis dimension = 6 ***********
# --------approximate solution path for # itr = 10 complete--------
# # epoch: 10	 sup error: 0.00024572014808654785
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 20	 sup error: 0.00023245811462402344
# ********** now running lsp with #basis dimension = 7 ***********
# --------approximate solution path for # itr = 10 complete--------
# # epoch: 10	 sup error: 0.00026404857635498047
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 20	 sup error: 9.281933307647705e-05
# --------approximate solution path for # itr = 30 complete--------
# # epoch: 30	 sup error: 8.448958396911621e-05
# ********** now running lsp with #basis dimension = 8 ***********
# --------approximate solution path for # itr = 10 complete--------
# # epoch: 10	 sup error: 8.26120376586914e-05
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 20	 sup error: 2.4646520614624023e-05
# --------approximate solution path for # itr = 30 complete--------
# # epoch: 30	 sup error: 2.0205974578857422e-05
# ********** now running lsp with #basis dimension = 9 ***********
# --------approximate solution path for # itr = 10 complete--------
# # epoch: 10	 sup error: 1.7464160919189453e-05
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 20	 sup error: 1.5497207641601562e-05
# ********** now running lsp with #basis dimension = 10 ***********
# --------approximate solution path for # itr = 10 complete--------
# # epoch: 10	 sup error: 1.3887882232666016e-05
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 20	 sup error: 1.1533498764038086e-05
# ********** now running lsp with #basis dimension = 11 ***********
# --------approximate solution path for # itr = 10 complete--------
# # epoch: 10	 sup error: 1.1414289474487305e-05
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 20	 sup error: 1.0460615158081055e-05
# ********** now running lsp with #basis dimension = 12 ***********
# --------approximate solution path for # itr = 10 complete--------
# # epoch: 10	 sup error: 7.18235969543457e-06
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 20	 sup error: 6.288290023803711e-06

# %%
pd.DataFrame(np.array(breaks), columns=['breaks']).to_csv('LSP_results_exact_boosted_breaks_legendre.csv', index=False)

# %%
file_path = 'LSP_results_exact_boosted_legendre.csv'

LSP_results_exact = pd.DataFrame(np.column_stack((num_itr_history, sup_err_history)), columns=['num_itr', 'sup_err'])

# Save the DataFrame to a CSV file
LSP_results_exact.to_csv(file_path, index=False)

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Display the DataFrame
df
# Out:
#     num_itr       sup_err
# 0      10.0  3.808291e+00
# 1      20.0  4.882355e-01
# 2      30.0  3.149908e-01
# 3      40.0  6.118584e-02
# 4      50.0  4.096654e-02
# 5      60.0  2.363187e-02
# 6      70.0  1.431553e-02
# 7      80.0  9.075150e-03
# 8      90.0  6.006986e-03
# 9     100.0  4.100710e-03
# 10    110.0  2.818584e-03
# 11    120.0  1.975745e-03
# 12    130.0  1.388729e-03
# 13    140.0  1.305252e-03
# 14    150.0  4.302859e-04
# 15    160.0  3.151000e-04
# 16    170.0  3.314614e-04
# 17    180.0  3.336668e-04
# 18    190.0  3.446341e-04
# 19    200.0  3.695488e-04
# 20    210.0  3.202856e-04
# 21    220.0  1.388788e-05
# 22    230.0  1.427531e-05
# 23    240.0  4.851818e-05
# 24    250.0  3.767014e-05
# 25    260.0  1.531839e-05
# 26    270.0  1.305342e-05
# 27    280.0  1.230836e-05
# 28    290.0  1.186132e-05
# 29    300.0  1.132488e-06
# 30    310.0  8.940697e-07
# 31    320.0  6.556511e-07
# 32    330.0  6.556511e-07
# 33    340.0  6.556511e-07
# 34    350.0  6.556511e-07

# %% [markdown]
# # Noisy gradient oracle

# %%
max_epochs = 200

# %%
phi_lam = scaled_shifted_legendre

# %%
def thresh_basis(basis_dim):
    return 0.1**(basis_dim/5 + 5) * (50**2)

# %%
# beta/sqrt(t)
def step_size(t, beta):
    return beta/np.sqrt(t+1)

# %%
start_basis_dim = 5
end_basis_dim = 10
beta = 0.5

# %%
np.random.seed(8675309)
torch.manual_seed(8675309)

num_itr_history, sup_err_history, breaks = lsp_boosting(input_dim, start_basis_dim, end_basis_dim, phi_lam, max_epochs,
                                                        SGD_data_loader, test_data_loader, loss_fn, lam_min, lam_max,
                                                        true_losses, step_size=step_size, const=beta, weighted_avg=True,
                                                        avg_upon_prev=True, thresh_basis=thresh_basis, record_frequency=10,
                                                        distribution='uniform', device=device, trace_frequency=10)
# Out:
# ********** now running lsp with #basis dimension = 5 ***********
# --------approximate solution path for # itr = 10 complete--------
# # epoch: 10	 sup error: 0.11422920227050781
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 20	 sup error: 0.01976636052131653
# --------approximate solution path for # itr = 30 complete--------
# # epoch: 30	 sup error: 0.009443342685699463
# --------approximate solution path for # itr = 40 complete--------
# # epoch: 40	 sup error: 0.002981826663017273
# --------approximate solution path for # itr = 50 complete--------
# # epoch: 50	 sup error: 0.002051115036010742
# --------approximate solution path for # itr = 60 complete--------
# # epoch: 60	 sup error: 0.0017272531986236572
# --------approximate solution path for # itr = 70 complete--------
# # epoch: 70	 sup error: 0.0030344128608703613
# --------approximate solution path for # itr = 80 complete--------
# # epoch: 80	 sup error: 0.0031889528036117554
# --------approximate solution path for # itr = 90 complete--------
# # epoch: 90	 sup error: 0.0019741803407669067
# --------approximate solution path for # itr = 100 complete--------
# # epoch: 100	 sup error: 0.0011832565069198608
# --------approximate solution path for # itr = 110 complete--------
# # epoch: 110	 sup error: 0.0012192130088806152
# --------approximate solution path for # itr = 120 complete--------
# # epoch: 120	 sup error: 0.0014258623123168945
# --------approximate solution path for # itr = 130 complete--------
# # epoch: 130	 sup error: 0.00106048583984375
# --------approximate solution path for # itr = 140 complete--------
# # epoch: 140	 sup error: 0.0009325146675109863
# --------approximate solution path for # itr = 150 complete--------
# # epoch: 150	 sup error: 0.0011007189750671387
# --------approximate solution path for # itr = 160 complete--------
# # epoch: 160	 sup error: 0.0009725987911224365
# --------approximate solution path for # itr = 170 complete--------
# # epoch: 170	 sup error: 0.0009678900241851807
# --------approximate solution path for # itr = 180 complete--------
# # epoch: 180	 sup error: 0.0011857151985168457
# --------approximate solution path for # itr = 190 complete--------
# # epoch: 190	 sup error: 0.0012883245944976807
# --------approximate solution path for # itr = 200 complete--------
# # epoch: 200	 sup error: 0.0010606646537780762
# ********** now running lsp with #basis dimension = 6 ***********
# --------approximate solution path for # itr = 10 complete--------
# # epoch: 10	 sup error: 0.001009523868560791
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 20	 sup error: 0.0009312033653259277
# --------approximate solution path for # itr = 30 complete--------
# # epoch: 30	 sup error: 0.0008503198623657227
# --------approximate solution path for # itr = 40 complete--------
# # epoch: 40	 sup error: 0.0006751716136932373
# --------approximate solution path for # itr = 50 complete--------
# # epoch: 50	 sup error: 0.0005334615707397461
# --------approximate solution path for # itr = 60 complete--------
# # epoch: 60	 sup error: 0.0005750060081481934
# --------approximate solution path for # itr = 70 complete--------
# # epoch: 70	 sup error: 0.0006523728370666504
# --------approximate solution path for # itr = 80 complete--------
# # epoch: 80	 sup error: 0.0006800293922424316
# --------approximate solution path for # itr = 90 complete--------
# # epoch: 90	 sup error: 0.0006966292858123779
# --------approximate solution path for # itr = 100 complete--------
# # epoch: 100	 sup error: 0.0006846487522125244
# --------approximate solution path for # itr = 110 complete--------
# # epoch: 110	 sup error: 0.0006428956985473633
# --------approximate solution path for # itr = 120 complete--------
# # epoch: 120	 sup error: 0.0006258189678192139
# --------approximate solution path for # itr = 130 complete--------
# # epoch: 130	 sup error: 0.0005751550197601318
# ********** now running lsp with #basis dimension = 7 ***********
# --------approximate solution path for # itr = 10 complete--------
# # epoch: 10	 sup error: 0.0004876554012298584
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 20	 sup error: 0.0004719942808151245
# --------approximate solution path for # itr = 30 complete--------
# # epoch: 30	 sup error: 0.00046008825302124023
# --------approximate solution path for # itr = 40 complete--------
# # epoch: 40	 sup error: 0.0004400908946990967
# --------approximate solution path for # itr = 50 complete--------
# # epoch: 50	 sup error: 0.00046628713607788086
# --------approximate solution path for # itr = 60 complete--------
# # epoch: 60	 sup error: 0.0004482865333557129
# --------approximate solution path for # itr = 70 complete--------
# # epoch: 70	 sup error: 0.00042372941970825195
# --------approximate solution path for # itr = 80 complete--------
# # epoch: 80	 sup error: 0.0003756582736968994
# --------approximate solution path for # itr = 90 complete--------
# # epoch: 90	 sup error: 0.0003440678119659424
# --------approximate solution path for # itr = 100 complete--------
# # epoch: 100	 sup error: 0.00033155083656311035
# --------approximate solution path for # itr = 110 complete--------
# # epoch: 110	 sup error: 0.00031831860542297363
# --------approximate solution path for # itr = 120 complete--------
# # epoch: 120	 sup error: 0.0003001093864440918
# --------approximate solution path for # itr = 130 complete--------
# # epoch: 130	 sup error: 0.0002880096435546875
# --------approximate solution path for # itr = 140 complete--------
# # epoch: 140	 sup error: 0.00029046833515167236
# --------approximate solution path for # itr = 150 complete--------
# # epoch: 150	 sup error: 0.00032266974449157715
# --------approximate solution path for # itr = 160 complete--------
# # epoch: 160	 sup error: 0.0003590881824493408
# --------approximate solution path for # itr = 170 complete--------
# # epoch: 170	 sup error: 0.0004069805145263672
# --------approximate solution path for # itr = 180 complete--------
# # epoch: 180	 sup error: 0.00043235719203948975
# --------approximate solution path for # itr = 190 complete--------
# # epoch: 190	 sup error: 0.000435560941696167
# --------approximate solution path for # itr = 200 complete--------
# # epoch: 200	 sup error: 0.0004156827926635742
# ********** now running lsp with #basis dimension = 8 ***********
# --------approximate solution path for # itr = 10 complete--------
# # epoch: 10	 sup error: 0.0003990083932876587
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 20	 sup error: 0.0003967583179473877
# --------approximate solution path for # itr = 30 complete--------
# # epoch: 30	 sup error: 0.0003851354122161865
# --------approximate solution path for # itr = 40 complete--------
# # epoch: 40	 sup error: 0.00036075711250305176
# --------approximate solution path for # itr = 50 complete--------
# # epoch: 50	 sup error: 0.0003459453582763672
# --------approximate solution path for # itr = 60 complete--------
# # epoch: 60	 sup error: 0.00035265088081359863
# --------approximate solution path for # itr = 70 complete--------
# # epoch: 70	 sup error: 0.0003396272659301758
# --------approximate solution path for # itr = 80 complete--------
# # epoch: 80	 sup error: 0.0003164559602737427
# --------approximate solution path for # itr = 90 complete--------
# # epoch: 90	 sup error: 0.0002880692481994629
# --------approximate solution path for # itr = 100 complete--------
# # epoch: 100	 sup error: 0.0002690553665161133
# --------approximate solution path for # itr = 110 complete--------
# # epoch: 110	 sup error: 0.0002473294734954834
# --------approximate solution path for # itr = 120 complete--------
# # epoch: 120	 sup error: 0.00023327767848968506
# --------approximate solution path for # itr = 130 complete--------
# # epoch: 130	 sup error: 0.00023105740547180176
# --------approximate solution path for # itr = 140 complete--------
# # epoch: 140	 sup error: 0.00023236870765686035
# --------approximate solution path for # itr = 150 complete--------
# # epoch: 150	 sup error: 0.0002402961254119873
# --------approximate solution path for # itr = 160 complete--------
# # epoch: 160	 sup error: 0.00024583935737609863
# --------approximate solution path for # itr = 170 complete--------
# # epoch: 170	 sup error: 0.00025153160095214844
# --------approximate solution path for # itr = 180 complete--------
# # epoch: 180	 sup error: 0.00024968385696411133
# --------approximate solution path for # itr = 190 complete--------
# # epoch: 190	 sup error: 0.0002377033233642578
# --------approximate solution path for # itr = 200 complete--------
# # epoch: 200	 sup error: 0.000233381986618042
# ********** now running lsp with #basis dimension = 9 ***********
# --------approximate solution path for # itr = 10 complete--------
# # epoch: 10	 sup error: 0.00023990869522094727
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 20	 sup error: 0.0002434849739074707
# --------approximate solution path for # itr = 30 complete--------
# # epoch: 30	 sup error: 0.0002461075782775879
# --------approximate solution path for # itr = 40 complete--------
# # epoch: 40	 sup error: 0.00025388598442077637
# --------approximate solution path for # itr = 50 complete--------
# # epoch: 50	 sup error: 0.0002652406692504883
# --------approximate solution path for # itr = 60 complete--------
# # epoch: 60	 sup error: 0.00026866793632507324
# --------approximate solution path for # itr = 70 complete--------
# # epoch: 70	 sup error: 0.0002595484256744385
# --------approximate solution path for # itr = 80 complete--------
# # epoch: 80	 sup error: 0.00025340914726257324
# --------approximate solution path for # itr = 90 complete--------
# # epoch: 90	 sup error: 0.0002562999725341797
# --------approximate solution path for # itr = 100 complete--------
# # epoch: 100	 sup error: 0.0002589225769042969
# --------approximate solution path for # itr = 110 complete--------
# # epoch: 110	 sup error: 0.0002607107162475586
# --------approximate solution path for # itr = 120 complete--------
# # epoch: 120	 sup error: 0.00025832653045654297
# --------approximate solution path for # itr = 130 complete--------
# # epoch: 130	 sup error: 0.00026220083236694336
# --------approximate solution path for # itr = 140 complete--------
# # epoch: 140	 sup error: 0.0002624690532684326
# --------approximate solution path for # itr = 150 complete--------
# # epoch: 150	 sup error: 0.0002643465995788574
# --------approximate solution path for # itr = 160 complete--------
# # epoch: 160	 sup error: 0.00026357173919677734
# --------approximate solution path for # itr = 170 complete--------
# # epoch: 170	 sup error: 0.000271037220954895
# --------approximate solution path for # itr = 180 complete--------
# # epoch: 180	 sup error: 0.00028620660305023193
# --------approximate solution path for # itr = 190 complete--------
# # epoch: 190	 sup error: 0.0002912282943725586
# --------approximate solution path for # itr = 200 complete--------
# # epoch: 200	 sup error: 0.00029240548610687256

# %%
pd.DataFrame(np.array(breaks), columns=['breaks']).to_csv('LSP_results_noisy_boosted_breaks_legendre.csv', index=False)

# %%
file_path = 'LSP_results_noisy_boosted_legendre.csv'

LSP_results_noisy = pd.DataFrame(np.column_stack((num_itr_history, sup_err_history)), columns=['num_itr', 'sup_err'])

# Save the DataFrame to a CSV file
LSP_results_noisy.to_csv(file_path, index=False)

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Display the DataFrame
df
# Out:
#     num_itr   sup_err
# 0      10.0  0.114229
# 1      20.0  0.019766
# 2      30.0  0.009443
# 3      40.0  0.002982
# 4      50.0  0.002051
# ..      ...       ...
# 88    890.0  0.000264
# 89    900.0  0.000271
# 90    910.0  0.000286
# 91    920.0  0.000291
# 92    930.0  0.000292
#
# [93 rows x 2 columns]
