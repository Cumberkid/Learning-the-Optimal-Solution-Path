# %% [markdown]
# # 01 Import libraries

# %%
import numpy as np
import torch

device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
import pandas as pd

# %%
import importlib

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import lib
importlib.reload(lib)
# Out:
# <module 'lib' from 'c:\\Users\\dongq\\OneDrive\\Desktop\\New results\\Portfolio Allocation\\Learning-the-Optimal-Solution-Path\\lib\\__init__.py'>

# %%
from lib.lsp.basis_generator import dampen_laguerre
from lib.lsp.basis_tf_module import Basis_TF_SGD
from lib.lsp.learn_solution_path import adaptive_lsp
from lib.lsp.loss_fn_lsp import reg_exp_weighted_logit
from lib.fast_tensor_data_loader import FastTensorDataLoader

# %% [markdown]
# # 02 Load data

# %%
# file path for Colab. May need to change this
X_df = pd.read_csv('X_processed.csv')
y_df = pd.read_csv('y_processed.csv')

# %%
X = np.array(X_df)
y = np.array(y_df).squeeze()

# %%
train_X = torch.tensor(X, dtype=torch.float32)
train_y = torch.tensor(y, dtype=torch.float32)

# %%
# full gradient descent uses all data points
GD_data_loader = FastTensorDataLoader(train_X, train_y, batch_size=1000, shuffle=True, )
# test data
test_data_loader = FastTensorDataLoader(train_X, train_y, batch_size=1000, shuffle=False, )

# %%
lam_max = [20]
lam_min = [0]
input_dim = X.shape[1]
loss_fn = reg_exp_weighted_logit

# %%
# Read the CSV file into a DataFrame
# truth = pd.read_csv('/content/Learning-the-Optimal-Solution-Path/experiments/fair-regression/results/exact_soln_list.csv')
truth = pd.read_csv('exact_soln_list_laguerre.csv')

# Display the DataFrame
truth
# Out:
#         losses   theta_0   theta_1   theta_2   theta_3   theta_4   theta_5  \
# 0     0.251592 -0.290164  0.186074  0.232884 -0.027476  0.166136  0.110354
# 1     0.251645 -0.290092  0.186073  0.232887 -0.027478  0.166136  0.110326
# 2     0.251698 -0.290020  0.186071  0.232891 -0.027481  0.166136  0.110298
# 3     0.251751 -0.289947  0.186070  0.232895 -0.027484  0.166136  0.110270
# 4     0.251804 -0.289874  0.186068  0.232898 -0.027487  0.166136  0.110242
# ...        ...       ...       ...       ...       ...       ...       ...
# 1019  0.425709  0.608973  0.015982  0.030750 -0.012680  0.033522 -0.189898
# 1020  0.405809  0.627298  0.006731  0.017247 -0.013635  0.025534 -0.197376
# 1021  0.382318  0.647696 -0.004087  0.001661 -0.014793  0.016128 -0.205935
# 1022  0.354260  0.670989 -0.016946 -0.016535 -0.016181  0.004871 -0.216011
# 1023  0.320320  0.698369 -0.032464 -0.037983 -0.017807 -0.008802 -0.228186
#
#        theta_6   theta_7   theta_8  ...  theta_36  theta_37  theta_38  \
# 0     0.142358  0.009975  0.157656  ...  0.000471  0.023097 -0.007038
# 1     0.142336  0.009961  0.157669  ...  0.000487  0.023069 -0.007039
# 2     0.142315  0.009946  0.157682  ...  0.000503  0.023042 -0.007041
# 3     0.142294  0.009931  0.157695  ...  0.000519  0.023015 -0.007042
# 4     0.142272  0.009916  0.157708  ...  0.000534  0.022988 -0.007043
# ...        ...       ...       ...  ...       ...       ...       ...
# 1019 -0.060873 -0.075246  0.138251  ...  0.104496 -0.190631 -0.003899
# 1020 -0.075369 -0.070611  0.125166  ...  0.104706 -0.193085 -0.002800
# 1021 -0.094402 -0.064959  0.109066  ...  0.104903 -0.195830 -0.001589
# 1022 -0.119855 -0.058109  0.089182  ...  0.105111 -0.199002 -0.000252
# 1023 -0.154196 -0.049927  0.064680  ...  0.105391 -0.202811  0.001220
#
#       theta_39  theta_40  theta_41  theta_42  theta_43  theta_44  theta_45
# 0     0.003151  0.004510 -0.024440  0.000471 -0.129229 -0.096597 -0.041242
# 1     0.003154  0.004514 -0.024434  0.000487 -0.129220 -0.096579 -0.041224
# 2     0.003157  0.004518 -0.024429  0.000503 -0.129210 -0.096561 -0.041206
# 3     0.003160  0.004522 -0.024423  0.000519 -0.129201 -0.096543 -0.041188
# 4     0.003162  0.004526 -0.024417  0.000534 -0.129191 -0.096525 -0.041170
# ...        ...       ...       ...       ...       ...       ...       ...
# 1019  0.016846  0.022910  0.049139  0.104496  0.117941  0.139251  0.161150
# 1020  0.016029  0.021890  0.052167  0.104706  0.126507  0.144123  0.163584
# 1021  0.015089  0.020769  0.055620  0.104903  0.136154  0.149574  0.166138
# 1022  0.014026  0.019573  0.059569  0.105111  0.147241  0.155866  0.168880
# 1023  0.012859  0.018354  0.064084  0.105391  0.160226  0.163374  0.171958
#
# [1024 rows x 47 columns]

# %%
selected_columns = ['theta_0', 'theta_1', 'theta_2', 'theta_3', 'theta_4',
                    'theta_5', 'theta_6', 'theta_7', 'theta_8', 'theta_9',
                    'theta_10', 'theta_11', 'theta_12', 'theta_13', 'theta_14',
                    'theta_15', 'theta_16', 'theta_17', 'theta_18', 'theta_19',
                    'theta_20', 'theta_21', 'theta_22', 'theta_23', 'theta_24',
                    'theta_25', 'theta_26', 'theta_27', 'theta_28', 'theta_29',
                    'theta_30', 'theta_31', 'theta_32', 'theta_33', 'theta_34',
                    'theta_35', 'theta_36', 'theta_37', 'theta_38', 'theta_39',
                    'theta_40', 'theta_41', 'theta_42', 'theta_43', 'theta_44',
                    'theta_45']
true_thetas = truth[selected_columns].to_numpy()
true_losses = truth['losses'].to_numpy()

# %%
# import time

# %% [markdown]
# # 03 SGD

# %%
max_epochs = 300

# %%
phi_lam = dampen_laguerre

# %%
start_basis_dim = 5
end_basis_dim = 13
init_lr = 0.0625

# %%
def thresh_basis(basis_dim):
    return 0.1**(basis_dim/7 + 1.3)

# %%
np.random.seed(8675309)
torch.manual_seed(8675309)

num_itr_history, sup_err_history, breaks = adaptive_lsp(input_dim, start_basis_dim, end_basis_dim,
                                        phi_lam, max_epochs, GD_data_loader, test_data_loader,
                                        loss_fn, lam_min, lam_max, true_losses, init_lr=init_lr,
                                        q=1.5, thresh_basis=thresh_basis, record_frequency=10,
                                        distribution='exponential', device=device, trace_frequency=10)
# Out:
# ********** now running lsp with #basis dimension = 5 ***********
# --------approximate solution path for # itr = 10 complete--------
# # epoch: 10	 sup error: 0.17033571004867554
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 20	 sup error: 0.12579107284545898
# --------approximate solution path for # itr = 30 complete--------
# # epoch: 30	 sup error: 0.1772816181182862
# --------approximate solution path for # itr = 40 complete--------
# # epoch: 40	 sup error: 0.290246456861496
# --------approximate solution path for # itr = 50 complete--------
# # epoch: 50	 sup error: 0.29006937146186834
# --------approximate solution path for # itr = 60 complete--------
# # epoch: 60	 sup error: 0.24645903706550604
# --------approximate solution path for # itr = 70 complete--------
# # epoch: 70	 sup error: 0.19762173295021063
# --------approximate solution path for # itr = 80 complete--------
# # epoch: 80	 sup error: 0.10872614383697515
# --------approximate solution path for # itr = 90 complete--------
# # epoch: 90	 sup error: 0.07210606336593628
# --------approximate solution path for # itr = 100 complete--------
# # epoch: 100	 sup error: 0.06728923320770264
# --------approximate solution path for # itr = 110 complete--------
# # epoch: 110	 sup error: 0.061665683984756525
# --------approximate solution path for # itr = 120 complete--------
# # epoch: 120	 sup error: 0.08270621299743658
# --------approximate solution path for # itr = 130 complete--------
# # epoch: 130	 sup error: 0.10285219550132757
# --------approximate solution path for # itr = 140 complete--------
# # epoch: 140	 sup error: 0.10417789220809942
# --------approximate solution path for # itr = 150 complete--------
# # epoch: 150	 sup error: 0.11093670129776007
# ********** now running lsp with #basis dimension = 6 ***********
# --------approximate solution path for # itr = 10 complete--------
# # epoch: 10	 sup error: 0.08267214894294744
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 20	 sup error: 0.08404576778411871
# --------approximate solution path for # itr = 30 complete--------
# # epoch: 30	 sup error: 0.06258511543273931
# --------approximate solution path for # itr = 40 complete--------
# # epoch: 40	 sup error: 0.0320776104927063
# --------approximate solution path for # itr = 50 complete--------
# # epoch: 50	 sup error: 0.03950855135917669
# --------approximate solution path for # itr = 60 complete--------
# # epoch: 60	 sup error: 0.04053312540054327
# --------approximate solution path for # itr = 70 complete--------
# # epoch: 70	 sup error: 0.02371573448181158
# --------approximate solution path for # itr = 80 complete--------
# # epoch: 80	 sup error: 0.02415865659713745
# ********** now running lsp with #basis dimension = 7 ***********
# --------approximate solution path for # itr = 10 complete--------
# # epoch: 10	 sup error: 0.06038087606430059
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 20	 sup error: 0.07265672087669378
# ********** now running lsp with #basis dimension = 8 ***********
# --------approximate solution path for # itr = 10 complete--------
# # epoch: 10	 sup error: 0.015759646892547607
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 20	 sup error: 0.016692101955413874
# --------approximate solution path for # itr = 30 complete--------
# # epoch: 30	 sup error: 0.018490850925445557
# --------approximate solution path for # itr = 40 complete--------
# # epoch: 40	 sup error: 0.0204595029354096
# --------approximate solution path for # itr = 50 complete--------
# # epoch: 50	 sup error: 0.029537111520767267
# --------approximate solution path for # itr = 60 complete--------
# # epoch: 60	 sup error: 0.029664099216461237
# --------approximate solution path for # itr = 70 complete--------
# # epoch: 70	 sup error: 0.029999464750289973
# --------approximate solution path for # itr = 80 complete--------
# # epoch: 80	 sup error: 0.030275613069534357
# --------approximate solution path for # itr = 90 complete--------
# # epoch: 90	 sup error: 0.031339108943939264
# --------approximate solution path for # itr = 100 complete--------
# # epoch: 100	 sup error: 0.03179642558097845
# --------approximate solution path for # itr = 110 complete--------
# # epoch: 110	 sup error: 0.03251877427101141
# --------approximate solution path for # itr = 120 complete--------
# # epoch: 120	 sup error: 0.03340154886245733
# ********** now running lsp with #basis dimension = 9 ***********
# --------approximate solution path for # itr = 10 complete--------
# # epoch: 10	 sup error: 0.04030913114547735
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 20	 sup error: 0.0442513525485993
# --------approximate solution path for # itr = 30 complete--------
# # epoch: 30	 sup error: 0.04986503720283514
# --------approximate solution path for # itr = 40 complete--------
# # epoch: 40	 sup error: 0.057073682546615656
# ********** now running lsp with #basis dimension = 10 ***********
# --------approximate solution path for # itr = 10 complete--------
# # epoch: 10	 sup error: 0.015125721693038996
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 20	 sup error: 0.01845362782478338
# --------approximate solution path for # itr = 30 complete--------
# # epoch: 30	 sup error: 0.022176712751388605
# --------approximate solution path for # itr = 40 complete--------
# # epoch: 40	 sup error: 0.022993594408035334
# --------approximate solution path for # itr = 50 complete--------
# # epoch: 50	 sup error: 0.024240702390670832
# --------approximate solution path for # itr = 60 complete--------
# # epoch: 60	 sup error: 0.024333089590072687
# --------approximate solution path for # itr = 70 complete--------
# # epoch: 70	 sup error: 0.02538099884986883
# --------approximate solution path for # itr = 80 complete--------
# # epoch: 80	 sup error: 0.026454836130142267
# --------approximate solution path for # itr = 90 complete--------
# # epoch: 90	 sup error: 0.027417361736297663
# ********** now running lsp with #basis dimension = 11 ***********
# --------approximate solution path for # itr = 10 complete--------
# # epoch: 10	 sup error: 0.027546107769012507
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 20	 sup error: 0.028711497783660944
# --------approximate solution path for # itr = 30 complete--------
# # epoch: 30	 sup error: 0.007467448711395264
# --------approximate solution path for # itr = 40 complete--------
# # epoch: 40	 sup error: 0.006215453147888239
# --------approximate solution path for # itr = 50 complete--------
# # epoch: 50	 sup error: 0.004567474126815851
# --------approximate solution path for # itr = 60 complete--------
# # epoch: 60	 sup error: 0.004470795392990168
# --------approximate solution path for # itr = 70 complete--------
# # epoch: 70	 sup error: 0.004304885864257868
# --------approximate solution path for # itr = 80 complete--------
# # epoch: 80	 sup error: 0.004212677478790339
# --------approximate solution path for # itr = 90 complete--------
# # epoch: 90	 sup error: 0.004108905792236384
# ********** now running lsp with #basis dimension = 12 ***********
# --------approximate solution path for # itr = 10 complete--------
# # epoch: 10	 sup error: 0.0035280585289001465
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 20	 sup error: 0.0037134587764740545
# --------approximate solution path for # itr = 30 complete--------
# # epoch: 30	 sup error: 0.004954099655151423
# --------approximate solution path for # itr = 40 complete--------
# # epoch: 40	 sup error: 0.005176663398742731
# --------approximate solution path for # itr = 50 complete--------
# # epoch: 50	 sup error: 0.005776345729827936
# --------approximate solution path for # itr = 60 complete--------
# # epoch: 60	 sup error: 0.00581768155097967
# --------approximate solution path for # itr = 70 complete--------
# # epoch: 70	 sup error: 0.0059713721275330145
# --------approximate solution path for # itr = 80 complete--------
# # epoch: 80	 sup error: 0.006108939647674616
# --------approximate solution path for # itr = 90 complete--------
# # epoch: 90	 sup error: 0.0038211941719055176
# --------approximate solution path for # itr = 100 complete--------
# # epoch: 100	 sup error: 0.0039033591747283936
# --------approximate solution path for # itr = 110 complete--------
# # epoch: 110	 sup error: 0.004121929407119751
# --------approximate solution path for # itr = 120 complete--------
# # epoch: 120	 sup error: 0.004011392593383789
# --------approximate solution path for # itr = 130 complete--------
# # epoch: 130	 sup error: 0.003686875104904175
# --------approximate solution path for # itr = 140 complete--------
# # epoch: 140	 sup error: 0.003465324640274048
# --------approximate solution path for # itr = 150 complete--------
# # epoch: 150	 sup error: 0.003244370222091675
# --------approximate solution path for # itr = 160 complete--------
# # epoch: 160	 sup error: 0.00297662615776062
# --------approximate solution path for # itr = 170 complete--------
# # epoch: 170	 sup error: 0.0028200745582580566
# --------approximate solution path for # itr = 180 complete--------
# # epoch: 180	 sup error: 0.002654731273651123
# --------approximate solution path for # itr = 190 complete--------
# # epoch: 190	 sup error: 0.002750635147094782

# %%
pd.DataFrame(np.array(breaks), columns=['breaks']).to_csv('LSP_results_exact_boosted_breaks_laguerre.csv', index=False)

# %%
file_path = 'LSP_results_exact_boosted_laguerre.csv'

LSP_results_exact = pd.DataFrame(np.column_stack((num_itr_history, sup_err_history)), columns=['num_itr', 'sup_err'])

# Save the DataFrame to a CSV file
LSP_results_exact.to_csv(file_path, index=False)

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Display the DataFrame
df
# Out:
#     num_itr   sup_err
# 0      10.0  0.170336
# 1      20.0  0.125791
# 2      30.0  0.177282
# 3      40.0  0.290246
# 4      50.0  0.290069
# ..      ...       ...
# 73    740.0  0.003244
# 74    750.0  0.002977
# 75    760.0  0.002820
# 76    770.0  0.002655
# 77    780.0  0.002751
#
# [78 rows x 2 columns]
