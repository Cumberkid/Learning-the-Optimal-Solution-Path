# %% [markdown]
# # 01 Import libraries

# %%
import numpy as np
import torch

device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
import pandas as pd

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import importlib

# %%
import lib
importlib.reload(lib)
# Out:
# <module 'lib' from 'c:\\Users\\dongq\\OneDrive\\Desktop\\New results\\Portfolio Allocation\\Learning-the-Optimal-Solution-Path\\lib\\__init__.py'>

# %%
from lib.lsp.basis_generator import dampen_laguerre
from lib.lsp.basis_tf_module import Basis_TF_SGD
from lib.lsp.learn_solution_path import learn_solution_path
from lib.lsp.loss_fn_lsp import reg_exp_weighted_logit
from lib.fast_tensor_data_loader import FastTensorDataLoader
from lib.lsp.utils_lsp import get_errs_lsp

# %% [markdown]
# # 02 Instantiate dataset

# %%
# file path
X_df = pd.read_csv('X_processed.csv')
y_df = pd.read_csv('y_processed.csv')

# %%
X = np.array(X_df)
y = np.array(y_df).squeeze()

# %%
train_X = torch.tensor(X, dtype=torch.float32)
train_y = torch.tensor(y, dtype=torch.float32)

# %%
# full gradient descent uses all data points
GD_data_loader = FastTensorDataLoader(train_X, train_y, batch_size=1000, shuffle=True, )
# test data
test_data_loader = FastTensorDataLoader(train_X, train_y, batch_size=1000, shuffle=False, )

# %%
lam_max = [20]
lam_min = [0]
input_dim = X.shape[1]
loss_fn = reg_exp_weighted_logit

# %%
# Read the CSV file into a DataFrame
truth = pd.read_csv('exact_soln_list_laguerre.csv')

# Display the DataFrame
truth
# Out:
#         losses   theta_0   theta_1   theta_2   theta_3   theta_4   theta_5  \
# 0     0.251592 -0.290164  0.186074  0.232884 -0.027476  0.166136  0.110354
# 1     0.251645 -0.290092  0.186073  0.232887 -0.027478  0.166136  0.110326
# 2     0.251698 -0.290020  0.186071  0.232891 -0.027481  0.166136  0.110298
# 3     0.251751 -0.289947  0.186070  0.232895 -0.027484  0.166136  0.110270
# 4     0.251804 -0.289874  0.186068  0.232898 -0.027487  0.166136  0.110242
# ...        ...       ...       ...       ...       ...       ...       ...
# 1019  0.425709  0.608973  0.015982  0.030750 -0.012680  0.033522 -0.189898
# 1020  0.405809  0.627298  0.006731  0.017247 -0.013635  0.025534 -0.197376
# 1021  0.382318  0.647696 -0.004087  0.001661 -0.014793  0.016128 -0.205935
# 1022  0.354260  0.670989 -0.016946 -0.016535 -0.016181  0.004871 -0.216011
# 1023  0.320320  0.698369 -0.032464 -0.037983 -0.017807 -0.008802 -0.228186
#
#        theta_6   theta_7   theta_8  ...  theta_36  theta_37  theta_38  \
# 0     0.142358  0.009975  0.157656  ...  0.000471  0.023097 -0.007038
# 1     0.142336  0.009961  0.157669  ...  0.000487  0.023069 -0.007039
# 2     0.142315  0.009946  0.157682  ...  0.000503  0.023042 -0.007041
# 3     0.142294  0.009931  0.157695  ...  0.000519  0.023015 -0.007042
# 4     0.142272  0.009916  0.157708  ...  0.000534  0.022988 -0.007043
# ...        ...       ...       ...  ...       ...       ...       ...
# 1019 -0.060873 -0.075246  0.138251  ...  0.104496 -0.190631 -0.003899
# 1020 -0.075369 -0.070611  0.125166  ...  0.104706 -0.193085 -0.002800
# 1021 -0.094402 -0.064959  0.109066  ...  0.104903 -0.195830 -0.001589
# 1022 -0.119855 -0.058109  0.089182  ...  0.105111 -0.199002 -0.000252
# 1023 -0.154196 -0.049927  0.064680  ...  0.105391 -0.202811  0.001220
#
#       theta_39  theta_40  theta_41  theta_42  theta_43  theta_44  theta_45
# 0     0.003151  0.004510 -0.024440  0.000471 -0.129229 -0.096597 -0.041242
# 1     0.003154  0.004514 -0.024434  0.000487 -0.129220 -0.096579 -0.041224
# 2     0.003157  0.004518 -0.024429  0.000503 -0.129210 -0.096561 -0.041206
# 3     0.003160  0.004522 -0.024423  0.000519 -0.129201 -0.096543 -0.041188
# 4     0.003162  0.004526 -0.024417  0.000534 -0.129191 -0.096525 -0.041170
# ...        ...       ...       ...       ...       ...       ...       ...
# 1019  0.016846  0.022910  0.049139  0.104496  0.117941  0.139251  0.161150
# 1020  0.016029  0.021890  0.052167  0.104706  0.126507  0.144123  0.163584
# 1021  0.015089  0.020769  0.055620  0.104903  0.136154  0.149574  0.166138
# 1022  0.014026  0.019573  0.059569  0.105111  0.147241  0.155866  0.168880
# 1023  0.012859  0.018354  0.064084  0.105391  0.160226  0.163374  0.171958
#
# [1024 rows x 47 columns]

# %%
selected_columns = ['theta_0', 'theta_1', 'theta_2', 'theta_3', 'theta_4',
                    'theta_5', 'theta_6', 'theta_7', 'theta_8', 'theta_9',
                    'theta_10', 'theta_11', 'theta_12', 'theta_13', 'theta_14',
                    'theta_15', 'theta_16', 'theta_17', 'theta_18', 'theta_19',
                    'theta_20', 'theta_21', 'theta_22', 'theta_23', 'theta_24',
                    'theta_25', 'theta_26', 'theta_27', 'theta_28', 'theta_29',
                    'theta_30', 'theta_31', 'theta_32', 'theta_33', 'theta_34',
                    'theta_35', 'theta_36', 'theta_37', 'theta_38', 'theta_39',
                    'theta_40', 'theta_41', 'theta_42', 'theta_43', 'theta_44',
                    'theta_45']
true_thetas = truth[selected_columns].to_numpy()
true_losses = truth['losses'].to_numpy()

# %% [markdown]
# # 03 SGD with Diminishing LR by Distance Diagnostic

# %% [markdown]
# Recall that our method runs SGD over random $\tilde λ$'s with a linear basis $\Phi(\tilde \lambda)$ of our choice. We want to approximate $\theta$ with $\Phi(\lambda)\beta$, so the objective function is $\min_\beta h(\Phi(\tilde\lambda)\beta, \tilde\lambda) = (1-\tilde\lambda) BCE(X_\text{pass}\Phi(\tilde\lambda)\beta,\ y_\text{pass}) + \tilde\lambda BCE(X_\text{fail}\Phi(\tilde\lambda)\beta,\ y_\text{fail})$. For each batch of training data set, we randomize $\tilde\lambda$. If batch size = 1, then this is equivalent to a standard SGD.

# %% [markdown]
# We use diminishing learning rate for better demonstrate convergence. If we use a constant learning rate, the solution path error will eventually do a random walk after descending to a certain threshold value.
#
# Set weighted_avg to 'False' see this random walk.

# %%
max_epochs = 6000

# %%
phi_lam = dampen_laguerre

# %%
def thresh_basis(basis_dim):
    return 1e-9

# %% [markdown]
# ## num basis func = 5

# %%
basis_dim = 5
init_lr = 0.0625

# %%
np.random.seed(8675309)
torch.manual_seed(8675309)

num_itr_history, sup_err_history_last_itr, weight, lr, itr = learn_solution_path(input_dim, basis_dim, phi_lam, max_epochs,
                                                               GD_data_loader, test_data_loader, loss_fn,
                                                               lam_min, lam_max, true_losses, init_lr=init_lr,
                                                               diminish=True, q=1.5, thresh_basis=thresh_basis,
                                                               weighted_avg=False,
                                                               record_frequency=10, distribution='exponential',
                                                               device=device, trace_frequency=100)

sup_err_history_last_itr = np.array(sup_err_history_last_itr)
# Out:
# --------approximate solution path for # itr = 100 complete--------
# # epoch: 100	 sup error: 0.1301219761371613
# --------approximate solution path for # itr = 200 complete--------
# # epoch: 200	 sup error: 0.0748749971389771
# --------approximate solution path for # itr = 300 complete--------
# # epoch: 300	 sup error: 0.057764887809753473
# --------approximate solution path for # itr = 400 complete--------
# # epoch: 400	 sup error: 0.14746946096420294
# --------approximate solution path for # itr = 500 complete--------
# # epoch: 500	 sup error: 0.28371706604957586
# --------approximate solution path for # itr = 600 complete--------
# # epoch: 600	 sup error: 0.14867219328880316
# --------approximate solution path for # itr = 700 complete--------
# # epoch: 700	 sup error: 0.2867776453495026
# --------approximate solution path for # itr = 800 complete--------
# # epoch: 800	 sup error: 0.3386392295360566
# --------approximate solution path for # itr = 900 complete--------
# # epoch: 900	 sup error: 0.06784233450889593
# --------approximate solution path for # itr = 1000 complete--------
# # epoch: 1000	 sup error: 0.1571453213691712
# --------approximate solution path for # itr = 1100 complete--------
# # epoch: 1100	 sup error: 0.09049174189567571
# --------approximate solution path for # itr = 1200 complete--------
# # epoch: 1200	 sup error: 0.20525905489921575
# --------approximate solution path for # itr = 1300 complete--------
# # epoch: 1300	 sup error: 0.07429659366607672
# --------approximate solution path for # itr = 1400 complete--------
# # epoch: 1400	 sup error: 0.12256485223770147
# --------approximate solution path for # itr = 1500 complete--------
# # epoch: 1500	 sup error: 0.07603892683982855
# --------approximate solution path for # itr = 1600 complete--------
# # epoch: 1600	 sup error: 0.08581668138504034
# --------approximate solution path for # itr = 1700 complete--------
# # epoch: 1700	 sup error: 0.1261009573936463
# --------approximate solution path for # itr = 1800 complete--------
# # epoch: 1800	 sup error: 0.08532306551933294
# --------approximate solution path for # itr = 1900 complete--------
# # epoch: 1900	 sup error: 0.2276253998279572
# --------approximate solution path for # itr = 2000 complete--------
# # epoch: 2000	 sup error: 0.42376294732093817
# --------approximate solution path for # itr = 2100 complete--------
# # epoch: 2100	 sup error: 0.1601588129997254
# --------approximate solution path for # itr = 2200 complete--------
# # epoch: 2200	 sup error: 0.07328903675079351
# --------approximate solution path for # itr = 2300 complete--------
# # epoch: 2300	 sup error: 0.15065246820449835
# --------approximate solution path for # itr = 2400 complete--------
# # epoch: 2400	 sup error: 0.1792509257793427
# --------approximate solution path for # itr = 2500 complete--------
# # epoch: 2500	 sup error: 0.2433918416500092
# --------approximate solution path for # itr = 2600 complete--------
# # epoch: 2600	 sup error: 0.08483773469924932
# --------approximate solution path for # itr = 2700 complete--------
# # epoch: 2700	 sup error: 0.09195122122764593
# --------approximate solution path for # itr = 2800 complete--------
# # epoch: 2800	 sup error: 0.07615217566490179
# --------approximate solution path for # itr = 2900 complete--------
# # epoch: 2900	 sup error: 0.0724735856056214
# --------approximate solution path for # itr = 3000 complete--------
# # epoch: 3000	 sup error: 0.42868915200233465
# --------approximate solution path for # itr = 3100 complete--------
# # epoch: 3100	 sup error: 0.24757751822471624
# --------approximate solution path for # itr = 3200 complete--------
# # epoch: 3200	 sup error: 0.15658056735992437
# --------approximate solution path for # itr = 3300 complete--------
# # epoch: 3300	 sup error: 0.358176738023758
# --------approximate solution path for # itr = 3400 complete--------
# # epoch: 3400	 sup error: 0.07392206788063055
# --------approximate solution path for # itr = 3500 complete--------
# # epoch: 3500	 sup error: 0.08952763676643377
# --------approximate solution path for # itr = 3600 complete--------
# # epoch: 3600	 sup error: 0.19861033558845526
# --------approximate solution path for # itr = 3700 complete--------
# # epoch: 3700	 sup error: 0.21235218644142156
# --------approximate solution path for # itr = 3800 complete--------
# # epoch: 3800	 sup error: 0.0639768540859223
# --------approximate solution path for # itr = 3900 complete--------
# # epoch: 3900	 sup error: 0.3049955070018769
# --------approximate solution path for # itr = 4000 complete--------
# # epoch: 4000	 sup error: 0.16384673118591314
# --------approximate solution path for # itr = 4100 complete--------
# # epoch: 4100	 sup error: 0.3149994313716889
# --------approximate solution path for # itr = 4200 complete--------
# # epoch: 4200	 sup error: 0.08484211564064031
# --------approximate solution path for # itr = 4300 complete--------
# # epoch: 4300	 sup error: 0.1547232568264008
# --------approximate solution path for # itr = 4400 complete--------
# # epoch: 4400	 sup error: 0.13037741184234625
# --------approximate solution path for # itr = 4500 complete--------
# # epoch: 4500	 sup error: 0.08023905754089361
# --------approximate solution path for # itr = 4600 complete--------
# # epoch: 4600	 sup error: 0.058485269546508845
# --------approximate solution path for # itr = 4700 complete--------
# # epoch: 4700	 sup error: 0.19673034548759466
# --------approximate solution path for # itr = 4800 complete--------
# # epoch: 4800	 sup error: 0.19572255015373236
# --------approximate solution path for # itr = 4900 complete--------
# # epoch: 4900	 sup error: 0.25778558850288397
# --------approximate solution path for # itr = 5000 complete--------
# # epoch: 5000	 sup error: 0.22395011782646185
# --------approximate solution path for # itr = 5100 complete--------
# # epoch: 5100	 sup error: 0.17783716320991522
# --------approximate solution path for # itr = 5200 complete--------
# # epoch: 5200	 sup error: 0.3420200645923615
# --------approximate solution path for # itr = 5300 complete--------
# # epoch: 5300	 sup error: 0.1381960809230805
# --------approximate solution path for # itr = 5400 complete--------
# # epoch: 5400	 sup error: 0.07810643315315252
# --------approximate solution path for # itr = 5500 complete--------
# # epoch: 5500	 sup error: 0.19204470515251165
# --------approximate solution path for # itr = 5600 complete--------
# # epoch: 5600	 sup error: 0.09209039807319647
# --------approximate solution path for # itr = 5700 complete--------
# # epoch: 5700	 sup error: 0.06049019098281866
# --------approximate solution path for # itr = 5800 complete--------
# # epoch: 5800	 sup error: 0.10543712973594671
# --------approximate solution path for # itr = 5900 complete--------
# # epoch: 5900	 sup error: 0.07425782084465032
# --------approximate solution path for # itr = 6000 complete--------
# # epoch: 6000	 sup error: 0.26628574728965765

# %%
file_path = 'LSP_results_exact_fixed_basis_laguerre_last_iterate_shrink_lr.csv'

LSP_results_exact_fixed_basis = pd.DataFrame(np.column_stack((num_itr_history, sup_err_history_last_itr)), columns=['num_itr', 'sup_err_5'])

# Save the DataFrame to a CSV file
LSP_results_exact_fixed_basis.to_csv(file_path, index=False)

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Display the DataFrame
df
# Out:
#      num_itr  sup_err_5
# 0       10.0   0.110583
# 1       20.0   0.147659
# 2       30.0   0.437088
# 3       40.0   0.419268
# 4       50.0   0.064437
# ..       ...        ...
# 595   5960.0   0.194845
# 596   5970.0   0.204207
# 597   5980.0   0.217541
# 598   5990.0   0.265227
# 599   6000.0   0.266286
#
# [600 rows x 2 columns]

# %% [markdown]
# ## num basis func = 7

# %%
basis_dim = 7
init_lr = 0.0625

# %%
np.random.seed(8675309)
torch.manual_seed(8675309)

num_itr_history, sup_err_history_last_itr, weight, lr, itr = learn_solution_path(input_dim, basis_dim, phi_lam, max_epochs,
                                                               GD_data_loader, test_data_loader, loss_fn,
                                                               lam_min, lam_max, true_losses, init_lr=init_lr,
                                                               diminish=True, q=1.5, thresh_basis=thresh_basis,
                                                               weighted_avg=False,
                                                               record_frequency=10, distribution='exponential',
                                                               device=device, trace_frequency=100)

sup_err_history_last_itr = np.array(sup_err_history_last_itr)
# Out:
# --------approximate solution path for # itr = 100 complete--------
# # epoch: 100	 sup error: 0.05680218338966375
# --------approximate solution path for # itr = 200 complete--------
# # epoch: 200	 sup error: 0.014192730188369806
# --------approximate solution path for # itr = 300 complete--------
# # epoch: 300	 sup error: 0.01246184110641485
# --------approximate solution path for # itr = 400 complete--------
# # epoch: 400	 sup error: 0.033269077539444025
# --------approximate solution path for # itr = 500 complete--------
# # epoch: 500	 sup error: 0.0693494081497193
# --------approximate solution path for # itr = 600 complete--------
# # epoch: 600	 sup error: 0.04959860444068914
# --------approximate solution path for # itr = 700 complete--------
# # epoch: 700	 sup error: 0.06317484378814703
# --------approximate solution path for # itr = 800 complete--------
# # epoch: 800	 sup error: 0.08454054594039923
# --------approximate solution path for # itr = 900 complete--------
# # epoch: 900	 sup error: 0.02232295274734497
# --------approximate solution path for # itr = 1000 complete--------
# # epoch: 1000	 sup error: 0.04339882731437689
# --------approximate solution path for # itr = 1100 complete--------
# # epoch: 1100	 sup error: 0.03433600068092352
# --------approximate solution path for # itr = 1200 complete--------
# # epoch: 1200	 sup error: 0.04054656624794012
# --------approximate solution path for # itr = 1300 complete--------
# # epoch: 1300	 sup error: 0.024407088756561335
# --------approximate solution path for # itr = 1400 complete--------
# # epoch: 1400	 sup error: 0.02704343199729925
# --------approximate solution path for # itr = 1500 complete--------
# # epoch: 1500	 sup error: 0.012727439403533991
# --------approximate solution path for # itr = 1600 complete--------
# # epoch: 1600	 sup error: 0.013931810855865534
# --------approximate solution path for # itr = 1700 complete--------
# # epoch: 1700	 sup error: 0.04452094435691839
# --------approximate solution path for # itr = 1800 complete--------
# # epoch: 1800	 sup error: 0.0308044850826264
# --------approximate solution path for # itr = 1900 complete--------
# # epoch: 1900	 sup error: 0.033466398715972956
# --------approximate solution path for # itr = 2000 complete--------
# # epoch: 2000	 sup error: 0.05111685395240789
# --------approximate solution path for # itr = 2100 complete--------
# # epoch: 2100	 sup error: 0.041009157896041926
# --------approximate solution path for # itr = 2200 complete--------
# # epoch: 2200	 sup error: 0.017908036708831843
# --------approximate solution path for # itr = 2300 complete--------
# # epoch: 2300	 sup error: 0.032388061285018976
# --------approximate solution path for # itr = 2400 complete--------
# # epoch: 2400	 sup error: 0.03385689854621893
# --------approximate solution path for # itr = 2500 complete--------
# # epoch: 2500	 sup error: 0.04801973700523382
# --------approximate solution path for # itr = 2600 complete--------
# # epoch: 2600	 sup error: 0.02157637476921087
# --------approximate solution path for # itr = 2700 complete--------
# # epoch: 2700	 sup error: 0.0294505655765534
# --------approximate solution path for # itr = 2800 complete--------
# # epoch: 2800	 sup error: 0.016272991895675715
# --------approximate solution path for # itr = 2900 complete--------
# # epoch: 2900	 sup error: 0.029405921697616633
# --------approximate solution path for # itr = 3000 complete--------
# # epoch: 3000	 sup error: 0.05704542994499212
# --------approximate solution path for # itr = 3100 complete--------
# # epoch: 3100	 sup error: 0.05090141296386724
# --------approximate solution path for # itr = 3200 complete--------
# # epoch: 3200	 sup error: 0.03523778915405279
# --------approximate solution path for # itr = 3300 complete--------
# # epoch: 3300	 sup error: 0.05546838045120245
# --------approximate solution path for # itr = 3400 complete--------
# # epoch: 3400	 sup error: 0.012171894311904963
# --------approximate solution path for # itr = 3500 complete--------
# # epoch: 3500	 sup error: 0.008632361888885498
# --------approximate solution path for # itr = 3600 complete--------
# # epoch: 3600	 sup error: 0.030710011720657404
# --------approximate solution path for # itr = 3700 complete--------
# # epoch: 3700	 sup error: 0.03315442800521856
# --------approximate solution path for # itr = 3800 complete--------
# # epoch: 3800	 sup error: 0.019581407308578547
# --------approximate solution path for # itr = 3900 complete--------
# # epoch: 3900	 sup error: 0.04732716083526617
# --------approximate solution path for # itr = 4000 complete--------
# # epoch: 4000	 sup error: 0.045027524232864435
# --------approximate solution path for # itr = 4100 complete--------
# # epoch: 4100	 sup error: 0.06042465567588812
# --------approximate solution path for # itr = 4200 complete--------
# # epoch: 4200	 sup error: 0.03304597735404974
# --------approximate solution path for # itr = 4300 complete--------
# # epoch: 4300	 sup error: 0.04445877671241766
# --------approximate solution path for # itr = 4400 complete--------
# # epoch: 4400	 sup error: 0.03523132205009466
# --------approximate solution path for # itr = 4500 complete--------
# # epoch: 4500	 sup error: 0.010067880153656061
# --------approximate solution path for # itr = 4600 complete--------
# # epoch: 4600	 sup error: 0.017576843500137385
# --------approximate solution path for # itr = 4700 complete--------
# # epoch: 4700	 sup error: 0.04442319273948675
# --------approximate solution path for # itr = 4800 complete--------
# # epoch: 4800	 sup error: 0.04888001084327703
# --------approximate solution path for # itr = 4900 complete--------
# # epoch: 4900	 sup error: 0.05546990036964422
# --------approximate solution path for # itr = 5000 complete--------
# # epoch: 5000	 sup error: 0.04466724395751959
# --------approximate solution path for # itr = 5100 complete--------
# # epoch: 5100	 sup error: 0.034702509641647394
# --------approximate solution path for # itr = 5200 complete--------
# # epoch: 5200	 sup error: 0.054291278123855646
# --------approximate solution path for # itr = 5300 complete--------
# # epoch: 5300	 sup error: 0.05011066794395452
# --------approximate solution path for # itr = 5400 complete--------
# # epoch: 5400	 sup error: 0.010712355375289973
# --------approximate solution path for # itr = 5500 complete--------
# # epoch: 5500	 sup error: 0.029857456684112604
# --------approximate solution path for # itr = 5600 complete--------
# # epoch: 5600	 sup error: 0.019996941089630182
# --------approximate solution path for # itr = 5700 complete--------
# # epoch: 5700	 sup error: 0.00725394487380987
# --------approximate solution path for # itr = 5800 complete--------
# # epoch: 5800	 sup error: 0.0072344243526459295
# --------approximate solution path for # itr = 5900 complete--------
# # epoch: 5900	 sup error: 0.03516960144042974
# --------approximate solution path for # itr = 6000 complete--------
# # epoch: 6000	 sup error: 0.0485180020332337

# %%
file_path = 'LSP_results_exact_fixed_basis_laguerre_last_iterate_shrink_lr.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

df['sup_err_7'] = sup_err_history_last_itr

# Save the DataFrame to a CSV file
df.to_csv(file_path, index=False)

# %% [markdown]
# ## num basis func = 9

# %%
basis_dim = 9
init_lr = 0.0625

# %%
np.random.seed(8675309)
torch.manual_seed(8675309)

num_itr_history, sup_err_history_last_itr, weight, lr, itr = learn_solution_path(input_dim, basis_dim, phi_lam, max_epochs,
                                                               GD_data_loader, test_data_loader, loss_fn,
                                                               lam_min, lam_max, true_losses, init_lr=init_lr,
                                                               diminish=True, q=1.5, thresh_basis=thresh_basis,
                                                               weighted_avg=False,
                                                               record_frequency=10, distribution='exponential',
                                                               device=device, trace_frequency=1000)

sup_err_history_last_itr = np.array(sup_err_history_last_itr)
# Out:
# --------approximate solution path for # itr = 1000 complete--------
# # epoch: 1000	 sup error: 0.013005137443542536
# --------approximate solution path for # itr = 2000 complete--------
# # epoch: 2000	 sup error: 0.01155266165733343
# --------approximate solution path for # itr = 3000 complete--------
# # epoch: 3000	 sup error: 0.021070331335067805
# --------approximate solution path for # itr = 4000 complete--------
# # epoch: 4000	 sup error: 0.020676285028457697
# --------approximate solution path for # itr = 5000 complete--------
# # epoch: 5000	 sup error: 0.022442072629928644
# --------approximate solution path for # itr = 6000 complete--------
# # epoch: 6000	 sup error: 0.01965263485908514

# %%
np.random.seed(8675309)
torch.manual_seed(8675309)

num_itr_history, sup_err_history_last_itr, weight, lr, itr = learn_solution_path(input_dim, basis_dim, phi_lam, max_epochs,
                                                               GD_data_loader, test_data_loader, loss_fn,
                                                               lam_min, lam_max, true_losses, init_lr=init_lr,
                                                               diminish=True, q=1.5, thresh_basis=thresh_basis,
                                                               weighted_avg=False,
                                                               record_frequency=10, distribution='exponential',
                                                               device=device, trace_frequency=100)

sup_err_history_last_itr = np.array(sup_err_history_last_itr)
# Out:
# --------approximate solution path for # itr = 100 complete--------
# # epoch: 100	 sup error: 0.04896950721740728
# --------approximate solution path for # itr = 200 complete--------
# # epoch: 200	 sup error: 0.007388442754745539
# --------approximate solution path for # itr = 300 complete--------
# # epoch: 300	 sup error: 0.012091338634490967
# --------approximate solution path for # itr = 400 complete--------
# # epoch: 400	 sup error: 0.01395034790039068
# --------approximate solution path for # itr = 500 complete--------
# # epoch: 500	 sup error: 0.017959564924240168
# --------approximate solution path for # itr = 600 complete--------
# # epoch: 600	 sup error: 0.01897063851356512
# --------approximate solution path for # itr = 700 complete--------
# # epoch: 700	 sup error: 0.022045165300369318
# --------approximate solution path for # itr = 800 complete--------
# # epoch: 800	 sup error: 0.02689382433891302
# --------approximate solution path for # itr = 900 complete--------
# # epoch: 900	 sup error: 0.013307929039001465
# --------approximate solution path for # itr = 1000 complete--------
# # epoch: 1000	 sup error: 0.013005167245864924
# --------approximate solution path for # itr = 1100 complete--------
# # epoch: 1100	 sup error: 0.018545418977737482
# --------approximate solution path for # itr = 1200 complete--------
# # epoch: 1200	 sup error: 0.020268321037292536
# --------approximate solution path for # itr = 1300 complete--------
# # epoch: 1300	 sup error: 0.010414123535156306
# --------approximate solution path for # itr = 1400 complete--------
# # epoch: 1400	 sup error: 0.011514276266098078
# --------approximate solution path for # itr = 1500 complete--------
# # epoch: 1500	 sup error: 0.010190844535827692
# --------approximate solution path for # itr = 1600 complete--------
# # epoch: 1600	 sup error: 0.006464660167694092
# --------approximate solution path for # itr = 1700 complete--------
# # epoch: 1700	 sup error: 0.01880395412445074
# --------approximate solution path for # itr = 1800 complete--------
# # epoch: 1800	 sup error: 0.014359802007675226
# --------approximate solution path for # itr = 1900 complete--------
# # epoch: 1900	 sup error: 0.009898483753204401
# --------approximate solution path for # itr = 2000 complete--------
# # epoch: 2000	 sup error: 0.01155266165733343
# --------approximate solution path for # itr = 2100 complete--------
# # epoch: 2100	 sup error: 0.022756516933441218
# --------approximate solution path for # itr = 2200 complete--------
# # epoch: 2200	 sup error: 0.009781032800674494
# --------approximate solution path for # itr = 2300 complete--------
# # epoch: 2300	 sup error: 0.0216247439384461
# --------approximate solution path for # itr = 2400 complete--------
# # epoch: 2400	 sup error: 0.020773023366928156
# --------approximate solution path for # itr = 2500 complete--------
# # epoch: 2500	 sup error: 0.02261671423912054
# --------approximate solution path for # itr = 2600 complete--------
# # epoch: 2600	 sup error: 0.00795015692710882
# --------approximate solution path for # itr = 2700 complete--------
# # epoch: 2700	 sup error: 0.014286398887634333
# --------approximate solution path for # itr = 2800 complete--------
# # epoch: 2800	 sup error: 0.01333069801330572
# --------approximate solution path for # itr = 2900 complete--------
# # epoch: 2900	 sup error: 0.016338527202606257
# --------approximate solution path for # itr = 3000 complete--------
# # epoch: 3000	 sup error: 0.021070301532745417
# --------approximate solution path for # itr = 3100 complete--------
# # epoch: 3100	 sup error: 0.02600869536399847
# --------approximate solution path for # itr = 3200 complete--------
# # epoch: 3200	 sup error: 0.023227632045745905
# --------approximate solution path for # itr = 3300 complete--------
# # epoch: 3300	 sup error: 0.024797737598419245
# --------approximate solution path for # itr = 3400 complete--------
# # epoch: 3400	 sup error: 0.005125790834426935
# --------approximate solution path for # itr = 3500 complete--------
# # epoch: 3500	 sup error: 0.005698591470718439
# --------approximate solution path for # itr = 3600 complete--------
# # epoch: 3600	 sup error: 0.01359513401985174
# --------approximate solution path for # itr = 3700 complete--------
# # epoch: 3700	 sup error: 0.018542379140853937
# --------approximate solution path for # itr = 3800 complete--------
# # epoch: 3800	 sup error: 0.015670895576477106
# --------approximate solution path for # itr = 3900 complete--------
# # epoch: 3900	 sup error: 0.021712630987167414
# --------approximate solution path for # itr = 4000 complete--------
# # epoch: 4000	 sup error: 0.02067625522613531
# --------approximate solution path for # itr = 4100 complete--------
# # epoch: 4100	 sup error: 0.02211394906044012
# --------approximate solution path for # itr = 4200 complete--------
# # epoch: 4200	 sup error: 0.017914235591888483
# --------approximate solution path for # itr = 4300 complete--------
# # epoch: 4300	 sup error: 0.023777484893798884
# --------approximate solution path for # itr = 4400 complete--------
# # epoch: 4400	 sup error: 0.02082455158233648
# --------approximate solution path for # itr = 4500 complete--------
# # epoch: 4500	 sup error: 0.008426785469055176
# --------approximate solution path for # itr = 4600 complete--------
# # epoch: 4600	 sup error: 0.007933497428894098
# --------approximate solution path for # itr = 4700 complete--------
# # epoch: 4700	 sup error: 0.018292546272277888
# --------approximate solution path for # itr = 4800 complete--------
# # epoch: 4800	 sup error: 0.020743846893310602
# --------approximate solution path for # itr = 4900 complete--------
# # epoch: 4900	 sup error: 0.02507039904594427
# --------approximate solution path for # itr = 5000 complete--------
# # epoch: 5000	 sup error: 0.022442072629928644
# --------approximate solution path for # itr = 5100 complete--------
# # epoch: 5100	 sup error: 0.015931904315948542
# --------approximate solution path for # itr = 5200 complete--------
# # epoch: 5200	 sup error: 0.01990967988967901
# --------approximate solution path for # itr = 5300 complete--------
# # epoch: 5300	 sup error: 0.02173051238060003
# --------approximate solution path for # itr = 5400 complete--------
# # epoch: 5400	 sup error: 0.004014343023300171
# --------approximate solution path for # itr = 5500 complete--------
# # epoch: 5500	 sup error: 0.00833770632743841
# --------approximate solution path for # itr = 5600 complete--------
# # epoch: 5600	 sup error: 0.006743907928466852
# --------approximate solution path for # itr = 5700 complete--------
# # epoch: 5700	 sup error: 0.005326390266418457
# --------approximate solution path for # itr = 5800 complete--------
# # epoch: 5800	 sup error: 0.004943132400512695
# --------approximate solution path for # itr = 5900 complete--------
# # epoch: 5900	 sup error: 0.019845873117446955
# --------approximate solution path for # itr = 6000 complete--------
# # epoch: 6000	 sup error: 0.019652664661407526

# %%
file_path = 'LSP_results_exact_fixed_basis_laguerre_last_iterate_shrink_lr.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

df['sup_err_9'] = sup_err_history_last_itr

# Save the DataFrame to a CSV file
df.to_csv(file_path, index=False)

# %% [markdown]
# # 04 Error Across $\Lambda$

# %%
model = Basis_TF_SGD(input_dim, 9, phi_lam, init_weight=weight, intercept=True).to(device)

# %%
errs = get_errs_lsp(lam_min[0], lam_max[0], true_losses, model, test_data_loader, loss_fn)

# %%
lambdas = np.linspace(lam_max[0], lam_min[0], len(true_losses))

# %%
pd.DataFrame(np.column_stack((errs, lambdas)), columns=['errs', 'lambdas']).to_csv('LSP_errs_laguerre_basis_9.csv', index=False)
