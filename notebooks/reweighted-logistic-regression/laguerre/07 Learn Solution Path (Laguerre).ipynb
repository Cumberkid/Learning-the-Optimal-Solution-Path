# %% [markdown]
# # 01 Import libraries

# %%
import numpy as np
import torch

device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
import pandas as pd

# %%
import importlib

# %% [markdown]
# ## Import our own modules

# %%
import lib
importlib.reload(lib)
# Out:
# <module 'lib' from '/content/Learning-the-Optimal-Solution-Path/lib/__init__.py'>

# %%
from lib.lsp.basis_generator import dampen_laguerre
from lib.lsp.basis_tf_module import Basis_TF_SGD
from lib.lsp.learn_solution_path import learn_solution_path
from lib.lsp.loss_fn_lsp import reg_exp_weighted_logit
from lib.fast_tensor_data_loader import FastTensorDataLoader

# %% [markdown]
# # 02 Instantiate dataset

# %%
# file path for Colab. May need to change this
X_df = pd.read_csv('X_processed.csv')
y_df = pd.read_csv('y_processed.csv')

# %%
X = np.array(X_df)
y = np.array(y_df).squeeze()

# %%
train_X = torch.tensor(X, dtype=torch.float32)
train_y = torch.tensor(y, dtype=torch.float32)

# %%
# full gradient descent uses all data points
GD_data_loader = FastTensorDataLoader(train_X, train_y, batch_size=1000, shuffle=True, )
# stochastic gradient descent uses mini-batch
SGD_data_loader = FastTensorDataLoader(train_X, train_y, batch_size=20, shuffle=True, )
# test data
test_data_loader = FastTensorDataLoader(train_X, train_y, batch_size=1000, shuffle=False, )

# %%
lam_max = 20
lam_min = 0
input_dim = X.shape[1]
loss_fn = reg_exp_weighted_logit

# %%
# Read the CSV file into a DataFrame
# truth = pd.read_csv('/content/Learning-the-Optimal-Solution-Path/experiments/fair-regression/results/exact_soln_list.csv')
truth = pd.read_csv('exact_soln_list_laguerre.csv')

# Display the DataFrame
truth
# Out:
#         losses   theta_0   theta_1   theta_2   theta_3   theta_4   theta_5  \
# 0     0.251592 -0.290164  0.186074  0.232884 -0.027476  0.166136  0.110354
# 1     0.251645 -0.290092  0.186073  0.232887 -0.027478  0.166136  0.110326
# 2     0.251698 -0.290020  0.186071  0.232891 -0.027481  0.166136  0.110298
# 3     0.251751 -0.289947  0.186070  0.232895 -0.027484  0.166136  0.110270
# 4     0.251804 -0.289874  0.186068  0.232898 -0.027487  0.166136  0.110242
# ...        ...       ...       ...       ...       ...       ...       ...
# 1019  0.425709  0.608973  0.015982  0.030750 -0.012680  0.033522 -0.189898
# 1020  0.405809  0.627298  0.006731  0.017247 -0.013635  0.025534 -0.197376
# 1021  0.382318  0.647696 -0.004087  0.001661 -0.014793  0.016128 -0.205935
# 1022  0.354260  0.670989 -0.016946 -0.016535 -0.016181  0.004871 -0.216011
# 1023  0.320320  0.698369 -0.032464 -0.037983 -0.017807 -0.008802 -0.228186
#
#        theta_6   theta_7   theta_8  ...  theta_36  theta_37  theta_38  \
# 0     0.142358  0.009975  0.157656  ...  0.000471  0.023097 -0.007038
# 1     0.142336  0.009961  0.157669  ...  0.000487  0.023069 -0.007039
# 2     0.142315  0.009946  0.157682  ...  0.000503  0.023042 -0.007041
# 3     0.142294  0.009931  0.157695  ...  0.000519  0.023015 -0.007042
# 4     0.142272  0.009916  0.157708  ...  0.000534  0.022988 -0.007043
# ...        ...       ...       ...  ...       ...       ...       ...
# 1019 -0.060873 -0.075246  0.138251  ...  0.104496 -0.190631 -0.003899
# 1020 -0.075369 -0.070611  0.125166  ...  0.104706 -0.193085 -0.002800
# 1021 -0.094402 -0.064959  0.109066  ...  0.104903 -0.195830 -0.001589
# 1022 -0.119855 -0.058109  0.089182  ...  0.105111 -0.199002 -0.000252
# 1023 -0.154196 -0.049927  0.064680  ...  0.105391 -0.202811  0.001220
#
#       theta_39  theta_40  theta_41  theta_42  theta_43  theta_44  theta_45
# 0     0.003151  0.004510 -0.024440  0.000471 -0.129229 -0.096597 -0.041242
# 1     0.003154  0.004514 -0.024434  0.000487 -0.129220 -0.096579 -0.041224
# 2     0.003157  0.004518 -0.024429  0.000503 -0.129210 -0.096561 -0.041206
# 3     0.003160  0.004522 -0.024423  0.000519 -0.129201 -0.096543 -0.041188
# 4     0.003162  0.004526 -0.024417  0.000534 -0.129191 -0.096525 -0.041170
# ...        ...       ...       ...       ...       ...       ...       ...
# 1019  0.016846  0.022910  0.049139  0.104496  0.117941  0.139251  0.161150
# 1020  0.016029  0.021890  0.052167  0.104706  0.126507  0.144123  0.163584
# 1021  0.015089  0.020769  0.055620  0.104903  0.136154  0.149574  0.166138
# 1022  0.014026  0.019573  0.059569  0.105111  0.147241  0.155866  0.168880
# 1023  0.012859  0.018354  0.064084  0.105391  0.160226  0.163374  0.171958
#
# [1024 rows x 47 columns]

# %%
selected_columns = ['theta_0', 'theta_1', 'theta_2', 'theta_3', 'theta_4',
                    'theta_5', 'theta_6', 'theta_7', 'theta_8', 'theta_9',
                    'theta_10', 'theta_11', 'theta_12', 'theta_13', 'theta_14',
                    'theta_15', 'theta_16', 'theta_17', 'theta_18', 'theta_19',
                    'theta_20', 'theta_21', 'theta_22', 'theta_23', 'theta_24',
                    'theta_25', 'theta_26', 'theta_27', 'theta_28', 'theta_29',
                    'theta_30', 'theta_31', 'theta_32', 'theta_33', 'theta_34',
                    'theta_35', 'theta_36', 'theta_37', 'theta_38', 'theta_39',
                    'theta_40', 'theta_41', 'theta_42', 'theta_43', 'theta_44',
                    'theta_45']
true_thetas = truth[selected_columns].to_numpy()
true_losses = truth['losses'].to_numpy()

# %% [markdown]
# # 03 SGD with Diminishing LR by Distance Diagnostic

# %% [markdown]
# Recall that our method runs SGD over random $\tilde λ$'s with a linear basis $\Phi(\tilde \lambda)$ of our choice. We want to approximate $\theta$ with $\Phi(\lambda)\beta$, so the objective function is $\min_\beta h(\Phi(\tilde\lambda)\beta, \tilde\lambda) = (1-\tilde\lambda) BCE(X_\text{pass}\Phi(\tilde\lambda)\beta,\ y_\text{pass}) + \tilde\lambda BCE(X_\text{fail}\Phi(\tilde\lambda)\beta,\ y_\text{fail})$. For each batch of training data set, we randomize $\tilde\lambda$.

# %% [markdown]
# We use diminishing learning rate for better demonstrate convergence. If we use a constant learning rate, the solution path error will eventually do a random walk after descending to a certain threshold value.
#
# Set weighted_avg to 'False' see this random walk.

# %%
max_epochs = 6000

# %%
phi_lam = dampen_laguerre

# %%
def thresh_basis(basis_dim):
    return -1

# %% [markdown]
# ## num basis func = 5

# %%
basis_dim = 5
init_lr = 0.0625

# %%
np.random.seed(8675309)
torch.manual_seed(8675309)

num_itr_history, sup_err_history, weight, lr, itr = learn_solution_path(input_dim, basis_dim, phi_lam, max_epochs,
                                                               GD_data_loader, test_data_loader, loss_fn,
                                                               lam_min, lam_max, true_losses, init_lr=init_lr,
                                                               diminish=True, q=1.5, thresh_basis=thresh_basis,
                                                               record_frequency=10, distribution='exponential',
                                                               device=device, trace_frequency=100)
sup_err_history = np.array(sup_err_history)
# Out:
# --------approximate solution path for # itr = 100 complete--------
# # epoch: 100	 sup error: 0.06728923320770264
# --------approximate solution path for # itr = 200 complete--------
# # epoch: 200	 sup error: 0.061814248561859186
# --------approximate solution path for # itr = 300 complete--------
# # epoch: 300	 sup error: 0.06067377328872686
# --------approximate solution path for # itr = 400 complete--------
# # epoch: 400	 sup error: 0.10549074411392217
# --------approximate solution path for # itr = 500 complete--------
# # epoch: 500	 sup error: 0.08142107725143438
# --------approximate solution path for # itr = 600 complete--------
# # epoch: 600	 sup error: 0.09814649820327764
# --------approximate solution path for # itr = 700 complete--------
# # epoch: 700	 sup error: 0.10419979691505438
# --------approximate solution path for # itr = 800 complete--------
# # epoch: 800	 sup error: 0.10402005910873419
# --------approximate solution path for # itr = 900 complete--------
# # epoch: 900	 sup error: 0.09586665034294134
# --------approximate solution path for # itr = 1000 complete--------
# # epoch: 1000	 sup error: 0.091049075126648
# --------approximate solution path for # itr = 1100 complete--------
# # epoch: 1100	 sup error: 0.08233067393302923
# --------approximate solution path for # itr = 1200 complete--------
# # epoch: 1200	 sup error: 0.07365909218788153
# --------approximate solution path for # itr = 1300 complete--------
# # epoch: 1300	 sup error: 0.07530182600021368
# --------approximate solution path for # itr = 1400 complete--------
# # epoch: 1400	 sup error: 0.07351467013359075
# --------approximate solution path for # itr = 1500 complete--------
# # epoch: 1500	 sup error: 0.07511135935783392
# --------approximate solution path for # itr = 1600 complete--------
# # epoch: 1600	 sup error: 0.07176128029823309
# --------approximate solution path for # itr = 1700 complete--------
# # epoch: 1700	 sup error: 0.07783490419387823
# --------approximate solution path for # itr = 1800 complete--------
# # epoch: 1800	 sup error: 0.07866230607032781
# --------approximate solution path for # itr = 1900 complete--------
# # epoch: 1900	 sup error: 0.0741203129291535
# --------approximate solution path for # itr = 2000 complete--------
# # epoch: 2000	 sup error: 0.07564613223075872
# --------approximate solution path for # itr = 2100 complete--------
# # epoch: 2100	 sup error: 0.07583612203598028
# --------approximate solution path for # itr = 2200 complete--------
# # epoch: 2200	 sup error: 0.07675793766975408
# --------approximate solution path for # itr = 2300 complete--------
# # epoch: 2300	 sup error: 0.08400520682334905
# --------approximate solution path for # itr = 2400 complete--------
# # epoch: 2400	 sup error: 0.0858732163906098
# --------approximate solution path for # itr = 2500 complete--------
# # epoch: 2500	 sup error: 0.08503654599189764
# --------approximate solution path for # itr = 2600 complete--------
# # epoch: 2600	 sup error: 0.08273512125015264
# --------approximate solution path for # itr = 2700 complete--------
# # epoch: 2700	 sup error: 0.08527591824531561
# --------approximate solution path for # itr = 2800 complete--------
# # epoch: 2800	 sup error: 0.08537819981575018
# --------approximate solution path for # itr = 2900 complete--------
# # epoch: 2900	 sup error: 0.08800911903381353
# --------approximate solution path for # itr = 3000 complete--------
# # epoch: 3000	 sup error: 0.08705487847328192
# --------approximate solution path for # itr = 3100 complete--------
# # epoch: 3100	 sup error: 0.08817160129547125
# --------approximate solution path for # itr = 3200 complete--------
# # epoch: 3200	 sup error: 0.08483588695526129
# --------approximate solution path for # itr = 3300 complete--------
# # epoch: 3300	 sup error: 0.08424356579780584
# --------approximate solution path for # itr = 3400 complete--------
# # epoch: 3400	 sup error: 0.07969737052917486
# --------approximate solution path for # itr = 3500 complete--------
# # epoch: 3500	 sup error: 0.07531037926673895
# --------approximate solution path for # itr = 3600 complete--------
# # epoch: 3600	 sup error: 0.07405328750610357
# --------approximate solution path for # itr = 3700 complete--------
# # epoch: 3700	 sup error: 0.08090299367904669
# --------approximate solution path for # itr = 3800 complete--------
# # epoch: 3800	 sup error: 0.08269402384758001
# --------approximate solution path for # itr = 3900 complete--------
# # epoch: 3900	 sup error: 0.08359336853027349
# --------approximate solution path for # itr = 4000 complete--------
# # epoch: 4000	 sup error: 0.08069112896919256
# --------approximate solution path for # itr = 4100 complete--------
# # epoch: 4100	 sup error: 0.0794049501419068
# --------approximate solution path for # itr = 4200 complete--------
# # epoch: 4200	 sup error: 0.07688960433006292
# --------approximate solution path for # itr = 4300 complete--------
# # epoch: 4300	 sup error: 0.07589334249496466
# --------approximate solution path for # itr = 4400 complete--------
# # epoch: 4400	 sup error: 0.07595297694206243
# --------approximate solution path for # itr = 4500 complete--------
# # epoch: 4500	 sup error: 0.07818284630775457
# --------approximate solution path for # itr = 4600 complete--------
# # epoch: 4600	 sup error: 0.08063590526580816
# --------approximate solution path for # itr = 4700 complete--------
# # epoch: 4700	 sup error: 0.08069577813148504
# --------approximate solution path for # itr = 4800 complete--------
# # epoch: 4800	 sup error: 0.08501800894737249
# --------approximate solution path for # itr = 4900 complete--------
# # epoch: 4900	 sup error: 0.08727672696113592
# --------approximate solution path for # itr = 5000 complete--------
# # epoch: 5000	 sup error: 0.09047582745552069
# --------approximate solution path for # itr = 5100 complete--------
# # epoch: 5100	 sup error: 0.09249541163444525
# --------approximate solution path for # itr = 5200 complete--------
# # epoch: 5200	 sup error: 0.09698775410652166
# --------approximate solution path for # itr = 5300 complete--------
# # epoch: 5300	 sup error: 0.09648466110229498
# --------approximate solution path for # itr = 5400 complete--------
# # epoch: 5400	 sup error: 0.09433373808860784
# --------approximate solution path for # itr = 5500 complete--------
# # epoch: 5500	 sup error: 0.0926648378372193
# --------approximate solution path for # itr = 5600 complete--------
# # epoch: 5600	 sup error: 0.09253352880477911
# --------approximate solution path for # itr = 5700 complete--------
# # epoch: 5700	 sup error: 0.09483200311660772
# --------approximate solution path for # itr = 5800 complete--------
# # epoch: 5800	 sup error: 0.09496602416038519
# --------approximate solution path for # itr = 5900 complete--------
# # epoch: 5900	 sup error: 0.09349787235260015
# --------approximate solution path for # itr = 6000 complete--------
# # epoch: 6000	 sup error: 0.09260982275009161

# %%
file_path = 'LSP_results_exact_fixed_basis.csv'

LSP_results_exact_fixed_basis = pd.DataFrame(np.column_stack((num_itr_history, sup_err_history)), columns=['num_itr', 'sup_err_5'])

# Save the DataFrame to a CSV file
LSP_results_exact_fixed_basis.to_csv(file_path, index=False)

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Display the DataFrame
df
# Out:
#      num_itr  sup_err_5
# 0       10.0   0.170329
# 1       20.0   0.126928
# 2       30.0   0.172975
# 3       40.0   0.283612
# 4       50.0   0.284675
# ..       ...        ...
# 595   5960.0   0.093463
# 596   5970.0   0.093419
# 597   5980.0   0.093537
# 598   5990.0   0.093370
# 599   6000.0   0.093062
#
# [600 rows x 2 columns]

# %% [markdown]
# ## num basis func = 7

# %%
basis_dim = 7
init_lr = 0.0625

# %%
np.random.seed(8675309)
torch.manual_seed(8675309)

num_itr_history, sup_err_history, weight, lr, itr = learn_solution_path(input_dim, basis_dim, phi_lam, max_epochs,
                                                               GD_data_loader, test_data_loader, loss_fn,
                                                               lam_min, lam_max, true_losses, init_lr=init_lr,
                                                               diminish=True, q=1.5, thresh_basis=thresh_basis,
                                                               record_frequency=10, distribution='exponential',
                                                               device=device, trace_frequency=100)
sup_err_history = np.array(sup_err_history)
# Out:
# --------approximate solution path for # itr = 100 complete--------
# # epoch: 100	 sup error: 0.08830827474594116
# --------approximate solution path for # itr = 200 complete--------
# # epoch: 200	 sup error: 0.051316797733306885
# --------approximate solution path for # itr = 300 complete--------
# # epoch: 300	 sup error: 0.03262564539909368
# --------approximate solution path for # itr = 400 complete--------
# # epoch: 400	 sup error: 0.03091061115264898
# --------approximate solution path for # itr = 500 complete--------
# # epoch: 500	 sup error: 0.027068316936492975
# --------approximate solution path for # itr = 600 complete--------
# # epoch: 600	 sup error: 0.026059836149215754
# --------approximate solution path for # itr = 700 complete--------
# # epoch: 700	 sup error: 0.024442106485366877
# --------approximate solution path for # itr = 800 complete--------
# # epoch: 800	 sup error: 0.01707234978675848
# --------approximate solution path for # itr = 900 complete--------
# # epoch: 900	 sup error: 0.013546437025070246
# --------approximate solution path for # itr = 1000 complete--------
# # epoch: 1000	 sup error: 0.011492282152175959
# --------approximate solution path for # itr = 1100 complete--------
# # epoch: 1100	 sup error: 0.012241929769516047
# --------approximate solution path for # itr = 1200 complete--------
# # epoch: 1200	 sup error: 0.0116663277149201
# --------approximate solution path for # itr = 1300 complete--------
# # epoch: 1300	 sup error: 0.012817680835723932
# --------approximate solution path for # itr = 1400 complete--------
# # epoch: 1400	 sup error: 0.013459175825119074
# --------approximate solution path for # itr = 1500 complete--------
# # epoch: 1500	 sup error: 0.01483330130577093
# --------approximate solution path for # itr = 1600 complete--------
# # epoch: 1600	 sup error: 0.016427993774414118
# --------approximate solution path for # itr = 1700 complete--------
# # epoch: 1700	 sup error: 0.017050832509994562
# --------approximate solution path for # itr = 1800 complete--------
# # epoch: 1800	 sup error: 0.018731176853179987
# --------approximate solution path for # itr = 1900 complete--------
# # epoch: 1900	 sup error: 0.020498931407928522
# --------approximate solution path for # itr = 2000 complete--------
# # epoch: 2000	 sup error: 0.021607369184494074
# --------approximate solution path for # itr = 2100 complete--------
# # epoch: 2100	 sup error: 0.022836208343505915
# --------approximate solution path for # itr = 2200 complete--------
# # epoch: 2200	 sup error: 0.022536456584930475
# --------approximate solution path for # itr = 2300 complete--------
# # epoch: 2300	 sup error: 0.023233860731124933
# --------approximate solution path for # itr = 2400 complete--------
# # epoch: 2400	 sup error: 0.024533420801162775
# --------approximate solution path for # itr = 2500 complete--------
# # epoch: 2500	 sup error: 0.02398765087127691
# --------approximate solution path for # itr = 2600 complete--------
# # epoch: 2600	 sup error: 0.02413949370384222
# --------approximate solution path for # itr = 2700 complete--------
# # epoch: 2700	 sup error: 0.02466267347335821
# --------approximate solution path for # itr = 2800 complete--------
# # epoch: 2800	 sup error: 0.02388343214988714
# --------approximate solution path for # itr = 2900 complete--------
# # epoch: 2900	 sup error: 0.022751897573471125
# --------approximate solution path for # itr = 3000 complete--------
# # epoch: 3000	 sup error: 0.023867219686508234
# --------approximate solution path for # itr = 3100 complete--------
# # epoch: 3100	 sup error: 0.025568604469299372
# --------approximate solution path for # itr = 3200 complete--------
# # epoch: 3200	 sup error: 0.026659905910492
# --------approximate solution path for # itr = 3300 complete--------
# # epoch: 3300	 sup error: 0.026559114456176813
# --------approximate solution path for # itr = 3400 complete--------
# # epoch: 3400	 sup error: 0.026599675416946467
# --------approximate solution path for # itr = 3500 complete--------
# # epoch: 3500	 sup error: 0.026506572961807306
# --------approximate solution path for # itr = 3600 complete--------
# # epoch: 3600	 sup error: 0.02608343958854681
# --------approximate solution path for # itr = 3700 complete--------
# # epoch: 3700	 sup error: 0.024680674076080378
# --------approximate solution path for # itr = 3800 complete--------
# # epoch: 3800	 sup error: 0.025621861219406183
# --------approximate solution path for # itr = 3900 complete--------
# # epoch: 3900	 sup error: 0.02704706788063055
# --------approximate solution path for # itr = 4000 complete--------
# # epoch: 4000	 sup error: 0.02637645602226263
# --------approximate solution path for # itr = 4100 complete--------
# # epoch: 4100	 sup error: 0.026159554719924982
# --------approximate solution path for # itr = 4200 complete--------
# # epoch: 4200	 sup error: 0.0249603688716889
# --------approximate solution path for # itr = 4300 complete--------
# # epoch: 4300	 sup error: 0.02418473362922674
# --------approximate solution path for # itr = 4400 complete--------
# # epoch: 4400	 sup error: 0.02398583292961126
# --------approximate solution path for # itr = 4500 complete--------
# # epoch: 4500	 sup error: 0.02415290474891668
# --------approximate solution path for # itr = 4600 complete--------
# # epoch: 4600	 sup error: 0.02405449748039251
# --------approximate solution path for # itr = 4700 complete--------
# # epoch: 4700	 sup error: 0.02323818206787115
# --------approximate solution path for # itr = 4800 complete--------
# # epoch: 4800	 sup error: 0.02269712090492254
# --------approximate solution path for # itr = 4900 complete--------
# # epoch: 4900	 sup error: 0.023089170455932673
# --------approximate solution path for # itr = 5000 complete--------
# # epoch: 5000	 sup error: 0.02255785465240484
# --------approximate solution path for # itr = 5100 complete--------
# # epoch: 5100	 sup error: 0.021574229001998957
# --------approximate solution path for # itr = 5200 complete--------
# # epoch: 5200	 sup error: 0.02100029587745672
# --------approximate solution path for # itr = 5300 complete--------
# # epoch: 5300	 sup error: 0.02072718739509588
# --------approximate solution path for # itr = 5400 complete--------
# # epoch: 5400	 sup error: 0.020232230424881037
# --------approximate solution path for # itr = 5500 complete--------
# # epoch: 5500	 sup error: 0.02025637030601507
# --------approximate solution path for # itr = 5600 complete--------
# # epoch: 5600	 sup error: 0.020778983831405695
# --------approximate solution path for # itr = 5700 complete--------
# # epoch: 5700	 sup error: 0.02120760083198553
# --------approximate solution path for # itr = 5800 complete--------
# # epoch: 5800	 sup error: 0.020935744047164973
# --------approximate solution path for # itr = 5900 complete--------
# # epoch: 5900	 sup error: 0.021048247814178522
# --------approximate solution path for # itr = 6000 complete--------
# # epoch: 6000	 sup error: 0.020962744951248224

# %%
file_path = 'LSP_results_exact_fixed_basis.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

df['sup_err_7'] = sup_err_history

# Save the DataFrame to a CSV file
df.to_csv(file_path, index=False)

# %% [markdown]
# ## num basis func = 9

# %%
basis_dim = 9
init_lr = 0.0625

# %%
np.random.seed(8675309)
torch.manual_seed(8675309)

num_itr_history, sup_err_history, weight, lr, itr = learn_solution_path(input_dim, basis_dim, phi_lam, max_epochs,
                                                               GD_data_loader, test_data_loader, loss_fn,
                                                               lam_min, lam_max, true_losses, init_lr=init_lr,
                                                               diminish=True, q=1.5, thresh_basis=thresh_basis,
                                                               record_frequency=10, distribution='exponential',
                                                               device=device, trace_frequency=100)
sup_err_history = np.array(sup_err_history)
# Out:
# --------approximate solution path for # itr = 100 complete--------
# # epoch: 100	 sup error: 0.042099952697753906
# --------approximate solution path for # itr = 200 complete--------
# # epoch: 200	 sup error: 0.02271133661270147
# --------approximate solution path for # itr = 300 complete--------
# # epoch: 300	 sup error: 0.04453656077384954
# --------approximate solution path for # itr = 400 complete--------
# # epoch: 400	 sup error: 0.02499511837959295
# --------approximate solution path for # itr = 500 complete--------
# # epoch: 500	 sup error: 0.015968173742294367
# --------approximate solution path for # itr = 600 complete--------
# # epoch: 600	 sup error: 0.011430442333221491
# --------approximate solution path for # itr = 700 complete--------
# # epoch: 700	 sup error: 0.009686499834060724
# --------approximate solution path for # itr = 800 complete--------
# # epoch: 800	 sup error: 0.012021511793136652
# --------approximate solution path for # itr = 900 complete--------
# # epoch: 900	 sup error: 0.009850949048996027
# --------approximate solution path for # itr = 1000 complete--------
# # epoch: 1000	 sup error: 0.008451968431472834
# --------approximate solution path for # itr = 1100 complete--------
# # epoch: 1100	 sup error: 0.008692860603332575
# --------approximate solution path for # itr = 1200 complete--------
# # epoch: 1200	 sup error: 0.009241610765457209
# --------approximate solution path for # itr = 1300 complete--------
# # epoch: 1300	 sup error: 0.01010707020759588
# --------approximate solution path for # itr = 1400 complete--------
# # epoch: 1400	 sup error: 0.010794281959533747
# --------approximate solution path for # itr = 1500 complete--------
# # epoch: 1500	 sup error: 0.011349260807037409
# --------approximate solution path for # itr = 1600 complete--------
# # epoch: 1600	 sup error: 0.010958403348922785
# --------approximate solution path for # itr = 1700 complete--------
# # epoch: 1700	 sup error: 0.011660993099212702
# --------approximate solution path for # itr = 1800 complete--------
# # epoch: 1800	 sup error: 0.011988848447799738
# --------approximate solution path for # itr = 1900 complete--------
# # epoch: 1900	 sup error: 0.01032018661499029
# --------approximate solution path for # itr = 2000 complete--------
# # epoch: 2000	 sup error: 0.009626895189285334
# --------approximate solution path for # itr = 2100 complete--------
# # epoch: 2100	 sup error: 0.010271757841110285
# --------approximate solution path for # itr = 2200 complete--------
# # epoch: 2200	 sup error: 0.009321868419647272
# --------approximate solution path for # itr = 2300 complete--------
# # epoch: 2300	 sup error: 0.009710162878036555
# --------approximate solution path for # itr = 2400 complete--------
# # epoch: 2400	 sup error: 0.00998669862747198
# --------approximate solution path for # itr = 2500 complete--------
# # epoch: 2500	 sup error: 0.01000672578811651
# --------approximate solution path for # itr = 2600 complete--------
# # epoch: 2600	 sup error: 0.010120481252670344
# --------approximate solution path for # itr = 2700 complete--------
# # epoch: 2700	 sup error: 0.010496526956558283
# --------approximate solution path for # itr = 2800 complete--------
# # epoch: 2800	 sup error: 0.009783506393432673
# --------approximate solution path for # itr = 2900 complete--------
# # epoch: 2900	 sup error: 0.009126365184783991
# --------approximate solution path for # itr = 3000 complete--------
# # epoch: 3000	 sup error: 0.00916633009910589
# --------approximate solution path for # itr = 3100 complete--------
# # epoch: 3100	 sup error: 0.007712513208389338
# --------approximate solution path for # itr = 3200 complete--------
# # epoch: 3200	 sup error: 0.007645666599273737
# --------approximate solution path for # itr = 3300 complete--------
# # epoch: 3300	 sup error: 0.007838636636734064
# --------approximate solution path for # itr = 3400 complete--------
# # epoch: 3400	 sup error: 0.00832632184028631
# --------approximate solution path for # itr = 3500 complete--------
# # epoch: 3500	 sup error: 0.00886103510856634
# --------approximate solution path for # itr = 3600 complete--------
# # epoch: 3600	 sup error: 0.009240895509719904
# --------approximate solution path for # itr = 3700 complete--------
# # epoch: 3700	 sup error: 0.00902822613716131
# --------approximate solution path for # itr = 3800 complete--------
# # epoch: 3800	 sup error: 0.008909285068512018
# --------approximate solution path for # itr = 3900 complete--------
# # epoch: 3900	 sup error: 0.00932255387306219
# --------approximate solution path for # itr = 4000 complete--------
# # epoch: 4000	 sup error: 0.009724766016006525
# --------approximate solution path for # itr = 4100 complete--------
# # epoch: 4100	 sup error: 0.009400665760040339
# --------approximate solution path for # itr = 4200 complete--------
# # epoch: 4200	 sup error: 0.009607762098312433
# --------approximate solution path for # itr = 4300 complete--------
# # epoch: 4300	 sup error: 0.009693771600723322
# --------approximate solution path for # itr = 4400 complete--------
# # epoch: 4400	 sup error: 0.009722262620925959
# --------approximate solution path for # itr = 4500 complete--------
# # epoch: 4500	 sup error: 0.008599638938903864
# --------approximate solution path for # itr = 4600 complete--------
# # epoch: 4600	 sup error: 0.008350312709808405
# --------approximate solution path for # itr = 4700 complete--------
# # epoch: 4700	 sup error: 0.008004456758499201
# --------approximate solution path for # itr = 4800 complete--------
# # epoch: 4800	 sup error: 0.008130908012390192
# --------approximate solution path for # itr = 4900 complete--------
# # epoch: 4900	 sup error: 0.007786422967910822
# --------approximate solution path for # itr = 5000 complete--------
# # epoch: 5000	 sup error: 0.00796994566917425
# --------approximate solution path for # itr = 5100 complete--------
# # epoch: 5100	 sup error: 0.008371114730835016
# --------approximate solution path for # itr = 5200 complete--------
# # epoch: 5200	 sup error: 0.008489102125167902
# --------approximate solution path for # itr = 5300 complete--------
# # epoch: 5300	 sup error: 0.00866886973381048
# --------approximate solution path for # itr = 5400 complete--------
# # epoch: 5400	 sup error: 0.008754402399063166
# --------approximate solution path for # itr = 5500 complete--------
# # epoch: 5500	 sup error: 0.00907853245735174
# --------approximate solution path for # itr = 5600 complete--------
# # epoch: 5600	 sup error: 0.009026736021041926
# --------approximate solution path for # itr = 5700 complete--------
# # epoch: 5700	 sup error: 0.008674591779708918
# --------approximate solution path for # itr = 5800 complete--------
# # epoch: 5800	 sup error: 0.00887164473533636
# --------approximate solution path for # itr = 5900 complete--------
# # epoch: 5900	 sup error: 0.009105801582336481
# --------approximate solution path for # itr = 6000 complete--------
# # epoch: 6000	 sup error: 0.008838444948196467

# %%
file_path = 'LSP_results_exact_fixed_basis.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

df['sup_err_9'] = sup_err_history

# Save the DataFrame to a CSV file
df.to_csv(file_path, index=False)
