# %% [markdown]
# # 01 Import libraries

# %%
import numpy as np
import torch

device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
import pandas as pd

# %%
import importlib

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import lib
importlib.reload(lib)
# Out:
# <module 'lib' from 'c:\\Users\\dongq\\OneDrive\\Desktop\\New results\\Learning-the-Optimal-Solution-Path\\lib\\__init__.py'>

# %%
from lib.lsp.basis_generator import bivariate_legendre, bivariate_chebyshev
from lib.lsp.learn_solution_path import adaptive_lsp, learn_solution_path
from lib.lsp.loss_fn_lsp import allocation_cost_no_con
from lib.lsp.utils_lsp import get_sup_error_lsp_2d
from lib.fast_tensor_data_loader import FastTensorDataLoader

# %% [markdown]
# # 02 Load data

# %%
# read file
decomp_cov_df = pd.read_csv('decomp_cov.csv')
mean_df = pd.read_csv('mean.csv')

# %%
decomp_cov = np.array(decomp_cov_df)
mean = np.array(mean_df).squeeze()

# %%
decomp_cov = torch.tensor(decomp_cov, dtype=torch.float32)
mean = torch.tensor(mean, dtype=torch.float32)

# %%
# full gradient descent uses all data points
GD_data_loader = FastTensorDataLoader(decomp_cov, mean, batch_size=len(decomp_cov), shuffle=False, )
# test data
test_data_loader = FastTensorDataLoader(decomp_cov, mean, batch_size=len(decomp_cov), shuffle=False, )

# %%
lam_max_2d = [1, 1]
lam_min_2d = [.2, 0]
input_dim = decomp_cov.shape[1]

# %%
# Read the CSV file into a DataFrame
# truth = pd.read_csv('/content/Learning-the-Optimal-Solution-Path/experiments/fair-regression/results/exact_soln_list.csv')
truth = pd.read_csv('exact_soln_list_cov_001_100_100_no_con.csv')

# Display the DataFrame
truth
# Out:
#            0         1         2         3         4         5         6  \
# 0  -0.013926 -0.013637 -0.013352 -0.013070 -0.012791 -0.012515 -0.012242
# 1  -0.014002 -0.013711 -0.013424 -0.013140 -0.012859 -0.012582 -0.012308
# 2  -0.014078 -0.013786 -0.013497 -0.013211 -0.012929 -0.012650 -0.012375
# 3  -0.014155 -0.013861 -0.013571 -0.013284 -0.013000 -0.012719 -0.012442
# 4  -0.014234 -0.013938 -0.013646 -0.013357 -0.013071 -0.012789 -0.012511
# ..       ...       ...       ...       ...       ...       ...       ...
# 95 -0.034586 -0.033755 -0.032940 -0.032141 -0.031358 -0.030589 -0.029835
# 96 -0.035320 -0.034465 -0.033626 -0.032804 -0.031998 -0.031208 -0.030434
# 97 -0.036098 -0.035216 -0.034352 -0.033505 -0.032676 -0.031863 -0.031066
# 98 -0.036925 -0.036015 -0.035123 -0.034249 -0.033394 -0.032556 -0.031735
# 99 -0.037807 -0.036865 -0.035943 -0.035040 -0.034156 -0.033291 -0.032444
#
#            7         8         9  ...        90        91        92        93  \
# 0  -0.011973 -0.011707 -0.011445  ... -0.000112 -0.000088 -0.000068 -0.000050
# 1  -0.012038 -0.011770 -0.011506  ... -0.000112 -0.000089 -0.000068 -0.000050
# 2  -0.012103 -0.011834 -0.011568  ... -0.000113 -0.000089 -0.000068 -0.000050
# 3  -0.012169 -0.011898 -0.011631  ... -0.000113 -0.000090 -0.000069 -0.000050
# 4  -0.012235 -0.011963 -0.011695  ... -0.000114 -0.000090 -0.000069 -0.000051
# ..       ...       ...       ...  ...       ...       ...       ...       ...
# 95 -0.029096 -0.028371 -0.027660  ... -0.000249 -0.000197 -0.000151 -0.000111
# 96 -0.029675 -0.028930 -0.028200  ... -0.000253 -0.000200 -0.000153 -0.000112
# 97 -0.030285 -0.029520 -0.028770  ... -0.000257 -0.000203 -0.000155 -0.000114
# 98 -0.030931 -0.030143 -0.029372  ... -0.000261 -0.000206 -0.000158 -0.000116
# 99 -0.031615 -0.030804 -0.030009  ... -0.000265 -0.000209 -0.000160 -0.000118
#
#           94        95        96        97        98   99
# 0  -0.000034 -0.000022 -0.000012 -0.000006 -0.000001  0.0
# 1  -0.000035 -0.000022 -0.000012 -0.000006 -0.000001  0.0
# 2  -0.000035 -0.000022 -0.000013 -0.000006 -0.000001  0.0
# 3  -0.000035 -0.000022 -0.000013 -0.000006 -0.000001  0.0
# 4  -0.000035 -0.000023 -0.000013 -0.000006 -0.000001  0.0
# ..       ...       ...       ...       ...       ...  ...
# 95 -0.000077 -0.000049 -0.000028 -0.000012 -0.000003  0.0
# 96 -0.000078 -0.000050 -0.000028 -0.000012 -0.000003  0.0
# 97 -0.000079 -0.000051 -0.000029 -0.000013 -0.000003  0.0
# 98 -0.000080 -0.000051 -0.000029 -0.000013 -0.000003  0.0
# 99 -0.000082 -0.000052 -0.000029 -0.000013 -0.000003  0.0
#
# [100 rows x 100 columns]

# %%
true_losses = truth.to_numpy()

# %%
loss_fn = allocation_cost_no_con

# %% [markdown]
# # 03 Adaptively learn solution path

# %%
max_epochs = 25

# %%
phi_lam = bivariate_legendre
# phi_lam = bivariate_chebyshev

# %%
basis_list = [4, 9, 16, 25, 36]
lr_list = [.1, .1, .1, .1, .1]
# basis_list = [4, 4]
# lr_list = [.1, .1]

# %%
def thresh_basis(basis_dim):
    return 0.1**(basis_dim/3 + 6)

# %%
def thresh_basis(basis_dim):
    return 0.1**(basis_dim/3.5 + 5)

# %%
np.random.seed(8675309)
torch.manual_seed(8675309)

num_itr_history, sup_err_history, breaks, break_grad_list = adaptive_lsp(input_dim, 4, 25,
                                        phi_lam, max_epochs, GD_data_loader,  test_data_loader,
                                        loss_fn, lam_min_2d, lam_max_2d, true_losses, init_lr=.1,
                                        diminish=False, weighted_avg=False,
                                        intercept=False, thresh_basis=thresh_basis, record_frequency=1,
                                        record_fctn=get_sup_error_lsp_2d,
                                        opt_method='lbfgs', distribution='uniform', device=device, 
                                        basis_list=basis_list, lr_list=lr_list,
                                        trace_frequency=1)
# Out:
# ********** now running lsp with #basis dimension = 4 ***********
# lr = 0.1
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 1	 sup error: 0.006372387160541733
# --------approximate solution path for # itr = 40 complete--------
# # epoch: 2	 sup error: 0.004795613338234146
# --------approximate solution path for # itr = 60 complete--------
# # epoch: 3	 sup error: 0.0035149255888483125
# --------approximate solution path for # itr = 80 complete--------
# # epoch: 4	 sup error: 0.003219174792053421
# --------approximate solution path for # itr = 86 complete--------
# # epoch: 5	 sup error: 0.003206914861681183
# ********** now running lsp with #basis dimension = 9 ***********
# lr = 0.1
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 1	 sup error: 0.0023326823608896333
# --------approximate solution path for # itr = 40 complete--------
# # epoch: 2	 sup error: 0.001775267173530777
# --------approximate solution path for # itr = 60 complete--------
# # epoch: 3	 sup error: 0.0010654764370939332
# --------approximate solution path for # itr = 80 complete--------
# # epoch: 4	 sup error: 0.0007943535344621735
# --------approximate solution path for # itr = 100 complete--------
# # epoch: 5	 sup error: 0.0007985631124994355
# --------approximate solution path for # itr = 103 complete--------
# # epoch: 6	 sup error: 0.0007985929148218232
# ********** now running lsp with #basis dimension = 16 ***********
# lr = 0.1
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 1	 sup error: 0.0007872531311533051
# --------approximate solution path for # itr = 40 complete--------
# # epoch: 2	 sup error: 0.0007687943177244264
# --------approximate solution path for # itr = 60 complete--------
# # epoch: 3	 sup error: 0.0005939403669855195
# --------approximate solution path for # itr = 80 complete--------
# # epoch: 4	 sup error: 0.0004995303349515992
# --------approximate solution path for # itr = 100 complete--------
# # epoch: 5	 sup error: 0.00042410065698834237
# --------approximate solution path for # itr = 120 complete--------
# # epoch: 6	 sup error: 0.00035108496713848886
# --------approximate solution path for # itr = 140 complete--------
# # epoch: 7	 sup error: 0.0002973998086473542
# --------approximate solution path for # itr = 160 complete--------
# # epoch: 8	 sup error: 0.00022218992281170663
# --------approximate solution path for # itr = 180 complete--------
# # epoch: 9	 sup error: 0.00018605460691662606
# --------approximate solution path for # itr = 182 complete--------
# # epoch: 10	 sup error: 0.00018472467828007516
# --------approximate solution path for # itr = 189 complete--------
# # epoch: 11	 sup error: 0.0001808876292726594
# --------approximate solution path for # itr = 191 complete--------
# # epoch: 12	 sup error: 0.00018062685895176706
# --------approximate solution path for # itr = 194 complete--------
# # epoch: 13	 sup error: 0.00018010159301968393
# --------approximate solution path for # itr = 196 complete--------
# # epoch: 14	 sup error: 0.00017995258140774545
# --------approximate solution path for # itr = 198 complete--------
# # epoch: 15	 sup error: 0.00017982219624729928
# --------approximate solution path for # itr = 200 complete--------
# # epoch: 16	 sup error: 0.00017971788811894235
# ********** now running lsp with #basis dimension = 25 ***********
# lr = 0.1
# --------approximate solution path for # itr = 20 complete--------
# # epoch: 1	 sup error: 0.00017977376747341928
# --------approximate solution path for # itr = 40 complete--------
# # epoch: 2	 sup error: 0.0001808466510793763
# --------approximate solution path for # itr = 42 complete--------
# # epoch: 3	 sup error: 0.00018089135456295785
# --------approximate solution path for # itr = 49 complete--------
# # epoch: 4	 sup error: 0.00018126015830250558
# --------approximate solution path for # itr = 53 complete--------
# # epoch: 5	 sup error: 0.0001815507309457856
# --------approximate solution path for # itr = 73 complete--------
# # epoch: 6	 sup error: 0.0001825006799718934
# --------approximate solution path for # itr = 93 complete--------
# # epoch: 7	 sup error: 0.00017237534094067392
# --------approximate solution path for # itr = 113 complete--------
# # epoch: 8	 sup error: 0.00015418847370358285
# --------approximate solution path for # itr = 133 complete--------
# # epoch: 9	 sup error: 0.00013613571691723642
# --------approximate solution path for # itr = 135 complete--------
# # epoch: 10	 sup error: 0.000135148514988144
# --------approximate solution path for # itr = 144 complete--------
# # epoch: 11	 sup error: 0.00012902041244717416
# --------approximate solution path for # itr = 147 complete--------
# # epoch: 12	 sup error: 0.00012785812187405404
# --------approximate solution path for # itr = 149 complete--------
# # epoch: 13	 sup error: 0.00012730677890988168
# --------approximate solution path for # itr = 155 complete--------
# # epoch: 14	 sup error: 0.00012493376898976144
# --------approximate solution path for # itr = 157 complete--------
# # epoch: 15	 sup error: 0.00012459849286289987
# --------approximate solution path for # itr = 159 complete--------
# # epoch: 16	 sup error: 0.000124293019058426
# --------approximate solution path for # itr = 161 complete--------
# # epoch: 17	 sup error: 0.00012402479815693673
# --------approximate solution path for # itr = 163 complete--------
# # epoch: 18	 sup error: 0.0001238124566099244
# --------approximate solution path for # itr = 165 complete--------
# # epoch: 19	 sup error: 0.00012359266448231515
# --------approximate solution path for # itr = 167 complete--------
# # epoch: 20	 sup error: 0.00012339894938679513
# --------approximate solution path for # itr = 169 complete--------
# # epoch: 21	 sup error: 0.00012323876190396127
# --------approximate solution path for # itr = 172 complete--------
# # epoch: 22	 sup error: 0.00012295936513157663
# --------approximate solution path for # itr = 174 complete--------
# # epoch: 23	 sup error: 0.00012284015584202584
# --------approximate solution path for # itr = 176 complete--------
# # epoch: 24	 sup error: 0.000122728397133072
# --------approximate solution path for # itr = 177 complete--------
# # epoch: 25	 sup error: 0.000122728397133072

# %%
pd.DataFrame(np.column_stack((break_grad_list, breaks)), columns=['break_grads', 'break_func_evals']).to_csv('LSP_results_exact_boosted_breaks_2d_no_con.csv', index=False)

# %%
last_grad_call = break_grad_list[len(break_grad_list)-1]

# %%
break_grad_list
# Out:
# [5, 11, 27, 52]

# %%
file_path = 'LSP_results_exact_boosted_2d_no_con.csv'

LSP_results_exact = pd.DataFrame(np.column_stack((np.arange(1, last_grad_call+1), num_itr_history, sup_err_history)), columns=['num_grad_call', 'num_itr', 'sup_err'])

# Save the DataFrame to a CSV file
LSP_results_exact.to_csv(file_path, index=False)

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Display the DataFrame
df
# Out:
#     num_grad_call  num_itr   sup_err
# 0             1.0     20.0  0.006372
# 1             2.0     40.0  0.004796
# 2             3.0     60.0  0.003515
# 3             4.0     80.0  0.003219
# 4             5.0     86.0  0.003207
# 5             6.0    106.0  0.002333
# 6             7.0    126.0  0.001775
# 7             8.0    146.0  0.001065
# 8             9.0    166.0  0.000794
# 9            10.0    186.0  0.000799
# 10           11.0    189.0  0.000799
# 11           12.0    209.0  0.000787
# 12           13.0    229.0  0.000769
# 13           14.0    249.0  0.000594
# 14           15.0    269.0  0.000500
# 15           16.0    289.0  0.000424
# 16           17.0    309.0  0.000351
# 17           18.0    329.0  0.000297
# 18           19.0    349.0  0.000222
# 19           20.0    369.0  0.000186
# 20           21.0    371.0  0.000185
# 21           22.0    378.0  0.000181
# 22           23.0    380.0  0.000181
# 23           24.0    383.0  0.000180
# 24           25.0    385.0  0.000180
# 25           26.0    387.0  0.000180
# 26           27.0    389.0  0.000180
# 27           28.0    409.0  0.000180
# 28           29.0    429.0  0.000181
# 29           30.0    431.0  0.000181
# 30           31.0    438.0  0.000181
# 31           32.0    442.0  0.000182
# 32           33.0    462.0  0.000183
# 33           34.0    482.0  0.000172
# 34           35.0    502.0  0.000154
# 35           36.0    522.0  0.000136
# 36           37.0    524.0  0.000135
# 37           38.0    533.0  0.000129
# 38           39.0    536.0  0.000128
# 39           40.0    538.0  0.000127
# 40           41.0    544.0  0.000125
# 41           42.0    546.0  0.000125
# 42           43.0    548.0  0.000124
# 43           44.0    550.0  0.000124
# 44           45.0    552.0  0.000124
# 45           46.0    554.0  0.000124
# 46           47.0    556.0  0.000123
# 47           48.0    558.0  0.000123
# 48           49.0    561.0  0.000123
# 49           50.0    563.0  0.000123
# 50           51.0    565.0  0.000123
# 51           52.0    566.0  0.000123
