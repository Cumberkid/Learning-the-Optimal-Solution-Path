# %% [markdown]
# # 01 Import Libraries

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
# !rm -r Learning-the-Optimal-Solution-Path
# !git clone https://github.com/Cumberkid/Learning-the-Optimal-Solution-Path.git
# Out:
# Cloning into 'Learning-the-Optimal-Solution-Path'...
# remote: Enumerating objects: 1744, done.
# remote: Counting objects: 100% (714/714), done.
# remote: Compressing objects: 100% (355/355), done.
# remote: Total 1744 (delta 542), reused 479 (delta 359), pack-reused 1030 (from 1)
# Receiving objects: 100% (1744/1744), 13.25 MiB | 8.31 MiB/s, done.
# Resolving deltas: 100% (1179/1179), done.

# %%
# Add the file directory to sys.path
# results_dir = '/content/Learning-the-Optimal-Solution-Path/experiments/fair-regression/results/'
results_dir = ''

# %% [markdown]
# # 02 Load NGS results

# %%
csv_file_path = results_dir + 'NGS_results_exact_legendre.csv'
NGS_results_exact = pd.read_csv(csv_file_path)
num_itr_NGS_exact = np.array(NGS_results_exact['num_itr'])
sup_err_NGS_exact = np.array(NGS_results_exact['sup_err'])

# %%
csv_file_path = results_dir + 'NGS_results_noisy_legendre.csv'
NGS_results_noisy = pd.read_csv(csv_file_path)
num_itr_NGS_noisy = np.array(NGS_results_noisy['num_itr'])
sup_err_NGS_noisy = np.array(NGS_results_noisy['sup_err'])

# %% [markdown]
# # 03 Plot NGS vs LSP fixed bases using Exact Gradient

# %%
csv_file_path = results_dir + 'LSP_results_exact_fixed_basis_legendre.csv'
LSP_results_exact = pd.read_csv(csv_file_path)
num_itr_LSP = np.array(LSP_results_exact['num_itr'])
sup_err_LSP_5 = np.array(LSP_results_exact['sup_err_5'])
sup_err_LSP_7 = np.array(LSP_results_exact['sup_err_7'])
sup_err_LSP_9 = np.array(LSP_results_exact['sup_err_9'])

# %%
# plot result of learning the solution path for every 100 gradient calls
plt.figure(figsize=(18,18))
plt.plot((num_itr_NGS_exact[:len(num_itr_NGS_exact)-4]), np.log(sup_err_NGS_exact[:len(num_itr_NGS_exact)-4]), '-o', linewidth=30, markersize=20, label = "NGS", alpha=0.5)
plt.plot((num_itr_LSP), np.log(sup_err_LSP_5), '--.', linewidth=5, markersize=13, label = "LSP-5 Legendre")
plt.plot((num_itr_LSP), np.log(sup_err_LSP_7), '--.', linewidth=5, markersize=13, label = "LSP-7 Legendre")
plt.plot((num_itr_LSP), np.log(sup_err_LSP_9), '--.', linewidth=5, markersize=13, label = "LSP-9 Legendre")

# Set global font size
mpl.rcParams['font.size'] = 55

font_size = 55
# Tick labels
plt.xticks(fontsize=font_size)
plt.yticks(fontsize=font_size)
plt.xlim(0, )
# Legend, if applicable
plt.legend(fontsize=font_size)

plt.xlabel('# Passes', fontsize=font_size)
plt.ylabel('Solution Path Error \n Presented in $\\log_{10}$', fontsize=font_size)
plt.grid(True)

# Show the plot
# plt.show()

plt.savefig("itr_exact.png")

# %% [markdown]
# # 04 Plot NGS vs LSP boosted using Exact Gradient

# %%
csv_file_path = results_dir + 'LSP_results_exact_boosted_legendre.csv'
LSP_results_exact_boosted = pd.read_csv(csv_file_path)
num_itr_LSP_boosted = np.array(LSP_results_exact_boosted['num_itr'])
sup_err_LSP_boosted = np.array(LSP_results_exact_boosted['sup_err'])

# %%
csv_file_path = results_dir + 'LSP_results_exact_boosted_breaks_legendre.csv'
LSP_results_exact_boosted_breaks = pd.read_csv(csv_file_path)
breaks = np.array(LSP_results_exact_boosted_breaks['breaks'])

# %%
# plot result of learning the solution path for every 100 gradient calls
plt.figure(figsize=(18,18))
plt.plot((num_itr_NGS_exact), np.log(sup_err_NGS_exact), '-o', linewidth=30, markersize=20, label = "Naive Grid Search", alpha=0.5)
for break_itr in breaks:
    plt.axvline(x = break_itr, color='tab:orange', alpha=0.5)
plt.plot((num_itr_LSP_boosted), np.log(sup_err_LSP_boosted), '--o', linewidth=8, markersize=20, label = "ALSP Legendre")

# Set global font size
mpl.rcParams['font.size'] = 55

font_size = 55
# Tick labels
plt.xticks(fontsize=font_size)
plt.yticks(fontsize=font_size)
plt.xlim(0, )

# Legend, if applicable
plt.legend(fontsize=font_size)

plt.xlabel('# Passes', fontsize=font_size)
plt.ylabel('Solution Path Error \n Presented in $\\log_{10}$', fontsize=font_size)
plt.grid(True)

# Show the plot
# plt.show()

plt.savefig("boosted_exact_legendre.png")

# %% [markdown]
# # 05 Plot NGS vs LSP fixed basis using Noisy Gradient

# %%
csv_file_path = results_dir + 'LSP_results_noisy_fixed_basis_legendre.csv'
LSP_results_noisy = pd.read_csv(csv_file_path)
num_itr_LSP = np.array(LSP_results_noisy['num_itr'])
sup_err_LSP_5 = np.array(LSP_results_noisy['sup_err_5'])
sup_err_LSP_7 = np.array(LSP_results_noisy['sup_err_7'])
sup_err_LSP_9 = np.array(LSP_results_noisy['sup_err_9'])

# %%
# plot result of learning the solution path for every 100 gradient calls
plt.figure(figsize=(18,18))
plt.plot((num_itr_NGS_noisy), np.log(sup_err_NGS_noisy), '-o', linewidth=30, markersize=20, label = "Naive Grid Search", alpha=0.5)
plt.plot((num_itr_LSP), np.log(sup_err_LSP_5), '--.', linewidth=5, markersize=13, label = "LSP: first 5 Legendre")
plt.plot((num_itr_LSP), np.log(sup_err_LSP_7), '--.', linewidth=5, markersize=13, label = "LSP: first 7 Legendre")
plt.plot((num_itr_LSP), np.log(sup_err_LSP_9), '--.', linewidth=5, markersize=13, label = "LSP: first 9 Legendre")

# Set global font size
mpl.rcParams['font.size'] = 55

font_size = 55
# Tick labels
plt.xticks(fontsize=font_size)
plt.yticks(fontsize=font_size)

# Legend, if applicable
plt.legend(fontsize=font_size)

plt.xlabel('# Passes', fontsize=font_size)
plt.ylabel('$\\log$ Solution Path Error', fontsize=font_size)
plt.grid(True)

# Show the plot
# plt.show()

plt.savefig("fixed_noisy_legendre.png")

# %% [markdown]
# # 06 Plot NGS vs LSP boosted using Noisy Gradient

# %%
csv_file_path = results_dir + 'LSP_results_noisy_boosted_legendre.csv'
LSP_results_noisy_boosted = pd.read_csv(csv_file_path)
num_itr_LSP_boosted = np.array(LSP_results_noisy_boosted['num_itr'])
sup_err_LSP_boosted = np.array(LSP_results_noisy_boosted['sup_err'])

# %%
csv_file_path = results_dir + 'LSP_results_noisy_boosted_breaks_legendre.csv'
LSP_results_noisy_boosted_breaks = pd.read_csv(csv_file_path)
breaks = np.array(LSP_results_noisy_boosted_breaks['breaks'])

# %%
# plot result of learning the solution path for every 100 gradient calls
plt.figure(figsize=(18,18))
plt.plot((num_itr_NGS_noisy), np.log(sup_err_NGS_noisy), '-o', linewidth=30, markersize=20, label = "Naive Grid Search", alpha=0.5)
for break_itr in breaks:
    plt.axvline(x = break_itr, color='tab:orange', alpha=0.5)
plt.plot((num_itr_LSP_boosted), np.log(sup_err_LSP_boosted), '--o', linewidth=8, markersize=20, label = "LSP adaptive Legendre")


# Set global font size
mpl.rcParams['font.size'] = 40

font_size = 40
# Tick labels
plt.xticks(fontsize=font_size)
plt.yticks(fontsize=font_size)

# Legend, if applicable
plt.legend(fontsize=font_size)

plt.xlabel('# Passes', fontsize=font_size)
plt.ylabel('$\\log$ Solution Path Error', fontsize=font_size)
plt.grid(True)

# Show the plot
plt.show()

# plt.savefig("noisy_boosted.png")

# %% [markdown]
# #07 Plot exact altogether

# %%
csv_file_path = results_dir + 'LSP_results_exact_fixed_basis_legendre.csv'
LSP_results_exact = pd.read_csv(csv_file_path)
num_itr_LSP = np.array(LSP_results_exact['num_itr'])
sup_err_LSP_5 = np.array(LSP_results_exact['sup_err_5'])
sup_err_LSP_7 = np.array(LSP_results_exact['sup_err_7'])
sup_err_LSP_9 = np.array(LSP_results_exact['sup_err_9'])

# %%
csv_file_path = results_dir + 'LSP_results_exact_boosted_legendre.csv'
LSP_results_exact_boosted = pd.read_csv(csv_file_path)
num_itr_LSP_boosted = np.array(LSP_results_exact_boosted['num_itr'])
sup_err_LSP_boosted = np.array(LSP_results_exact_boosted['sup_err'])

# %%
csv_file_path = results_dir + 'LSP_results_exact_boosted_breaks_legendre.csv'
LSP_results_exact_boosted_breaks = pd.read_csv(csv_file_path)
breaks = np.array(LSP_results_exact_boosted_breaks['breaks'])

# %%
# plot result of learning the solution path for every 100 gradient calls
plt.figure(figsize=(18,18))
plt.plot((num_itr_NGS_exact[:len(num_itr_NGS_exact)-4]), np.log10(sup_err_NGS_exact[:len(num_itr_NGS_exact)-4]), '-o', linewidth=30, markersize=20, label = "Naive Grid Search", alpha=0.5)
for break_itr in breaks:
    plt.axvline(x = break_itr, color='tab:orange', alpha=0.5)
plt.plot((num_itr_LSP_boosted), np.log10(sup_err_LSP_boosted), '--o', linewidth=8, markersize=20, label = "ALSP Legendre")
plt.plot((num_itr_LSP), np.log10(sup_err_LSP_5), '--.', linewidth=5, markersize=13, label = "LSP-5 Legendre")
plt.plot((num_itr_LSP), np.log10(sup_err_LSP_7), '--.', linewidth=5, markersize=13, label = "LSP-7 Legendre")
plt.plot((num_itr_LSP), np.log10(sup_err_LSP_9), '--.', linewidth=5, markersize=13, label = "LSP-9 Legendre")

# Set global font size
mpl.rcParams['font.size'] = 55

font_size = 55
# Tick labels
plt.xticks(fontsize=font_size)
plt.yticks(fontsize=font_size)
plt.xlim(0, )
# Legend, if applicable
plt.legend(fontsize=font_size)

plt.xlabel('# Passes', fontsize=font_size)
plt.ylabel('Solution Path Error \n Presented in $\\log_{10}$', fontsize=font_size)
plt.grid(True)

# Show the plot
# plt.show()

plt.savefig("itr_exact.png")
